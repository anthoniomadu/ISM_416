# %% [markdown]
# ## Study the resource materials for this week's class on ISM 415, and see if you can apply similar techique to your structured corpus.
#
# + Read your csv corpus
# + check and drop missing values
# + Try other things

# %%
import pandas as pd

# %%
data = pd.read_csv('emails.csv')
data
# Out:
#                        sender_email           sender_name recipient_name  \
# 0       james_ngola2002@maktoob.com    "MR. JAMES NGOLA."            NaN
# 1      bensul2004nng@spinfinder.com     "Mr. Ben Suleman"            NaN
# 2              obong_715@epatra.com  "PRINCE OBONG ELEME"            NaN
# 3              obong_715@epatra.com  "PRINCE OBONG ELEME"            NaN
# 4                m_abacha03@www.com       "Maryam Abacha"            NaN
# ...                             ...                   ...            ...
# 3972  michealagu0255@zipmail.com.br                   NaN            NaN
# 3973       ali_sherif252@hotmail.fr                   NaN            NaN
# 3974  drusmanibrahimtg08@hotmail.fr                   NaN            NaN
# 3975     motherdorisk61@hotmail.com                   NaN            NaN
# 3976                            NaN                   NaN            NaN
#
#         date_sent                                            subject  \
# ...

# %%
data.isnull().sum()
# Out:
# sender_email        473
# sender_name        1671
# recipient_name     3813
# date_sent           614
# subject              27
# email_body            1
# recipient_email    3977
# dtype: int64

# %%
#how many rows and columns
data.shape
# Out:
# (3977, 7)

# %%
# drop the columns which have too many null values and assign to new variable
newdata = data.drop(['recipient_name', 'recipient_email', 'sender_name'], axis = 1) # in python, Row 0 column 1

# %%
newdata
# Out:
#                        sender_email    date_sent  \
# 0       james_ngola2002@maktoob.com  31 Oct 2002
# 1      bensul2004nng@spinfinder.com  31 Oct 2002
# 2              obong_715@epatra.com  31 Oct 2002
# 3              obong_715@epatra.com  31 Oct 2002
# 4                m_abacha03@www.com   1 Nov 2002
# ...                             ...          ...
# 3972  michealagu0255@zipmail.com.br          NaN
# 3973       ali_sherif252@hotmail.fr  17 Sep 2007
# 3974  drusmanibrahimtg08@hotmail.fr  18 Sep 2007
# 3975     motherdorisk61@hotmail.com  19 Sep 2007
# 3976                            NaN  19 Sep 2007
#
#                                                 subject  \
# 0            URGENT BUSINESS ASSISTANCE AND PARTNERSHIP
# 1                   URGENT ASSISTANCE /RELATIONSHIP (P)
# 2                                       GOOD DAY TO YOU
# 3                                       GOOD DAY TO YOU
# 4                               I Need Your Assistance.
# ...

# %%
newdata.isnull().sum()
# Out:
# sender_email    473
# date_sent       614
# subject          27
# email_body        1
# dtype: int64

# %%
# Number of emails 
newdata.email_body.value_counts()
# Out:
# From=3A Mrs Farah al-Hashemi\nAddress=3A Chiang Rai hospital\n31-12 Chiang Rai - Lampoon Rd=2C\n=2CChiang Rai Thailand\n\nDearest Beloved=2C\n\nThank you for the attention beeing given to go through my mail=2EI am Mrs=2EFarah al-Hashemi=2C The wife of iraq military finance corps Chief=2C who was incharge of the payment of the military salary during his life service\ntime =2E I am 58 years old=2C i am now receiving treatment in the hospital=2E It's quite obvious that I won't live Longer according to my doctor as i am sufering from my kidney transplant illness=2Cthis is because my illness has gotten to a very bad stage=2E\n\nMy late husband died from the British and American attacks over my country =2Cand during the period of our marriage we had two male children Musa and Idris=2EAfter the death of my husband =2C I inherited some money which my late husband deposited with a Security Finance Company in Thailand for safety=2EThe doctor has advised me that I may not live long=2C so I now 
# ...

# %% [markdown]
#  There are 3476 emails with messages

# %%
# Changing to datetime format
newdata['date_sent'] = pd.to_datetime(newdata['date_sent'], errors = 'coerce')

# %% [markdown]
# ### Month with the most emails

# %%
newdata['Month'] = newdata ['date_sent'].dt.month
newdata
# Out:
#                        sender_email  date_sent  \
# 0       james_ngola2002@maktoob.com 2002-10-31
# 1      bensul2004nng@spinfinder.com 2002-10-31
# 2              obong_715@epatra.com 2002-10-31
# 3              obong_715@epatra.com 2002-10-31
# 4                m_abacha03@www.com 2002-11-01
# ...                             ...        ...
# 3972  michealagu0255@zipmail.com.br        NaT
# 3973       ali_sherif252@hotmail.fr 2007-09-17
# 3974  drusmanibrahimtg08@hotmail.fr 2007-09-18
# 3975     motherdorisk61@hotmail.com 2007-09-19
# 3976                            NaN 2007-09-19
#
#                                                 subject  \
# 0            URGENT BUSINESS ASSISTANCE AND PARTNERSHIP
# 1                   URGENT ASSISTANCE /RELATIONSHIP (P)
# 2                                       GOOD DAY TO YOU
# 3                                       GOOD DAY TO YOU
# 4                               I Need Your Assistance.
# ...

# %%
newdata.isnull().sum()
# Out:
# sender_email    473
# date_sent       614
# subject          27
# email_body        1
# Month           614
# dtype: int64
