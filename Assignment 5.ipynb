# %% [markdown]
# ## Scrape any two articles of choice, summarize them and perform NLP tasks on the summaries

# %% [markdown]
# ### Import Libraries

# %%
import requests #Requests information from url
from bs4 import BeautifulSoup  #Makes the page received more understandable(beautiful)
import gensim 
import docx
from gensim.summarization import summarize

# %% [markdown]
# ### Scraping and summerizing article 1

# %%
url1 = 'https://www.npr.org/2021/05/26/1000448553/tiny-fund-scores-historic-win-in-battle-against-exxonmobil-over-future-of-oil'

# %%
requests.get(url1)
page = requests.get(url1).text
soup = BeautifulSoup(page)
header = soup.find('h1').get_text()
date = soup.find(name = 'span', attrs = {'class':'date'}).text
p_tags = soup.find_all('p')
text = [tags.get_text().strip() for tags in p_tags]
sentence_list = [sentence for sentence in text if not '\n' in sentence]
body = [sentence for sentence in sentence_list if '.' in sentence]
article = ''.join(body)
summary1 = summarize(article, 1)
doc = docx.Document()
doc.add_heading(header)
doc.add_picture('pic01.png')
doc.add_paragraph(date)
doc.add_paragraph(summary1)
doc.save('article1.docx')

# %%
summary1
# Out:
# 'Pictured are pumps at an Exxon gas station in Charlotte, N.C. A tiny fund got two board members elected to the oil giant\'s board, delivering a historic defeat to ExxonMobil.In a dramatic boardroom battle on Wednesday, a tiny hedge fund fought with the energy giant ExxonMobil over the future of the oil and gas industry — and won.The brand-new activist hedge fund successfully placed at least two new candidates on the company\'s board of directors in hopes that they can use that position to push Exxon to take climate change more seriously.\nFor two more seats on the board, the vote was too close to call.Winning a seat for any directors at all is an unprecedented achievement by activist shareholders, who have spent decades trying to persuade companies to cut their carbon emissions.\nTo do it at ExxonMobil, once the world\'s most influential oil company, makes the feat all the more astonishing.And it demonstrates how arguments about the financial implications of climate change — specifically, the possibility that the world will stop using oil and gas and investments in fossil fuels will not pay off — have moved firmly to the center of mainstream investor thinking.Public companies have a board of directors that\'s responsible for oversight of the CEO and overall corporate strategy.\nThe members of the board are technically elected by shareholders, but normally those elections are uncontested and voting is just a formality.Sometimes, though, unhappy investors decide to make it a real race by putting forward rival candidates.\nThat\'s exactly what happened at Exxon.A hedge fund called Engine No. 1 was formed just last year with the express purpose of challenging Exxon\'s corporate strategy.The company and the upstart fund have been vying for shareholders\' votes through slideshows, letters and public statements.The fund pointed to Exxon\'s poor performance, relative to its peers, during the years leading up to the pandemic.\nIt also forcefully argued that the company has not laid out a viable plan to be profitable if the world makes a rapid transition away from oil and gas to ward off the worst effects of climate change.Large European oil and gas companies are investing in renewable energy and pledging to slash their emissions to zero, but Exxon has consistently rejected that strategy.\nThe company says its core strengths are in oil and gas, and it argues that the world simply will not pivot away from those energy sources very quickly.Instead of branching into new industries where it doesn\'t have a competitive advantage, it argues that it can invest in carbon capture technology — capturing greenhouse gases in the atmosphere — and continue to make money off oil and gas in a "lower-carbon" future.This vision of the future is increasingly at odds with the goals espoused by world governments and the pathways laid out by organizations like the International Energy Agency.Exxon regards those goals and pathways as unrealistic, skeptically noting that some plans for fighting climate change would require people to immediately adjust their home thermostats and take significantly fewer flights.\nThose are behavioral changes the company does not believe likely enough to factor in to its business planning.The vote to defy management and add two dissident members to the board represents a repudiation of that philosophy.Engine No. 1 holds a tiny fraction of Exxon shares — just 0.02%, according to the proxy advisory firm ISS.\nBy itself, it had no chance to sway the company.But it spent months building support for its case.\nCalSTRS, the California teachers pension, was an early backer, citing frustration with Exxon\'s lack of response to previous shareholder proposals and direct appeals from investors."When Engine No. 1 brought this idea to us around replacing some of the incumbent directors, we were very intrigued — because we had tried everything else," says Aeisha Mastagni, a portfolio manager with CalSTRS\' sustainable investment and stewards ...

# %% [markdown]
# ### Tokenization

# %%
import spacy

# %% [markdown]
# ### Load the language model

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(summary1)

# %%
for token in doc:
    print(token.text, '--->', spacy.explain(token.text))
# Out:
# Pictured ---> None
# are ---> None
# pumps ---> None
# at ---> None
# an ---> None
# Exxon ---> None
# gas ---> None
# station ---> None
# in ---> None
# Charlotte ---> None
# , ---> punctuation mark, comma
# N.C. ---> None
# A ---> None
# tiny ---> None
# fund ---> None
# got ---> None
# two ---> None
# board ---> None
# members ---> None
# elected ---> None
# to ---> None
# the ---> None
# oil ---> None
# giant ---> None
# 's ---> None
# board ---> None
# , ---> punctuation mark, comma
# delivering ---> None
# a ---> None
# historic ---> None
# defeat ---> None
# to ---> None
# ExxonMobil ---> None
# . ---> punctuation mark, sentence closer
# In ---> None
# a ---> None
# dramatic ---> None
# boardroom ---> None
# battle ---> None
# on ---> None
# Wednesday ---> None
# , ---> punctuation mark, comma
# a ---> None
# tiny ---> None
# hedge ---> None
# fund ---> None
# fought ---> None
# with ---> None
# the ---> None
# energy ---> None
# giant ---> None
# ExxonMobil ---> None
# over ---> None
# the ---> None
# future ---> None
# of ---> None
# the ---> None
# oil ---> None
# and ---> None
# gas ---> None
# industry ---> None
# — ---> None
# and ---> None
# won ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# brand ---> None
# - ---> None
# new ---> None
# activist ---> None
# hedge ---> None
# fund ---> None
# successfully ---> None
# placed ---> None
# at ---> None
# least ---> None
# two ---> None
# new ---> None
# candidates ---> None
# on ---> None
# the ---> None
# company ---> None
# 's ---> None
# board ---> None
# of ---> None
# directors ---> None
# in ---> None
# hopes ---> None
# that ---> None
# they ---> None
# can ---> None
# use ---> None
# that ---> None
# position ---> None
# to ---> None
# push ---> None
# Exxon ---> None
# to ---> None
# take ---> None
# climate ---> None
# change ---> None
# more ---> None
# seriously ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# For ---> None
# two ---> None
# more ---> None
# seats ---> None
# on ---> None
# the ---> None
# board ---> None
# , ---> punctuation mark, comma
# the ---> None
# vote ---> None
# was ---> None
# too ---> None
# close ---> None
# to ---> None
# call ---> None
# . ---> punctuation mark, sentence closer
# Winning ---> None
# a ---> None
# seat ---> None
# for ---> None
# any ---> None
# directors ---> None
# at ---> None
# all ---> None
# is ---> None
# an ---> None
# unprecedented ---> None
# achievement ---> None
# by ---> None
# activist ---> None
# shareholders ---> None
# , ---> punctuation mark, comma
# who ---> None
# have ---> None
# spent ---> None
# decades ---> None
# trying ---> None
# to ---> None
# persuade ---> None
# companies ---> None
# to ---> None
# cut ---> None
# their ---> None
# carbon ---> None
# emissions ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# To ---> None
# do ---> None
# it ---> None
# at ---> None
# ExxonMobil ---> None
# , ---> punctuation mark, comma
# once ---> None
# the ---> None
# world ---> None
# 's ---> None
# most ---> None
# influential ---> None
# oil ---> None
# company ---> None
# , ---> punctuation mark, comma
# makes ---> None
# the ---> None
# feat ---> None
# all ---> None
# the ---> None
# more ---> None
# astonishing ---> None
# . ---> punctuation mark, sentence closer
# And ---> None
# it ---> None
# demonstrates ---> None
# how ---> None
# arguments ---> None
# about ---> None
# the ---> None
# financial ---> None
# implications ---> None
# of ---> None
# climate ---> None
# change ---> None
# — ---> None
# specifically ---> None
# , ---> punctuation mark, comma
# the ---> None
# possibility ---> None
# that ---> None
# the ---> None
# world ---> None
# will ---> None
# stop ---> None
# using ---> None
# oil ---> None
# and ---> None
# gas ---> None
# and ---> None
# investments ---> None
# in ---> None
# fossil ---> None
# fuels ---> None
# will ---> None
# not ---> None
# pay ---> None
# off ---> None
# — ---> None
# have ---> None
# moved ---> None
# firmly ---> None
# to ---> None
# the ---> None
# center ---> None
# of ---> None
# mainstream ---> None
# investor ---> None
# thinking ---> None
# . ---> punctuation mark, sentence closer
# Public ---> None
# companies ---> None
# have ---> None
# a ---> None
# board ---> None
# of ---> None
# directors ---> None
# that ---> None
# 's ---> None
# responsible ---> None
# for ---> None
# oversight ---> None
# of ---> None
# the ---> None
# CEO ---> None
# and ---> None
# overall ---> None
# corporate ---> None
# strategy ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# The ---> None
# members ---> None
# of ---> None
# the ---> None
# board ---> None
# are ---> None
# technically ---> None
# elected ---> None
# by ---> None
# shareholders ---> None
# , ---> punctuation mark, comma
# but ---> None
# normally ---> None
# those ---> None
# elections ---> None
# are ---> None
# uncontested ---> None
# and ---> None
# voting ---> None
# is ---> None
# just ---> None
# a ---> None
# formality ---> None
# . ---> punctuation mark, sentence closer
# Sometimes ---> None
# , ---> punctuation mark, comma
# though ---> None
# , ---> punctuation mark, comma
# unhappy ---> None
# investors ---> None
# decide ---> None
# to ---> None
# make ---> None
# it ---> None
# a ---> None
# real ---> None
# race ---> None
# by ---> None
# putting ---> None
# forward ---> None
# rival ---> None
# candidates ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# That ---> None
# 's ---> None
# exactly ---> None
# what ---> None
# happened ---> None
# at ---> None
# Exxon ---> None
# . ---> punctuation mark, sentence closer
# A ---> None
# hedge ---> None
# fund ---> None
# called ---> None
# Engine ---> None
# No ---> None
# . ---> punctuation mark, sentence closer
# 1 ---> None
# was ---> None
# formed ---> None
# just ---> None
# last ---> None
# year ---> None
# with ---> None
# the ---> None
# express ---> None
# purpose ---> None
# of ---> None
# challenging ---> None
# Exxon ---> None
# 's ---> None
# corporate ---> None
# strategy ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# company ---> None
# and ---> None
# the ---> None
# upstart ---> None
# fund ---> None
# have ---> None
# been ---> None
# vying ---> None
# for ---> None
# shareholders ---> None
# ' ---> None
# votes ---> None
# through ---> None
# slideshows ---> None
# , ---> punctuation mark, comma
# letters ---> None
# and ---> None
# public ---> None
# statements ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# fund ---> None
# pointed ---> None
# to ---> None
# Exxon ---> None
# 's ---> None
# poor ---> None
# performance ---> None
# , ---> punctuation mark, comma
# relative ---> None
# to ---> None
# its ---> None
# peers ---> None
# , ---> punctuation mark, comma
# during ---> None
# the ---> None
# years ---> None
# leading ---> None
# up ---> None
# to ---> None
# the ---> None
# pandemic ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# It ---> None
# also ---> None
# forcefully ---> None
# argued ---> None
# that ---> None
# the ---> None
# company ---> None
# has ---> None
# not ---> None
# laid ---> None
# out ---> None
# a ---> None
# viable ---> None
# plan ---> None
# to ---> None
# be ---> None
# profitable ---> None
# if ---> None
# the ---> None
# world ---> None
# makes ---> None
# a ---> None
# rapid ---> None
# transition ---> None
# away ---> None
# from ---> None
# oil ---> None
# and ---> None
# gas ---> None
# to ---> None
# ward ---> None
# off ---> None
# the ---> None
# worst ---> None
# effects ---> None
# of ---> None
# climate ---> None
# change ---> None
# . ---> punctuation mark, sentence closer
# Large ---> None
# European ---> None
# oil ---> None
# and ---> None
# gas ---> None
# companies ---> None
# are ---> None
# investing ---> None
# in ---> None
# renewable ---> None
# energy ---> None
# and ---> None
# pledging ---> None
# to ---> None
# slash ---> None
# their ---> None
# emissions ---> None
# to ---> None
# zero ---> None
# , ---> punctuation mark, comma
# but ---> None
# Exxon ---> None
# has ---> None
# consistently ---> None
# rejected ---> None
# that ---> None
# strategy ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# The ---> None
# company ---> None
# says ---> None
# its ---> None
# core ---> None
# strengths ---> None
# are ---> None
# in ---> None
# oil ---> None
# and ---> None
# gas ---> None
# , ---> punctuation mark, comma
# and ---> None
# it ---> None
# argues ---> None
# that ---> None
# the ---> None
# world ---> None
# simply ---> None
# will ---> None
# not ---> None
# pivot ---> None
# away ---> None
# from ---> None
# those ---> None
# energy ---> None
# sources ---> None
# very ---> None
# quickly ---> None
# . ---> punctuation mark, sentence closer
# Instead ---> None
# of ---> None
# branching ---> None
# into ---> None
# new ---> None
# industries ---> None
# where ---> None
# it ---> None
# does ---> None
# n't ---> None
# have ---> None
# a ---> None
# competitive ---> None
# advantage ---> None
# , ---> punctuation mark, comma
# it ---> None
# argues ---> None
# that ---> None
# it ---> None
# can ---> None
# invest ---> None
# in ---> None
# carbon ---> None
# capture ---> None
# technology ---> None
# — ---> None
# capturing ---> None
# greenhouse ---> None
# gases ---> None
# in ---> None
# the ---> None
# atmosphere ---> None
# — ---> None
# and ---> None
# continue ---> None
# to ---> None
# make ---> None
# money ---> None
# off ---> None
# oil ---> None
# and ---> None
# gas ---> None
# in ---> None
# a ---> None
# " ---> None
# lower ---> None
# - ---> None
# carbon ---> None
# " ---> None
# future ---> None
# . ---> punctuation mark, sentence closer
# This ---> None
# vision ---> None
# of ---> None
# the ---> None
# future ---> None
# is ---> None
# increasingly ---> None
# at ---> None
# odds ---> None
# with ---> None
# the ---> None
# goals ---> None
# espoused ---> None
# by ---> None
# world ---> None
# governments ---> None
# and ---> None
# the ---> None
# pathways ---> None
# laid ---> None
# out ---> None
# by ---> None
# organizations ---> None
# like ---> None
# the ---> None
# International ---> None
# Energy ---> None
# Agency ---> None
# . ---> punctuation mark, sentence closer
# Exxon ---> None
# regards ---> None
# those ---> None
# goals ---> None
# and ---> None
# pathways ---> None
# as ---> None
# unrealistic ---> None
# , ---> punctuation mark, comma
# skeptically ---> None
# noting ---> None
# that ---> None
# some ---> None
# plans ---> None
# for ---> None
# fighting ---> None
# climate ---> None
# change ---> None
# would ---> None
# require ---> None
# people ---> None
# to ---> None
# immediately ---> None
# adjust ---> None
# their ---> None
# home ---> None
# thermostats ---> None
# and ---> None
# take ---> None
# significantly ---> None
# fewer ---> None
# flights ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# Those ---> None
# are ---> None
# behavioral ---> None
# changes ---> None
# the ---> None
# company ---> None
# does ---> None
# not ---> None
# believe ---> None
# likely ---> None
# enough ---> None
# to ---> None
# factor ---> None
# in ---> None
# to ---> None
# its ---> None
# business ---> None
# planning ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# vote ---> None
# to ---> None
# defy ---> None
# management ---> None
# and ---> None
# add ---> None
# two ---> None
# dissident ---> None
# members ---> None
# to ---> None
# the ---> None
# board ---> None
# represents ---> None
# a ---> None
# repudiation ---> None
# of ---> None
# that ---> None
# philosophy ---> None
# . ---> punctuation mark, sentence closer
# Engine ---> None
# No ---> None
# . ---> punctuation mark, sentence closer
# 1 ---> None
# holds ---> None
# a ---> None
# tiny ---> None
# fraction ---> None
# of ---> None
# Exxon ---> None
# shares ---> None
# — ---> None
# just ---> None
# 0.02 ---> None
# % ---> None
# , ---> punctuation mark, comma
# according ---> None
# to ---> None
# the ---> None
# proxy ---> None
# advisory ---> None
# firm ---> None
# ISS ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# By ---> None
# itself ---> None
# , ---> punctuation mark, comma
# it ---> None
# had ---> None
# no ---> None
# chance ---> None
# to ---> None
# sway ---> None
# the ---> None
# company ---> None
# . ---> punctuation mark, sentence closer
# But ---> None
# it ---> None
# spent ---> None
# months ---> None
# building ---> None
# support ---> None
# for ---> None
# its ---> None
# case ---> case marking
# . ---> punctuation mark, sentence closer
#
#  ---> None
# CalSTRS ---> None
# , ---> punctuation mark, comma
# the ---> None
# California ---> None
# teachers ---> None
# pension ---> None
# , ---> punctuation mark, comma
# was ---> None
# an ---> None
# early ---> None
# backer ---> None
# , ---> punctuation mark, comma
# citing ---> None
# frustration ---> None
# with ---> None
# Exxon ---> None
# 's ---> None
# lack ---> None
# of ---> None
# response ---> None
# to ---> None
# previous ---> None
# shareholder ---> None
# proposals ---> None
# and ---> None
# direct ---> None
# appeals ---> None
# from ---> None
# investors ---> None
# . ---> punctuation mark, sentence closer
# "When ---> None
# Engine ---> None
# No ---> None
# . ---> punctuation mark, sentence closer
# 1 ---> None
# brought ---> None
# this ---> None
# idea ---> None
# to ---> None
# us ---> None
# around ---> None
# replacing ---> None
# some ---> None
# of ---> None
# the ---> None
# incumbent ---> None
# directors ---> None
# , ---> punctuation mark, comma
# we ---> None
# were ---> None
# very ---> None
# intrigued ---> None
# — ---> None
# because ---> None
# we ---> None
# had ---> None
# tried ---> None
# everything ---> None
# else ---> None
# , ---> punctuation mark, comma
# " ---> None
# says ---> None
# Aeisha ---> None
# Mastagni ---> None
# , ---> punctuation mark, comma
# a ---> None
# portfolio ---> None
# manager ---> None
# with ---> None
# CalSTRS ---> None
# ' ---> None
# sustainable ---> None
# investment ---> None
# and ---> None
# stewardship ---> None
# strategies ---> None
# unit ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# influential ---> None
# proxy ---> None
# advisory ---> None
# firms ---> None
# ISS ---> None
# and ---> None
# Glass ---> None
# Lewis ---> None
# , ---> punctuation mark, comma
# which ---> None
# issue ---> None
# recommendations ---> None
# on ---> None
# how ---> None
# investors ---> None
# should ---> None
# vote ---> None
# in ---> None
# shareholder ---> None
# meetings ---> None
# , ---> punctuation mark, comma
# also ---> None
# partially ---> None
# endorsed ---> None
# Engine ---> None
# No ---> None
# . ---> punctuation mark, sentence closer
# 1 ---> None
# 's ---> None
# nominations ---> None
# . ---> punctuation mark, sentence closer
# Their ---> None
# reports ---> None
# provide ---> None
# a ---> None
# striking ---> None
# glimpse ---> None
# into ---> None
# how ---> None
# arguments ---> None
# that ---> None
# were ---> None
# initially ---> None
# made ---> None
# by ---> None
# climate ---> None
# activists ---> None
# are ---> None
# becoming ---> None
# increasingly ---> None
# mainstream ---> None
# in ---> None
# the ---> None
# investor ---> None
# community ---> None
# . ---> punctuation mark, sentence closer
# Both ---> None
# firms ---> None
# used ---> None
# the ---> None
# word ---> None
# " ---> None
# inevitable ---> None
# " ---> None
# to ---> None
# describe ---> None
# the ---> None
# energy ---> None
# transition ---> None
# , ---> punctuation mark, comma
# or ---> None
# the ---> None
# world ---> None
# 's ---> None
# shift ---> None
# away ---> None
# from ---> None
# relying ---> None
# on ---> None
# fossil ---> None
# fuels ---> None
# , ---> punctuation mark, comma
# and ---> None
# agreed ---> None
# that ---> None
# Exxon ---> None
# has ---> None
# inadequately ---> None
# prepared ---> None
# for ---> None
# this ---> None
# future ---> None
# . ---> punctuation mark, sentence closer
# Heading ---> None
# into ---> None
# Wednesday ---> None
# 's ---> None
# meeting ---> None
# , ---> punctuation mark, comma
# all ---> None
# eyes ---> None
# were ---> None
# on ---> None
# the ---> None
# three ---> None
# companies ---> None
# with ---> None
# the ---> None
# biggest ---> None
# sway ---> None
# in ---> None
# this ---> None
# vote ---> None
# : ---> punctuation mark, colon or ellipsis
# Blackrock ---> None
# , ---> punctuation mark, comma
# Vanguard ---> None
# and ---> None
# State ---> None
# Street ---> None
# Global ---> None
# Advisors ---> None
# . ---> punctuation mark, sentence closer
# Those ---> None
# companies ---> None
# manage ---> None
# huge ---> None
# funds ---> None
# — ---> None
# including ---> None
# many ---> None
# people ---> None
# 's ---> None
# retirement ---> None
# accounts ---> None
# — ---> None
# and ---> None
# their ---> None
# votes ---> None
# are ---> None
# weighted ---> None
# accordingly ---> None
# , ---> punctuation mark, comma
# giving ---> None
# them ---> None
# tremendous ---> None
# power ---> None
# in ---> None
# these ---> None
# kinds ---> None
# of ---> None
# proxy ---> None
# votes ---> None
# . ---> punctuation mark, sentence closer
# All ---> None
# three ---> None
# have ---> None
# pledged ---> None
# support ---> None
# for ---> None
# investor ---> None
# initiatives ---> None
# focused ---> None
# on ---> None
# fighting ---> None
# climate ---> None
# change ---> None
# . ---> punctuation mark, sentence closer

# %% [markdown]
# ### POS tagging

# %%
for token in doc:
    print(token.text, '--->', token.pos_, '--->', spacy.explain(token.pos_))
# Out:
# Pictured ---> VERB ---> verb
# are ---> AUX ---> auxiliary
# pumps ---> NOUN ---> noun
# at ---> ADP ---> adposition
# an ---> DET ---> determiner
# Exxon ---> PROPN ---> proper noun
# gas ---> NOUN ---> noun
# station ---> NOUN ---> noun
# in ---> ADP ---> adposition
# Charlotte ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# N.C. ---> PROPN ---> proper noun
# A ---> DET ---> determiner
# tiny ---> ADJ ---> adjective
# fund ---> NOUN ---> noun
# got ---> VERB ---> verb
# two ---> NUM ---> numeral
# board ---> NOUN ---> noun
# members ---> NOUN ---> noun
# elected ---> VERB ---> verb
# to ---> ADP ---> adposition
# the ---> DET ---> determiner
# oil ---> NOUN ---> noun
# giant ---> NOUN ---> noun
# 's ---> PART ---> particle
# board ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# delivering ---> VERB ---> verb
# a ---> DET ---> determiner
# historic ---> ADJ ---> adjective
# defeat ---> NOUN ---> noun
# to ---> ADP ---> adposition
# ExxonMobil ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# In ---> ADP ---> adposition
# a ---> DET ---> determiner
# dramatic ---> ADJ ---> adjective
# boardroom ---> NOUN ---> noun
# battle ---> NOUN ---> noun
# on ---> ADP ---> adposition
# Wednesday ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# a ---> DET ---> determiner
# tiny ---> ADJ ---> adjective
# hedge ---> NOUN ---> noun
# fund ---> NOUN ---> noun
# fought ---> VERB ---> verb
# with ---> ADP ---> adposition
# the ---> DET ---> determiner
# energy ---> NOUN ---> noun
# giant ---> NOUN ---> noun
# ExxonMobil ---> PROPN ---> proper noun
# over ---> ADP ---> adposition
# the ---> DET ---> determiner
# future ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# oil ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# gas ---> NOUN ---> noun
# industry ---> NOUN ---> noun
# — ---> PUNCT ---> punctuation
# and ---> CCONJ ---> coordinating conjunction
# won ---> VERB ---> verb
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# brand ---> NOUN ---> noun
# - ---> PUNCT ---> punctuation
# new ---> ADJ ---> adjective
# activist ---> ADJ ---> adjective
# hedge ---> NOUN ---> noun
# fund ---> NOUN ---> noun
# successfully ---> ADV ---> adverb
# placed ---> VERB ---> verb
# at ---> ADP ---> adposition
# least ---> ADV ---> adverb
# two ---> NUM ---> numeral
# new ---> ADJ ---> adjective
# candidates ---> NOUN ---> noun
# on ---> ADP ---> adposition
# the ---> DET ---> determiner
# company ---> NOUN ---> noun
# 's ---> PART ---> particle
# board ---> NOUN ---> noun
# of ---> ADP ---> adposition
# directors ---> NOUN ---> noun
# in ---> ADP ---> adposition
# hopes ---> NOUN ---> noun
# that ---> SCONJ ---> subordinating conjunction
# they ---> PRON ---> pronoun
# can ---> AUX ---> auxiliary
# use ---> VERB ---> verb
# that ---> DET ---> determiner
# position ---> NOUN ---> noun
# to ---> PART ---> particle
# push ---> VERB ---> verb
# Exxon ---> PROPN ---> proper noun
# to ---> PART ---> particle
# take ---> VERB ---> verb
# climate ---> NOUN ---> noun
# change ---> NOUN ---> noun
# more ---> ADV ---> adverb
# seriously ---> ADV ---> adverb
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# For ---> ADP ---> adposition
# two ---> NUM ---> numeral
# more ---> ADJ ---> adjective
# seats ---> NOUN ---> noun
# on ---> ADP ---> adposition
# the ---> DET ---> determiner
# board ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# vote ---> NOUN ---> noun
# was ---> AUX ---> auxiliary
# too ---> ADV ---> adverb
# close ---> ADJ ---> adjective
# to ---> PART ---> particle
# call ---> VERB ---> verb
# . ---> PUNCT ---> punctuation
# Winning ---> VERB ---> verb
# a ---> DET ---> determiner
# seat ---> NOUN ---> noun
# for ---> ADP ---> adposition
# any ---> DET ---> determiner
# directors ---> NOUN ---> noun
# at ---> ADV ---> adverb
# all ---> ADV ---> adverb
# is ---> AUX ---> auxiliary
# an ---> DET ---> determiner
# unprecedented ---> ADJ ---> adjective
# achievement ---> NOUN ---> noun
# by ---> ADP ---> adposition
# activist ---> ADJ ---> adjective
# shareholders ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# who ---> PRON ---> pronoun
# have ---> AUX ---> auxiliary
# spent ---> VERB ---> verb
# decades ---> NOUN ---> noun
# trying ---> VERB ---> verb
# to ---> PART ---> particle
# persuade ---> VERB ---> verb
# companies ---> NOUN ---> noun
# to ---> PART ---> particle
# cut ---> VERB ---> verb
# their ---> PRON ---> pronoun
# carbon ---> NOUN ---> noun
# emissions ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# To ---> PART ---> particle
# do ---> VERB ---> verb
# it ---> PRON ---> pronoun
# at ---> ADP ---> adposition
# ExxonMobil ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# once ---> SCONJ ---> subordinating conjunction
# the ---> DET ---> determiner
# world ---> NOUN ---> noun
# 's ---> PART ---> particle
# most ---> ADV ---> adverb
# influential ---> ADJ ---> adjective
# oil ---> NOUN ---> noun
# company ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# makes ---> VERB ---> verb
# the ---> DET ---> determiner
# feat ---> NOUN ---> noun
# all ---> DET ---> determiner
# the ---> DET ---> determiner
# more ---> ADV ---> adverb
# astonishing ---> ADJ ---> adjective
# . ---> PUNCT ---> punctuation
# And ---> CCONJ ---> coordinating conjunction
# it ---> PRON ---> pronoun
# demonstrates ---> VERB ---> verb
# how ---> ADV ---> adverb
# arguments ---> NOUN ---> noun
# about ---> ADP ---> adposition
# the ---> DET ---> determiner
# financial ---> ADJ ---> adjective
# implications ---> NOUN ---> noun
# of ---> ADP ---> adposition
# climate ---> NOUN ---> noun
# change ---> NOUN ---> noun
# — ---> PUNCT ---> punctuation
# specifically ---> ADV ---> adverb
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# possibility ---> NOUN ---> noun
# that ---> SCONJ ---> subordinating conjunction
# the ---> DET ---> determiner
# world ---> NOUN ---> noun
# will ---> AUX ---> auxiliary
# stop ---> VERB ---> verb
# using ---> VERB ---> verb
# oil ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# gas ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# investments ---> NOUN ---> noun
# in ---> ADP ---> adposition
# fossil ---> ADJ ---> adjective
# fuels ---> NOUN ---> noun
# will ---> AUX ---> auxiliary
# not ---> PART ---> particle
# pay ---> VERB ---> verb
# off ---> ADP ---> adposition
# — ---> PUNCT ---> punctuation
# have ---> AUX ---> auxiliary
# moved ---> VERB ---> verb
# firmly ---> ADV ---> adverb
# to ---> ADP ---> adposition
# the ---> DET ---> determiner
# center ---> NOUN ---> noun
# of ---> ADP ---> adposition
# mainstream ---> ADJ ---> adjective
# investor ---> NOUN ---> noun
# thinking ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Public ---> ADJ ---> adjective
# companies ---> NOUN ---> noun
# have ---> VERB ---> verb
# a ---> DET ---> determiner
# board ---> NOUN ---> noun
# of ---> ADP ---> adposition
# directors ---> NOUN ---> noun
# that ---> DET ---> determiner
# 's ---> VERB ---> verb
# responsible ---> ADJ ---> adjective
# for ---> ADP ---> adposition
# oversight ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# CEO ---> PROPN ---> proper noun
# and ---> CCONJ ---> coordinating conjunction
# overall ---> ADJ ---> adjective
# corporate ---> ADJ ---> adjective
# strategy ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# The ---> DET ---> determiner
# members ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# board ---> NOUN ---> noun
# are ---> AUX ---> auxiliary
# technically ---> ADV ---> adverb
# elected ---> VERB ---> verb
# by ---> ADP ---> adposition
# shareholders ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# but ---> CCONJ ---> coordinating conjunction
# normally ---> ADV ---> adverb
# those ---> DET ---> determiner
# elections ---> NOUN ---> noun
# are ---> VERB ---> verb
# uncontested ---> ADJ ---> adjective
# and ---> CCONJ ---> coordinating conjunction
# voting ---> NOUN ---> noun
# is ---> VERB ---> verb
# just ---> ADV ---> adverb
# a ---> DET ---> determiner
# formality ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Sometimes ---> ADV ---> adverb
# , ---> PUNCT ---> punctuation
# though ---> ADV ---> adverb
# , ---> PUNCT ---> punctuation
# unhappy ---> ADJ ---> adjective
# investors ---> NOUN ---> noun
# decide ---> VERB ---> verb
# to ---> PART ---> particle
# make ---> VERB ---> verb
# it ---> PRON ---> pronoun
# a ---> DET ---> determiner
# real ---> ADJ ---> adjective
# race ---> NOUN ---> noun
# by ---> ADP ---> adposition
# putting ---> VERB ---> verb
# forward ---> ADV ---> adverb
# rival ---> ADJ ---> adjective
# candidates ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# That ---> DET ---> determiner
# 's ---> AUX ---> auxiliary
# exactly ---> ADV ---> adverb
# what ---> PRON ---> pronoun
# happened ---> VERB ---> verb
# at ---> ADP ---> adposition
# Exxon ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# A ---> DET ---> determiner
# hedge ---> NOUN ---> noun
# fund ---> NOUN ---> noun
# called ---> VERB ---> verb
# Engine ---> PROPN ---> proper noun
# No ---> NOUN ---> noun
# . ---> NOUN ---> noun
# 1 ---> NUM ---> numeral
# was ---> AUX ---> auxiliary
# formed ---> VERB ---> verb
# just ---> ADV ---> adverb
# last ---> ADJ ---> adjective
# year ---> NOUN ---> noun
# with ---> ADP ---> adposition
# the ---> DET ---> determiner
# express ---> ADJ ---> adjective
# purpose ---> NOUN ---> noun
# of ---> ADP ---> adposition
# challenging ---> VERB ---> verb
# Exxon ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# corporate ---> ADJ ---> adjective
# strategy ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# company ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# the ---> DET ---> determiner
# upstart ---> ADJ ---> adjective
# fund ---> NOUN ---> noun
# have ---> AUX ---> auxiliary
# been ---> AUX ---> auxiliary
# vying ---> VERB ---> verb
# for ---> ADP ---> adposition
# shareholders ---> NOUN ---> noun
# ' ---> PART ---> particle
# votes ---> NOUN ---> noun
# through ---> ADP ---> adposition
# slideshows ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# letters ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# public ---> ADJ ---> adjective
# statements ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# fund ---> NOUN ---> noun
# pointed ---> VERB ---> verb
# to ---> ADP ---> adposition
# Exxon ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# poor ---> ADJ ---> adjective
# performance ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# relative ---> ADJ ---> adjective
# to ---> ADP ---> adposition
# its ---> PRON ---> pronoun
# peers ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# during ---> ADP ---> adposition
# the ---> DET ---> determiner
# years ---> NOUN ---> noun
# leading ---> VERB ---> verb
# up ---> ADP ---> adposition
# to ---> ADP ---> adposition
# the ---> DET ---> determiner
# pandemic ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# It ---> PRON ---> pronoun
# also ---> ADV ---> adverb
# forcefully ---> ADV ---> adverb
# argued ---> VERB ---> verb
# that ---> SCONJ ---> subordinating conjunction
# the ---> DET ---> determiner
# company ---> NOUN ---> noun
# has ---> AUX ---> auxiliary
# not ---> PART ---> particle
# laid ---> VERB ---> verb
# out ---> ADP ---> adposition
# a ---> DET ---> determiner
# viable ---> ADJ ---> adjective
# plan ---> NOUN ---> noun
# to ---> PART ---> particle
# be ---> VERB ---> verb
# profitable ---> ADJ ---> adjective
# if ---> SCONJ ---> subordinating conjunction
# the ---> DET ---> determiner
# world ---> NOUN ---> noun
# makes ---> VERB ---> verb
# a ---> DET ---> determiner
# rapid ---> ADJ ---> adjective
# transition ---> NOUN ---> noun
# away ---> ADV ---> adverb
# from ---> ADP ---> adposition
# oil ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# gas ---> NOUN ---> noun
# to ---> PART ---> particle
# ward ---> VERB ---> verb
# off ---> ADP ---> adposition
# the ---> DET ---> determiner
# worst ---> ADJ ---> adjective
# effects ---> NOUN ---> noun
# of ---> ADP ---> adposition
# climate ---> NOUN ---> noun
# change ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Large ---> ADJ ---> adjective
# European ---> ADJ ---> adjective
# oil ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# gas ---> NOUN ---> noun
# companies ---> NOUN ---> noun
# are ---> AUX ---> auxiliary
# investing ---> VERB ---> verb
# in ---> ADP ---> adposition
# renewable ---> ADJ ---> adjective
# energy ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# pledging ---> VERB ---> verb
# to ---> PART ---> particle
# slash ---> VERB ---> verb
# their ---> PRON ---> pronoun
# emissions ---> NOUN ---> noun
# to ---> ADP ---> adposition
# zero ---> NUM ---> numeral
# , ---> PUNCT ---> punctuation
# but ---> CCONJ ---> coordinating conjunction
# Exxon ---> PROPN ---> proper noun
# has ---> AUX ---> auxiliary
# consistently ---> ADV ---> adverb
# rejected ---> VERB ---> verb
# that ---> DET ---> determiner
# strategy ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# The ---> DET ---> determiner
# company ---> NOUN ---> noun
# says ---> VERB ---> verb
# its ---> PRON ---> pronoun
# core ---> NOUN ---> noun
# strengths ---> NOUN ---> noun
# are ---> AUX ---> auxiliary
# in ---> ADP ---> adposition
# oil ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# gas ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# and ---> CCONJ ---> coordinating conjunction
# it ---> PRON ---> pronoun
# argues ---> VERB ---> verb
# that ---> SCONJ ---> subordinating conjunction
# the ---> DET ---> determiner
# world ---> NOUN ---> noun
# simply ---> ADV ---> adverb
# will ---> AUX ---> auxiliary
# not ---> PART ---> particle
# pivot ---> VERB ---> verb
# away ---> ADV ---> adverb
# from ---> ADP ---> adposition
# those ---> DET ---> determiner
# energy ---> NOUN ---> noun
# sources ---> NOUN ---> noun
# very ---> ADV ---> adverb
# quickly ---> ADV ---> adverb
# . ---> PUNCT ---> punctuation
# Instead ---> ADV ---> adverb
# of ---> ADP ---> adposition
# branching ---> VERB ---> verb
# into ---> ADP ---> adposition
# new ---> ADJ ---> adjective
# industries ---> NOUN ---> noun
# where ---> ADV ---> adverb
# it ---> PRON ---> pronoun
# does ---> AUX ---> auxiliary
# n't ---> PART ---> particle
# have ---> VERB ---> verb
# a ---> DET ---> determiner
# competitive ---> ADJ ---> adjective
# advantage ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# it ---> PRON ---> pronoun
# argues ---> VERB ---> verb
# that ---> SCONJ ---> subordinating conjunction
# it ---> PRON ---> pronoun
# can ---> AUX ---> auxiliary
# invest ---> VERB ---> verb
# in ---> ADP ---> adposition
# carbon ---> NOUN ---> noun
# capture ---> NOUN ---> noun
# technology ---> NOUN ---> noun
# — ---> PUNCT ---> punctuation
# capturing ---> VERB ---> verb
# greenhouse ---> NOUN ---> noun
# gases ---> NOUN ---> noun
# in ---> ADP ---> adposition
# the ---> DET ---> determiner
# atmosphere ---> NOUN ---> noun
# — ---> PUNCT ---> punctuation
# and ---> CCONJ ---> coordinating conjunction
# continue ---> VERB ---> verb
# to ---> PART ---> particle
# make ---> VERB ---> verb
# money ---> NOUN ---> noun
# off ---> ADP ---> adposition
# oil ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# gas ---> NOUN ---> noun
# in ---> ADP ---> adposition
# a ---> DET ---> determiner
# " ---> PUNCT ---> punctuation
# lower ---> ADJ ---> adjective
# - ---> PUNCT ---> punctuation
# carbon ---> NOUN ---> noun
# " ---> PUNCT ---> punctuation
# future ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# This ---> DET ---> determiner
# vision ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# future ---> NOUN ---> noun
# is ---> AUX ---> auxiliary
# increasingly ---> ADV ---> adverb
# at ---> ADP ---> adposition
# odds ---> NOUN ---> noun
# with ---> ADP ---> adposition
# the ---> DET ---> determiner
# goals ---> NOUN ---> noun
# espoused ---> VERB ---> verb
# by ---> ADP ---> adposition
# world ---> NOUN ---> noun
# governments ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# the ---> DET ---> determiner
# pathways ---> NOUN ---> noun
# laid ---> VERB ---> verb
# out ---> ADP ---> adposition
# by ---> ADP ---> adposition
# organizations ---> NOUN ---> noun
# like ---> ADP ---> adposition
# the ---> DET ---> determiner
# International ---> PROPN ---> proper noun
# Energy ---> PROPN ---> proper noun
# Agency ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# Exxon ---> PROPN ---> proper noun
# regards ---> VERB ---> verb
# those ---> DET ---> determiner
# goals ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# pathways ---> NOUN ---> noun
# as ---> ADP ---> adposition
# unrealistic ---> ADJ ---> adjective
# , ---> PUNCT ---> punctuation
# skeptically ---> ADV ---> adverb
# noting ---> VERB ---> verb
# that ---> SCONJ ---> subordinating conjunction
# some ---> DET ---> determiner
# plans ---> NOUN ---> noun
# for ---> ADP ---> adposition
# fighting ---> VERB ---> verb
# climate ---> NOUN ---> noun
# change ---> NOUN ---> noun
# would ---> AUX ---> auxiliary
# require ---> VERB ---> verb
# people ---> NOUN ---> noun
# to ---> PART ---> particle
# immediately ---> ADV ---> adverb
# adjust ---> VERB ---> verb
# their ---> PRON ---> pronoun
# home ---> NOUN ---> noun
# thermostats ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# take ---> VERB ---> verb
# significantly ---> ADV ---> adverb
# fewer ---> ADJ ---> adjective
# flights ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# Those ---> DET ---> determiner
# are ---> AUX ---> auxiliary
# behavioral ---> ADJ ---> adjective
# changes ---> NOUN ---> noun
# the ---> DET ---> determiner
# company ---> NOUN ---> noun
# does ---> AUX ---> auxiliary
# not ---> PART ---> particle
# believe ---> VERB ---> verb
# likely ---> ADJ ---> adjective
# enough ---> ADV ---> adverb
# to ---> PART ---> particle
# factor ---> VERB ---> verb
# in ---> ADP ---> adposition
# to ---> ADP ---> adposition
# its ---> PRON ---> pronoun
# business ---> NOUN ---> noun
# planning ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# vote ---> NOUN ---> noun
# to ---> PART ---> particle
# defy ---> VERB ---> verb
# management ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# add ---> VERB ---> verb
# two ---> NUM ---> numeral
# dissident ---> ADJ ---> adjective
# members ---> NOUN ---> noun
# to ---> ADP ---> adposition
# the ---> DET ---> determiner
# board ---> NOUN ---> noun
# represents ---> VERB ---> verb
# a ---> DET ---> determiner
# repudiation ---> NOUN ---> noun
# of ---> ADP ---> adposition
# that ---> DET ---> determiner
# philosophy ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Engine ---> NOUN ---> noun
# No ---> NOUN ---> noun
# . ---> NOUN ---> noun
# 1 ---> NUM ---> numeral
# holds ---> VERB ---> verb
# a ---> DET ---> determiner
# tiny ---> ADJ ---> adjective
# fraction ---> NOUN ---> noun
# of ---> ADP ---> adposition
# Exxon ---> PROPN ---> proper noun
# shares ---> NOUN ---> noun
# — ---> PUNCT ---> punctuation
# just ---> ADV ---> adverb
# 0.02 ---> NUM ---> numeral
# % ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# according ---> VERB ---> verb
# to ---> ADP ---> adposition
# the ---> DET ---> determiner
# proxy ---> ADJ ---> adjective
# advisory ---> ADJ ---> adjective
# firm ---> NOUN ---> noun
# ISS ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# By ---> ADP ---> adposition
# itself ---> PRON ---> pronoun
# , ---> PUNCT ---> punctuation
# it ---> PRON ---> pronoun
# had ---> VERB ---> verb
# no ---> DET ---> determiner
# chance ---> NOUN ---> noun
# to ---> PART ---> particle
# sway ---> VERB ---> verb
# the ---> DET ---> determiner
# company ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# But ---> CCONJ ---> coordinating conjunction
# it ---> PRON ---> pronoun
# spent ---> VERB ---> verb
# months ---> NOUN ---> noun
# building ---> NOUN ---> noun
# support ---> NOUN ---> noun
# for ---> ADP ---> adposition
# its ---> PRON ---> pronoun
# case ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# CalSTRS ---> X ---> other
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# California ---> PROPN ---> proper noun
# teachers ---> NOUN ---> noun
# pension ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# was ---> AUX ---> auxiliary
# an ---> DET ---> determiner
# early ---> ADJ ---> adjective
# backer ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# citing ---> VERB ---> verb
# frustration ---> NOUN ---> noun
# with ---> ADP ---> adposition
# Exxon ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# lack ---> NOUN ---> noun
# of ---> ADP ---> adposition
# response ---> NOUN ---> noun
# to ---> ADP ---> adposition
# previous ---> ADJ ---> adjective
# shareholder ---> NOUN ---> noun
# proposals ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# direct ---> ADJ ---> adjective
# appeals ---> NOUN ---> noun
# from ---> ADP ---> adposition
# investors ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# "When ---> PROPN ---> proper noun
# Engine ---> NOUN ---> noun
# No ---> NOUN ---> noun
# . ---> NOUN ---> noun
# 1 ---> NUM ---> numeral
# brought ---> VERB ---> verb
# this ---> DET ---> determiner
# idea ---> NOUN ---> noun
# to ---> ADP ---> adposition
# us ---> PRON ---> pronoun
# around ---> ADP ---> adposition
# replacing ---> VERB ---> verb
# some ---> DET ---> determiner
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# incumbent ---> ADJ ---> adjective
# directors ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# we ---> PRON ---> pronoun
# were ---> AUX ---> auxiliary
# very ---> ADV ---> adverb
# intrigued ---> VERB ---> verb
# — ---> PUNCT ---> punctuation
# because ---> SCONJ ---> subordinating conjunction
# we ---> PRON ---> pronoun
# had ---> AUX ---> auxiliary
# tried ---> VERB ---> verb
# everything ---> PRON ---> pronoun
# else ---> ADV ---> adverb
# , ---> PUNCT ---> punctuation
# " ---> PUNCT ---> punctuation
# says ---> VERB ---> verb
# Aeisha ---> PROPN ---> proper noun
# Mastagni ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# a ---> DET ---> determiner
# portfolio ---> NOUN ---> noun
# manager ---> NOUN ---> noun
# with ---> ADP ---> adposition
# CalSTRS ---> NOUN ---> noun
# ' ---> PART ---> particle
# sustainable ---> ADJ ---> adjective
# investment ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# stewardship ---> NOUN ---> noun
# strategies ---> NOUN ---> noun
# unit ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# influential ---> ADJ ---> adjective
# proxy ---> NOUN ---> noun
# advisory ---> ADJ ---> adjective
# firms ---> NOUN ---> noun
# ISS ---> PROPN ---> proper noun
# and ---> CCONJ ---> coordinating conjunction
# Glass ---> PROPN ---> proper noun
# Lewis ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# which ---> DET ---> determiner
# issue ---> VERB ---> verb
# recommendations ---> NOUN ---> noun
# on ---> ADP ---> adposition
# how ---> ADV ---> adverb
# investors ---> NOUN ---> noun
# should ---> AUX ---> auxiliary
# vote ---> VERB ---> verb
# in ---> ADP ---> adposition
# shareholder ---> NOUN ---> noun
# meetings ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# also ---> ADV ---> adverb
# partially ---> ADV ---> adverb
# endorsed ---> VERB ---> verb
# Engine ---> PROPN ---> proper noun
# No ---> NOUN ---> noun
# . ---> NOUN ---> noun
# 1 ---> NUM ---> numeral
# 's ---> PART ---> particle
# nominations ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Their ---> PRON ---> pronoun
# reports ---> NOUN ---> noun
# provide ---> VERB ---> verb
# a ---> DET ---> determiner
# striking ---> ADJ ---> adjective
# glimpse ---> NOUN ---> noun
# into ---> ADP ---> adposition
# how ---> ADV ---> adverb
# arguments ---> NOUN ---> noun
# that ---> DET ---> determiner
# were ---> AUX ---> auxiliary
# initially ---> ADV ---> adverb
# made ---> VERB ---> verb
# by ---> ADP ---> adposition
# climate ---> NOUN ---> noun
# activists ---> NOUN ---> noun
# are ---> AUX ---> auxiliary
# becoming ---> VERB ---> verb
# increasingly ---> ADV ---> adverb
# mainstream ---> ADJ ---> adjective
# in ---> ADP ---> adposition
# the ---> DET ---> determiner
# investor ---> NOUN ---> noun
# community ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Both ---> DET ---> determiner
# firms ---> NOUN ---> noun
# used ---> VERB ---> verb
# the ---> DET ---> determiner
# word ---> NOUN ---> noun
# " ---> PUNCT ---> punctuation
# inevitable ---> ADJ ---> adjective
# " ---> PUNCT ---> punctuation
# to ---> PART ---> particle
# describe ---> VERB ---> verb
# the ---> DET ---> determiner
# energy ---> NOUN ---> noun
# transition ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# or ---> CCONJ ---> coordinating conjunction
# the ---> DET ---> determiner
# world ---> NOUN ---> noun
# 's ---> PART ---> particle
# shift ---> NOUN ---> noun
# away ---> ADV ---> adverb
# from ---> ADP ---> adposition
# relying ---> VERB ---> verb
# on ---> ADP ---> adposition
# fossil ---> ADJ ---> adjective
# fuels ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# and ---> CCONJ ---> coordinating conjunction
# agreed ---> VERB ---> verb
# that ---> SCONJ ---> subordinating conjunction
# Exxon ---> PROPN ---> proper noun
# has ---> AUX ---> auxiliary
# inadequately ---> ADV ---> adverb
# prepared ---> VERB ---> verb
# for ---> ADP ---> adposition
# this ---> DET ---> determiner
# future ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Heading ---> VERB ---> verb
# into ---> ADP ---> adposition
# Wednesday ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# meeting ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# all ---> DET ---> determiner
# eyes ---> NOUN ---> noun
# were ---> AUX ---> auxiliary
# on ---> ADP ---> adposition
# the ---> DET ---> determiner
# three ---> NUM ---> numeral
# companies ---> NOUN ---> noun
# with ---> ADP ---> adposition
# the ---> DET ---> determiner
# biggest ---> ADJ ---> adjective
# sway ---> NOUN ---> noun
# in ---> ADP ---> adposition
# this ---> DET ---> determiner
# vote ---> NOUN ---> noun
# : ---> PUNCT ---> punctuation
# Blackrock ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# Vanguard ---> PROPN ---> proper noun
# and ---> CCONJ ---> coordinating conjunction
# State ---> PROPN ---> proper noun
# Street ---> PROPN ---> proper noun
# Global ---> PROPN ---> proper noun
# Advisors ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# Those ---> DET ---> determiner
# companies ---> NOUN ---> noun
# manage ---> VERB ---> verb
# huge ---> ADJ ---> adjective
# funds ---> NOUN ---> noun
# — ---> PUNCT ---> punctuation
# including ---> VERB ---> verb
# many ---> ADJ ---> adjective
# people ---> NOUN ---> noun
# 's ---> PART ---> particle
# retirement ---> NOUN ---> noun
# accounts ---> NOUN ---> noun
# — ---> PUNCT ---> punctuation
# and ---> CCONJ ---> coordinating conjunction
# their ---> PRON ---> pronoun
# votes ---> NOUN ---> noun
# are ---> AUX ---> auxiliary
# weighted ---> VERB ---> verb
# accordingly ---> ADV ---> adverb
# , ---> PUNCT ---> punctuation
# giving ---> VERB ---> verb
# them ---> PRON ---> pronoun
# tremendous ---> ADJ ---> adjective
# power ---> NOUN ---> noun
# in ---> ADP ---> adposition
# these ---> DET ---> determiner
# kinds ---> NOUN ---> noun
# of ---> ADP ---> adposition
# proxy ---> NOUN ---> noun
# votes ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# All ---> DET ---> determiner
# three ---> NUM ---> numeral
# have ---> AUX ---> auxiliary
# pledged ---> VERB ---> verb
# support ---> NOUN ---> noun
# for ---> ADP ---> adposition
# investor ---> NOUN ---> noun
# initiatives ---> NOUN ---> noun
# focused ---> VERB ---> verb
# on ---> ADP ---> adposition
# fighting ---> VERB ---> verb
# climate ---> NOUN ---> noun
# change ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation

# %% [markdown]
# ### Dependency Parsing

# %%
for token in doc:
    print(token.text, '--->', token.dep_, '--->', spacy.explain(token.dep_))
# Out:
# Pictured ---> nsubj ---> nominal subject
# are ---> ROOT ---> None
# pumps ---> attr ---> attribute
# at ---> prep ---> prepositional modifier
# an ---> det ---> determiner
# Exxon ---> compound ---> compound
# gas ---> compound ---> compound
# station ---> pobj ---> object of preposition
# in ---> prep ---> prepositional modifier
# Charlotte ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# N.C. ---> punct ---> punctuation
# A ---> det ---> determiner
# tiny ---> amod ---> adjectival modifier
# fund ---> nsubj ---> nominal subject
# got ---> ROOT ---> None
# two ---> nummod ---> numeric modifier
# board ---> compound ---> compound
# members ---> dobj ---> direct object
# elected ---> acl ---> clausal modifier of noun (adjectival clause)
# to ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# oil ---> compound ---> compound
# giant ---> poss ---> possession modifier
# 's ---> case ---> case marking
# board ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# delivering ---> advcl ---> adverbial clause modifier
# a ---> det ---> determiner
# historic ---> amod ---> adjectival modifier
# defeat ---> dobj ---> direct object
# to ---> prep ---> prepositional modifier
# ExxonMobil ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# In ---> prep ---> prepositional modifier
# a ---> det ---> determiner
# dramatic ---> amod ---> adjectival modifier
# boardroom ---> compound ---> compound
# battle ---> pobj ---> object of preposition
# on ---> prep ---> prepositional modifier
# Wednesday ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# a ---> det ---> determiner
# tiny ---> amod ---> adjectival modifier
# hedge ---> compound ---> compound
# fund ---> nsubj ---> nominal subject
# fought ---> acl ---> clausal modifier of noun (adjectival clause)
# with ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# energy ---> compound ---> compound
# giant ---> pobj ---> object of preposition
# ExxonMobil ---> appos ---> appositional modifier
# over ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# future ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# oil ---> nmod ---> modifier of nominal
# and ---> cc ---> coordinating conjunction
# gas ---> conj ---> conjunct
# industry ---> pobj ---> object of preposition
# — ---> punct ---> punctuation
# and ---> cc ---> coordinating conjunction
# won ---> ROOT ---> None
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# brand ---> npadvmod ---> noun phrase as adverbial modifier
# - ---> punct ---> punctuation
# new ---> amod ---> adjectival modifier
# activist ---> amod ---> adjectival modifier
# hedge ---> compound ---> compound
# fund ---> ROOT ---> None
# successfully ---> advmod ---> adverbial modifier
# placed ---> acl ---> clausal modifier of noun (adjectival clause)
# at ---> advmod ---> adverbial modifier
# least ---> advmod ---> adverbial modifier
# two ---> nummod ---> numeric modifier
# new ---> amod ---> adjectival modifier
# candidates ---> dobj ---> direct object
# on ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# company ---> poss ---> possession modifier
# 's ---> case ---> case marking
# board ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# directors ---> pobj ---> object of preposition
# in ---> prep ---> prepositional modifier
# hopes ---> pobj ---> object of preposition
# that ---> mark ---> marker
# they ---> nsubj ---> nominal subject
# can ---> aux ---> auxiliary
# use ---> acl ---> clausal modifier of noun (adjectival clause)
# that ---> det ---> determiner
# position ---> dobj ---> direct object
# to ---> aux ---> auxiliary
# push ---> xcomp ---> open clausal complement
# Exxon ---> dobj ---> direct object
# to ---> aux ---> auxiliary
# take ---> advcl ---> adverbial clause modifier
# climate ---> compound ---> compound
# change ---> dobj ---> direct object
# more ---> advmod ---> adverbial modifier
# seriously ---> advmod ---> adverbial modifier
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# For ---> prep ---> prepositional modifier
# two ---> nummod ---> numeric modifier
# more ---> amod ---> adjectival modifier
# seats ---> pobj ---> object of preposition
# on ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# board ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# the ---> det ---> determiner
# vote ---> nsubj ---> nominal subject
# was ---> ROOT ---> None
# too ---> advmod ---> adverbial modifier
# close ---> acomp ---> adjectival complement
# to ---> aux ---> auxiliary
# call ---> xcomp ---> open clausal complement
# . ---> punct ---> punctuation
# Winning ---> csubj ---> clausal subject
# a ---> det ---> determiner
# seat ---> dobj ---> direct object
# for ---> prep ---> prepositional modifier
# any ---> det ---> determiner
# directors ---> pobj ---> object of preposition
# at ---> advmod ---> adverbial modifier
# all ---> advmod ---> adverbial modifier
# is ---> ROOT ---> None
# an ---> det ---> determiner
# unprecedented ---> amod ---> adjectival modifier
# achievement ---> attr ---> attribute
# by ---> prep ---> prepositional modifier
# activist ---> amod ---> adjectival modifier
# shareholders ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# who ---> nsubj ---> nominal subject
# have ---> aux ---> auxiliary
# spent ---> relcl ---> relative clause modifier
# decades ---> dobj ---> direct object
# trying ---> xcomp ---> open clausal complement
# to ---> aux ---> auxiliary
# persuade ---> xcomp ---> open clausal complement
# companies ---> dobj ---> direct object
# to ---> aux ---> auxiliary
# cut ---> xcomp ---> open clausal complement
# their ---> poss ---> possession modifier
# carbon ---> compound ---> compound
# emissions ---> dobj ---> direct object
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# To ---> aux ---> auxiliary
# do ---> advcl ---> adverbial clause modifier
# it ---> dobj ---> direct object
# at ---> prep ---> prepositional modifier
# ExxonMobil ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# once ---> advmod ---> adverbial modifier
# the ---> det ---> determiner
# world ---> poss ---> possession modifier
# 's ---> case ---> case marking
# most ---> advmod ---> adverbial modifier
# influential ---> amod ---> adjectival modifier
# oil ---> compound ---> compound
# company ---> dobj ---> direct object
# , ---> punct ---> punctuation
# makes ---> ROOT ---> None
# the ---> det ---> determiner
# feat ---> nsubj ---> nominal subject
# all ---> advmod ---> adverbial modifier
# the ---> advmod ---> adverbial modifier
# more ---> advmod ---> adverbial modifier
# astonishing ---> ccomp ---> clausal complement
# . ---> punct ---> punctuation
# And ---> cc ---> coordinating conjunction
# it ---> nsubj ---> nominal subject
# demonstrates ---> ROOT ---> None
# how ---> advmod ---> adverbial modifier
# arguments ---> nsubj ---> nominal subject
# about ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# financial ---> amod ---> adjectival modifier
# implications ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# climate ---> compound ---> compound
# change ---> pobj ---> object of preposition
# — ---> punct ---> punctuation
# specifically ---> advmod ---> adverbial modifier
# , ---> punct ---> punctuation
# the ---> det ---> determiner
# possibility ---> nsubj ---> nominal subject
# that ---> mark ---> marker
# the ---> det ---> determiner
# world ---> nsubj ---> nominal subject
# will ---> aux ---> auxiliary
# stop ---> acl ---> clausal modifier of noun (adjectival clause)
# using ---> xcomp ---> open clausal complement
# oil ---> dobj ---> direct object
# and ---> cc ---> coordinating conjunction
# gas ---> conj ---> conjunct
# and ---> cc ---> coordinating conjunction
# investments ---> conj ---> conjunct
# in ---> prep ---> prepositional modifier
# fossil ---> amod ---> adjectival modifier
# fuels ---> pobj ---> object of preposition
# will ---> aux ---> auxiliary
# not ---> neg ---> negation modifier
# pay ---> ccomp ---> clausal complement
# off ---> prt ---> particle
# — ---> punct ---> punctuation
# have ---> aux ---> auxiliary
# moved ---> conj ---> conjunct
# firmly ---> advmod ---> adverbial modifier
# to ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# center ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# mainstream ---> amod ---> adjectival modifier
# investor ---> compound ---> compound
# thinking ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# Public ---> amod ---> adjectival modifier
# companies ---> nsubj ---> nominal subject
# have ---> ROOT ---> None
# a ---> det ---> determiner
# board ---> dobj ---> direct object
# of ---> prep ---> prepositional modifier
# directors ---> pobj ---> object of preposition
# that ---> nsubj ---> nominal subject
# 's ---> relcl ---> relative clause modifier
# responsible ---> acomp ---> adjectival complement
# for ---> prep ---> prepositional modifier
# oversight ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# CEO ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# overall ---> amod ---> adjectival modifier
# corporate ---> amod ---> adjectival modifier
# strategy ---> conj ---> conjunct
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# The ---> det ---> determiner
# members ---> nsubjpass ---> nominal subject (passive)
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# board ---> pobj ---> object of preposition
# are ---> auxpass ---> auxiliary (passive)
# technically ---> advmod ---> adverbial modifier
# elected ---> ROOT ---> None
# by ---> agent ---> agent
# shareholders ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# but ---> cc ---> coordinating conjunction
# normally ---> advmod ---> adverbial modifier
# those ---> det ---> determiner
# elections ---> nsubj ---> nominal subject
# are ---> conj ---> conjunct
# uncontested ---> acomp ---> adjectival complement
# and ---> cc ---> coordinating conjunction
# voting ---> nsubj ---> nominal subject
# is ---> conj ---> conjunct
# just ---> advmod ---> adverbial modifier
# a ---> det ---> determiner
# formality ---> attr ---> attribute
# . ---> punct ---> punctuation
# Sometimes ---> advmod ---> adverbial modifier
# , ---> punct ---> punctuation
# though ---> advmod ---> adverbial modifier
# , ---> punct ---> punctuation
# unhappy ---> amod ---> adjectival modifier
# investors ---> nsubj ---> nominal subject
# decide ---> ROOT ---> None
# to ---> aux ---> auxiliary
# make ---> xcomp ---> open clausal complement
# it ---> nsubj ---> nominal subject
# a ---> det ---> determiner
# real ---> amod ---> adjectival modifier
# race ---> ccomp ---> clausal complement
# by ---> prep ---> prepositional modifier
# putting ---> pcomp ---> complement of preposition
# forward ---> prt ---> particle
# rival ---> amod ---> adjectival modifier
# candidates ---> dobj ---> direct object
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# That ---> nsubj ---> nominal subject
# 's ---> ROOT ---> None
# exactly ---> advmod ---> adverbial modifier
# what ---> nsubj ---> nominal subject
# happened ---> ccomp ---> clausal complement
# at ---> prep ---> prepositional modifier
# Exxon ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# A ---> det ---> determiner
# hedge ---> compound ---> compound
# fund ---> nsubjpass ---> nominal subject (passive)
# called ---> acl ---> clausal modifier of noun (adjectival clause)
# Engine ---> oprd ---> object predicate
# No ---> oprd ---> object predicate
# . ---> oprd ---> object predicate
# 1 ---> nsubjpass ---> nominal subject (passive)
# was ---> auxpass ---> auxiliary (passive)
# formed ---> ROOT ---> None
# just ---> advmod ---> adverbial modifier
# last ---> amod ---> adjectival modifier
# year ---> npadvmod ---> noun phrase as adverbial modifier
# with ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# express ---> amod ---> adjectival modifier
# purpose ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# challenging ---> pcomp ---> complement of preposition
# Exxon ---> poss ---> possession modifier
# 's ---> case ---> case marking
# corporate ---> amod ---> adjectival modifier
# strategy ---> dobj ---> direct object
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# company ---> nsubj ---> nominal subject
# and ---> cc ---> coordinating conjunction
# the ---> det ---> determiner
# upstart ---> amod ---> adjectival modifier
# fund ---> conj ---> conjunct
# have ---> aux ---> auxiliary
# been ---> aux ---> auxiliary
# vying ---> ROOT ---> None
# for ---> prep ---> prepositional modifier
# shareholders ---> poss ---> possession modifier
# ' ---> case ---> case marking
# votes ---> pobj ---> object of preposition
# through ---> prep ---> prepositional modifier
# slideshows ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# letters ---> conj ---> conjunct
# and ---> cc ---> coordinating conjunction
# public ---> amod ---> adjectival modifier
# statements ---> conj ---> conjunct
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# fund ---> nsubj ---> nominal subject
# pointed ---> ROOT ---> None
# to ---> prep ---> prepositional modifier
# Exxon ---> poss ---> possession modifier
# 's ---> case ---> case marking
# poor ---> amod ---> adjectival modifier
# performance ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# relative ---> advmod ---> adverbial modifier
# to ---> prep ---> prepositional modifier
# its ---> poss ---> possession modifier
# peers ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# during ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# years ---> pobj ---> object of preposition
# leading ---> acl ---> clausal modifier of noun (adjectival clause)
# up ---> prep ---> prepositional modifier
# to ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# pandemic ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
#
#  ---> punct ---> punctuation
# It ---> nsubj ---> nominal subject
# also ---> advmod ---> adverbial modifier
# forcefully ---> advmod ---> adverbial modifier
# argued ---> ROOT ---> None
# that ---> mark ---> marker
# the ---> det ---> determiner
# company ---> nsubj ---> nominal subject
# has ---> aux ---> auxiliary
# not ---> neg ---> negation modifier
# laid ---> ccomp ---> clausal complement
# out ---> prt ---> particle
# a ---> det ---> determiner
# viable ---> amod ---> adjectival modifier
# plan ---> dobj ---> direct object
# to ---> aux ---> auxiliary
# be ---> acl ---> clausal modifier of noun (adjectival clause)
# profitable ---> acomp ---> adjectival complement
# if ---> mark ---> marker
# the ---> det ---> determiner
# world ---> nsubj ---> nominal subject
# makes ---> advcl ---> adverbial clause modifier
# a ---> det ---> determiner
# rapid ---> amod ---> adjectival modifier
# transition ---> dobj ---> direct object
# away ---> advmod ---> adverbial modifier
# from ---> prep ---> prepositional modifier
# oil ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# gas ---> conj ---> conjunct
# to ---> aux ---> auxiliary
# ward ---> relcl ---> relative clause modifier
# off ---> prt ---> particle
# the ---> det ---> determiner
# worst ---> amod ---> adjectival modifier
# effects ---> dobj ---> direct object
# of ---> prep ---> prepositional modifier
# climate ---> compound ---> compound
# change ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# Large ---> amod ---> adjectival modifier
# European ---> amod ---> adjectival modifier
# oil ---> nmod ---> modifier of nominal
# and ---> cc ---> coordinating conjunction
# gas ---> conj ---> conjunct
# companies ---> nsubj ---> nominal subject
# are ---> aux ---> auxiliary
# investing ---> ROOT ---> None
# in ---> prep ---> prepositional modifier
# renewable ---> amod ---> adjectival modifier
# energy ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# pledging ---> conj ---> conjunct
# to ---> aux ---> auxiliary
# slash ---> advcl ---> adverbial clause modifier
# their ---> poss ---> possession modifier
# emissions ---> dobj ---> direct object
# to ---> prep ---> prepositional modifier
# zero ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# but ---> cc ---> coordinating conjunction
# Exxon ---> nsubj ---> nominal subject
# has ---> aux ---> auxiliary
# consistently ---> advmod ---> adverbial modifier
# rejected ---> conj ---> conjunct
# that ---> det ---> determiner
# strategy ---> dobj ---> direct object
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# The ---> det ---> determiner
# company ---> nsubj ---> nominal subject
# says ---> ROOT ---> None
# its ---> poss ---> possession modifier
# core ---> compound ---> compound
# strengths ---> nsubj ---> nominal subject
# are ---> ccomp ---> clausal complement
# in ---> prep ---> prepositional modifier
# oil ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# gas ---> conj ---> conjunct
# , ---> punct ---> punctuation
# and ---> cc ---> coordinating conjunction
# it ---> nsubj ---> nominal subject
# argues ---> conj ---> conjunct
# that ---> mark ---> marker
# the ---> det ---> determiner
# world ---> nsubj ---> nominal subject
# simply ---> advmod ---> adverbial modifier
# will ---> aux ---> auxiliary
# not ---> neg ---> negation modifier
# pivot ---> ccomp ---> clausal complement
# away ---> advmod ---> adverbial modifier
# from ---> prep ---> prepositional modifier
# those ---> det ---> determiner
# energy ---> compound ---> compound
# sources ---> pobj ---> object of preposition
# very ---> advmod ---> adverbial modifier
# quickly ---> advmod ---> adverbial modifier
# . ---> punct ---> punctuation
# Instead ---> advmod ---> adverbial modifier
# of ---> prep ---> prepositional modifier
# branching ---> pcomp ---> complement of preposition
# into ---> prep ---> prepositional modifier
# new ---> amod ---> adjectival modifier
# industries ---> pobj ---> object of preposition
# where ---> advmod ---> adverbial modifier
# it ---> nsubj ---> nominal subject
# does ---> aux ---> auxiliary
# n't ---> neg ---> negation modifier
# have ---> relcl ---> relative clause modifier
# a ---> det ---> determiner
# competitive ---> amod ---> adjectival modifier
# advantage ---> dobj ---> direct object
# , ---> punct ---> punctuation
# it ---> nsubj ---> nominal subject
# argues ---> ROOT ---> None
# that ---> mark ---> marker
# it ---> nsubj ---> nominal subject
# can ---> aux ---> auxiliary
# invest ---> ccomp ---> clausal complement
# in ---> prep ---> prepositional modifier
# carbon ---> compound ---> compound
# capture ---> compound ---> compound
# technology ---> pobj ---> object of preposition
# — ---> punct ---> punctuation
# capturing ---> advcl ---> adverbial clause modifier
# greenhouse ---> compound ---> compound
# gases ---> dobj ---> direct object
# in ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# atmosphere ---> pobj ---> object of preposition
# — ---> punct ---> punctuation
# and ---> cc ---> coordinating conjunction
# continue ---> conj ---> conjunct
# to ---> aux ---> auxiliary
# make ---> xcomp ---> open clausal complement
# money ---> dobj ---> direct object
# off ---> prep ---> prepositional modifier
# oil ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# gas ---> conj ---> conjunct
# in ---> prep ---> prepositional modifier
# a ---> det ---> determiner
# " ---> punct ---> punctuation
# lower ---> amod ---> adjectival modifier
# - ---> punct ---> punctuation
# carbon ---> nmod ---> modifier of nominal
# " ---> punct ---> punctuation
# future ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# This ---> det ---> determiner
# vision ---> nsubj ---> nominal subject
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# future ---> pobj ---> object of preposition
# is ---> ROOT ---> None
# increasingly ---> advmod ---> adverbial modifier
# at ---> prep ---> prepositional modifier
# odds ---> pobj ---> object of preposition
# with ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# goals ---> pobj ---> object of preposition
# espoused ---> acl ---> clausal modifier of noun (adjectival clause)
# by ---> agent ---> agent
# world ---> compound ---> compound
# governments ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# the ---> det ---> determiner
# pathways ---> conj ---> conjunct
# laid ---> acl ---> clausal modifier of noun (adjectival clause)
# out ---> prt ---> particle
# by ---> agent ---> agent
# organizations ---> pobj ---> object of preposition
# like ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# International ---> compound ---> compound
# Energy ---> compound ---> compound
# Agency ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# Exxon ---> nsubj ---> nominal subject
# regards ---> ROOT ---> None
# those ---> det ---> determiner
# goals ---> dobj ---> direct object
# and ---> cc ---> coordinating conjunction
# pathways ---> conj ---> conjunct
# as ---> prep ---> prepositional modifier
# unrealistic ---> amod ---> adjectival modifier
# , ---> punct ---> punctuation
# skeptically ---> advmod ---> adverbial modifier
# noting ---> advcl ---> adverbial clause modifier
# that ---> mark ---> marker
# some ---> det ---> determiner
# plans ---> nsubj ---> nominal subject
# for ---> prep ---> prepositional modifier
# fighting ---> pcomp ---> complement of preposition
# climate ---> compound ---> compound
# change ---> dobj ---> direct object
# would ---> aux ---> auxiliary
# require ---> ccomp ---> clausal complement
# people ---> dobj ---> direct object
# to ---> aux ---> auxiliary
# immediately ---> advmod ---> adverbial modifier
# adjust ---> xcomp ---> open clausal complement
# their ---> poss ---> possession modifier
# home ---> compound ---> compound
# thermostats ---> dobj ---> direct object
# and ---> cc ---> coordinating conjunction
# take ---> conj ---> conjunct
# significantly ---> advmod ---> adverbial modifier
# fewer ---> amod ---> adjectival modifier
# flights ---> dobj ---> direct object
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# Those ---> nsubj ---> nominal subject
# are ---> ROOT ---> None
# behavioral ---> amod ---> adjectival modifier
# changes ---> attr ---> attribute
# the ---> det ---> determiner
# company ---> nsubj ---> nominal subject
# does ---> aux ---> auxiliary
# not ---> neg ---> negation modifier
# believe ---> relcl ---> relative clause modifier
# likely ---> oprd ---> object predicate
# enough ---> advmod ---> adverbial modifier
# to ---> aux ---> auxiliary
# factor ---> xcomp ---> open clausal complement
# in ---> prt ---> particle
# to ---> prep ---> prepositional modifier
# its ---> poss ---> possession modifier
# business ---> compound ---> compound
# planning ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# vote ---> nsubj ---> nominal subject
# to ---> aux ---> auxiliary
# defy ---> acl ---> clausal modifier of noun (adjectival clause)
# management ---> dobj ---> direct object
# and ---> cc ---> coordinating conjunction
# add ---> conj ---> conjunct
# two ---> nummod ---> numeric modifier
# dissident ---> amod ---> adjectival modifier
# members ---> dobj ---> direct object
# to ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# board ---> pobj ---> object of preposition
# represents ---> ROOT ---> None
# a ---> det ---> determiner
# repudiation ---> dobj ---> direct object
# of ---> prep ---> prepositional modifier
# that ---> det ---> determiner
# philosophy ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# Engine ---> nmod ---> modifier of nominal
# No ---> nsubj ---> nominal subject
# . ---> appos ---> appositional modifier
# 1 ---> nummod ---> numeric modifier
# holds ---> ROOT ---> None
# a ---> det ---> determiner
# tiny ---> amod ---> adjectival modifier
# fraction ---> dobj ---> direct object
# of ---> prep ---> prepositional modifier
# Exxon ---> compound ---> compound
# shares ---> pobj ---> object of preposition
# — ---> punct ---> punctuation
# just ---> advmod ---> adverbial modifier
# 0.02 ---> nummod ---> numeric modifier
# % ---> appos ---> appositional modifier
# , ---> punct ---> punctuation
# according ---> prep ---> prepositional modifier
# to ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# proxy ---> amod ---> adjectival modifier
# advisory ---> amod ---> adjectival modifier
# firm ---> pobj ---> object of preposition
# ISS ---> appos ---> appositional modifier
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# By ---> prep ---> prepositional modifier
# itself ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# it ---> nsubj ---> nominal subject
# had ---> ROOT ---> None
# no ---> det ---> determiner
# chance ---> dobj ---> direct object
# to ---> aux ---> auxiliary
# sway ---> acl ---> clausal modifier of noun (adjectival clause)
# the ---> det ---> determiner
# company ---> dobj ---> direct object
# . ---> punct ---> punctuation
# But ---> cc ---> coordinating conjunction
# it ---> nsubj ---> nominal subject
# spent ---> ROOT ---> None
# months ---> dobj ---> direct object
# building ---> xcomp ---> open clausal complement
# support ---> dobj ---> direct object
# for ---> prep ---> prepositional modifier
# its ---> poss ---> possession modifier
# case ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
#
#  ---> punct ---> punctuation
# CalSTRS ---> nsubj ---> nominal subject
# , ---> punct ---> punctuation
# the ---> det ---> determiner
# California ---> compound ---> compound
# teachers ---> compound ---> compound
# pension ---> appos ---> appositional modifier
# , ---> punct ---> punctuation
# was ---> ROOT ---> None
# an ---> det ---> determiner
# early ---> amod ---> adjectival modifier
# backer ---> attr ---> attribute
# , ---> punct ---> punctuation
# citing ---> advcl ---> adverbial clause modifier
# frustration ---> dobj ---> direct object
# with ---> prep ---> prepositional modifier
# Exxon ---> poss ---> possession modifier
# 's ---> case ---> case marking
# lack ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# response ---> pobj ---> object of preposition
# to ---> prep ---> prepositional modifier
# previous ---> amod ---> adjectival modifier
# shareholder ---> compound ---> compound
# proposals ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# direct ---> amod ---> adjectival modifier
# appeals ---> conj ---> conjunct
# from ---> prep ---> prepositional modifier
# investors ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# "When ---> nmod ---> modifier of nominal
# Engine ---> compound ---> compound
# No ---> nsubj ---> nominal subject
# . ---> appos ---> appositional modifier
# 1 ---> nummod ---> numeric modifier
# brought ---> advcl ---> adverbial clause modifier
# this ---> det ---> determiner
# idea ---> dobj ---> direct object
# to ---> dative ---> dative
# us ---> pobj ---> object of preposition
# around ---> prep ---> prepositional modifier
# replacing ---> pcomp ---> complement of preposition
# some ---> dobj ---> direct object
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# incumbent ---> amod ---> adjectival modifier
# directors ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# we ---> nsubjpass ---> nominal subject (passive)
# were ---> auxpass ---> auxiliary (passive)
# very ---> advmod ---> adverbial modifier
# intrigued ---> ccomp ---> clausal complement
# — ---> punct ---> punctuation
# because ---> mark ---> marker
# we ---> nsubj ---> nominal subject
# had ---> aux ---> auxiliary
# tried ---> advcl ---> adverbial clause modifier
# everything ---> dobj ---> direct object
# else ---> advmod ---> adverbial modifier
# , ---> punct ---> punctuation
# " ---> punct ---> punctuation
# says ---> ROOT ---> None
# Aeisha ---> compound ---> compound
# Mastagni ---> nsubj ---> nominal subject
# , ---> punct ---> punctuation
# a ---> det ---> determiner
# portfolio ---> compound ---> compound
# manager ---> appos ---> appositional modifier
# with ---> prep ---> prepositional modifier
# CalSTRS ---> poss ---> possession modifier
# ' ---> case ---> case marking
# sustainable ---> amod ---> adjectival modifier
# investment ---> nmod ---> modifier of nominal
# and ---> cc ---> coordinating conjunction
# stewardship ---> compound ---> compound
# strategies ---> conj ---> conjunct
# unit ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# influential ---> amod ---> adjectival modifier
# proxy ---> amod ---> adjectival modifier
# advisory ---> amod ---> adjectival modifier
# firms ---> nsubj ---> nominal subject
# ISS ---> appos ---> appositional modifier
# and ---> cc ---> coordinating conjunction
# Glass ---> compound ---> compound
# Lewis ---> conj ---> conjunct
# , ---> punct ---> punctuation
# which ---> nsubj ---> nominal subject
# issue ---> relcl ---> relative clause modifier
# recommendations ---> dobj ---> direct object
# on ---> prep ---> prepositional modifier
# how ---> advmod ---> adverbial modifier
# investors ---> nsubj ---> nominal subject
# should ---> aux ---> auxiliary
# vote ---> pcomp ---> complement of preposition
# in ---> prep ---> prepositional modifier
# shareholder ---> compound ---> compound
# meetings ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# also ---> advmod ---> adverbial modifier
# partially ---> advmod ---> adverbial modifier
# endorsed ---> ROOT ---> None
# Engine ---> compound ---> compound
# No ---> dobj ---> direct object
# . ---> npadvmod ---> noun phrase as adverbial modifier
# 1 ---> poss ---> possession modifier
# 's ---> case ---> case marking
# nominations ---> dobj ---> direct object
# . ---> punct ---> punctuation
# Their ---> poss ---> possession modifier
# reports ---> nsubj ---> nominal subject
# provide ---> ROOT ---> None
# a ---> det ---> determiner
# striking ---> amod ---> adjectival modifier
# glimpse ---> dobj ---> direct object
# into ---> prep ---> prepositional modifier
# how ---> advmod ---> adverbial modifier
# arguments ---> nsubj ---> nominal subject
# that ---> nsubjpass ---> nominal subject (passive)
# were ---> auxpass ---> auxiliary (passive)
# initially ---> advmod ---> adverbial modifier
# made ---> relcl ---> relative clause modifier
# by ---> agent ---> agent
# climate ---> compound ---> compound
# activists ---> pobj ---> object of preposition
# are ---> aux ---> auxiliary
# becoming ---> pcomp ---> complement of preposition
# increasingly ---> advmod ---> adverbial modifier
# mainstream ---> acomp ---> adjectival complement
# in ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# investor ---> compound ---> compound
# community ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# Both ---> det ---> determiner
# firms ---> nsubj ---> nominal subject
# used ---> ROOT ---> None
# the ---> det ---> determiner
# word ---> dobj ---> direct object
# " ---> punct ---> punctuation
# inevitable ---> oprd ---> object predicate
# " ---> punct ---> punctuation
# to ---> aux ---> auxiliary
# describe ---> xcomp ---> open clausal complement
# the ---> det ---> determiner
# energy ---> compound ---> compound
# transition ---> dobj ---> direct object
# , ---> punct ---> punctuation
# or ---> cc ---> coordinating conjunction
# the ---> det ---> determiner
# world ---> poss ---> possession modifier
# 's ---> case ---> case marking
# shift ---> conj ---> conjunct
# away ---> advmod ---> adverbial modifier
# from ---> prep ---> prepositional modifier
# relying ---> pcomp ---> complement of preposition
# on ---> prep ---> prepositional modifier
# fossil ---> compound ---> compound
# fuels ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# and ---> cc ---> coordinating conjunction
# agreed ---> conj ---> conjunct
# that ---> mark ---> marker
# Exxon ---> nsubj ---> nominal subject
# has ---> aux ---> auxiliary
# inadequately ---> advmod ---> adverbial modifier
# prepared ---> ccomp ---> clausal complement
# for ---> prep ---> prepositional modifier
# this ---> det ---> determiner
# future ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# Heading ---> advcl ---> adverbial clause modifier
# into ---> prep ---> prepositional modifier
# Wednesday ---> poss ---> possession modifier
# 's ---> case ---> case marking
# meeting ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# all ---> det ---> determiner
# eyes ---> nsubj ---> nominal subject
# were ---> ROOT ---> None
# on ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# three ---> nummod ---> numeric modifier
# companies ---> pobj ---> object of preposition
# with ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# biggest ---> amod ---> adjectival modifier
# sway ---> pobj ---> object of preposition
# in ---> prep ---> prepositional modifier
# this ---> det ---> determiner
# vote ---> pobj ---> object of preposition
# : ---> punct ---> punctuation
# Blackrock ---> appos ---> appositional modifier
# , ---> punct ---> punctuation
# Vanguard ---> conj ---> conjunct
# and ---> cc ---> coordinating conjunction
# State ---> compound ---> compound
# Street ---> compound ---> compound
# Global ---> compound ---> compound
# Advisors ---> conj ---> conjunct
# . ---> punct ---> punctuation
# Those ---> det ---> determiner
# companies ---> nsubj ---> nominal subject
# manage ---> ROOT ---> None
# huge ---> amod ---> adjectival modifier
# funds ---> dobj ---> direct object
# — ---> punct ---> punctuation
# including ---> prep ---> prepositional modifier
# many ---> amod ---> adjectival modifier
# people ---> poss ---> possession modifier
# 's ---> case ---> case marking
# retirement ---> compound ---> compound
# accounts ---> pobj ---> object of preposition
# — ---> punct ---> punctuation
# and ---> cc ---> coordinating conjunction
# their ---> poss ---> possession modifier
# votes ---> nsubjpass ---> nominal subject (passive)
# are ---> auxpass ---> auxiliary (passive)
# weighted ---> conj ---> conjunct
# accordingly ---> advmod ---> adverbial modifier
# , ---> punct ---> punctuation
# giving ---> advcl ---> adverbial clause modifier
# them ---> dative ---> dative
# tremendous ---> amod ---> adjectival modifier
# power ---> dobj ---> direct object
# in ---> prep ---> prepositional modifier
# these ---> det ---> determiner
# kinds ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# proxy ---> compound ---> compound
# votes ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# All ---> det ---> determiner
# three ---> nsubj ---> nominal subject
# have ---> aux ---> auxiliary
# pledged ---> ROOT ---> None
# support ---> dobj ---> direct object
# for ---> prep ---> prepositional modifier
# investor ---> compound ---> compound
# initiatives ---> pobj ---> object of preposition
# focused ---> acl ---> clausal modifier of noun (adjectival clause)
# on ---> prep ---> prepositional modifier
# fighting ---> pcomp ---> complement of preposition
# climate ---> compound ---> compound
# change ---> dobj ---> direct object
# . ---> punct ---> punctuation

# %% [markdown]
# ### Lemmatization

# %%
for token in doc:
    print(token.text, '--->', token.lemma_, '--->', spacy.explain(token.lemma_))
# Out:
# Pictured ---> picture ---> None
# are ---> be ---> None
# pumps ---> pump ---> None
# at ---> at ---> None
# an ---> an ---> None
# Exxon ---> Exxon ---> None
# gas ---> gas ---> None
# station ---> station ---> None
# in ---> in ---> None
# Charlotte ---> Charlotte ---> None
# , ---> , ---> punctuation mark, comma
# N.C. ---> N.C. ---> None
# A ---> a ---> None
# tiny ---> tiny ---> None
# fund ---> fund ---> None
# got ---> get ---> None
# two ---> two ---> None
# board ---> board ---> None
# members ---> member ---> None
# elected ---> elect ---> None
# to ---> to ---> None
# the ---> the ---> None
# oil ---> oil ---> None
# giant ---> giant ---> None
# 's ---> 's ---> None
# board ---> board ---> None
# , ---> , ---> punctuation mark, comma
# delivering ---> deliver ---> None
# a ---> a ---> None
# historic ---> historic ---> None
# defeat ---> defeat ---> None
# to ---> to ---> None
# ExxonMobil ---> ExxonMobil ---> None
# . ---> . ---> punctuation mark, sentence closer
# In ---> in ---> None
# a ---> a ---> None
# dramatic ---> dramatic ---> None
# boardroom ---> boardroom ---> None
# battle ---> battle ---> None
# on ---> on ---> None
# Wednesday ---> Wednesday ---> None
# , ---> , ---> punctuation mark, comma
# a ---> a ---> None
# tiny ---> tiny ---> None
# hedge ---> hedge ---> None
# fund ---> fund ---> None
# fought ---> fight ---> None
# with ---> with ---> None
# the ---> the ---> None
# energy ---> energy ---> None
# giant ---> giant ---> None
# ExxonMobil ---> ExxonMobil ---> None
# over ---> over ---> None
# the ---> the ---> None
# future ---> future ---> None
# of ---> of ---> None
# the ---> the ---> None
# oil ---> oil ---> None
# and ---> and ---> None
# gas ---> gas ---> None
# industry ---> industry ---> None
# — ---> — ---> None
# and ---> and ---> None
# won ---> win ---> None
# . ---> . ---> punctuation mark, sentence closer
# The ---> the ---> None
# brand ---> brand ---> None
# - ---> - ---> None
# new ---> new ---> None
# activist ---> activist ---> None
# hedge ---> hedge ---> None
# fund ---> fund ---> None
# successfully ---> successfully ---> None
# placed ---> place ---> None
# at ---> at ---> None
# least ---> least ---> None
# two ---> two ---> None
# new ---> new ---> None
# candidates ---> candidate ---> None
# on ---> on ---> None
# the ---> the ---> None
# company ---> company ---> None
# 's ---> 's ---> None
# board ---> board ---> None
# of ---> of ---> None
# directors ---> director ---> None
# in ---> in ---> None
# hopes ---> hope ---> None
# that ---> that ---> None
# they ---> they ---> None
# can ---> can ---> None
# use ---> use ---> None
# that ---> that ---> None
# position ---> position ---> None
# to ---> to ---> None
# push ---> push ---> None
# Exxon ---> Exxon ---> None
# to ---> to ---> None
# take ---> take ---> None
# climate ---> climate ---> None
# change ---> change ---> None
# more ---> more ---> None
# seriously ---> seriously ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# For ---> for ---> None
# two ---> two ---> None
# more ---> more ---> None
# seats ---> seat ---> None
# on ---> on ---> None
# the ---> the ---> None
# board ---> board ---> None
# , ---> , ---> punctuation mark, comma
# the ---> the ---> None
# vote ---> vote ---> None
# was ---> be ---> None
# too ---> too ---> None
# close ---> close ---> None
# to ---> to ---> None
# call ---> call ---> None
# . ---> . ---> punctuation mark, sentence closer
# Winning ---> win ---> None
# a ---> a ---> None
# seat ---> seat ---> None
# for ---> for ---> None
# any ---> any ---> None
# directors ---> director ---> None
# at ---> at ---> None
# all ---> all ---> None
# is ---> be ---> None
# an ---> an ---> None
# unprecedented ---> unprecedented ---> None
# achievement ---> achievement ---> None
# by ---> by ---> None
# activist ---> activist ---> None
# shareholders ---> shareholder ---> None
# , ---> , ---> punctuation mark, comma
# who ---> who ---> None
# have ---> have ---> None
# spent ---> spend ---> None
# decades ---> decade ---> None
# trying ---> try ---> None
# to ---> to ---> None
# persuade ---> persuade ---> None
# companies ---> company ---> None
# to ---> to ---> None
# cut ---> cut ---> None
# their ---> their ---> None
# carbon ---> carbon ---> None
# emissions ---> emission ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# To ---> to ---> None
# do ---> do ---> None
# it ---> it ---> None
# at ---> at ---> None
# ExxonMobil ---> ExxonMobil ---> None
# , ---> , ---> punctuation mark, comma
# once ---> once ---> None
# the ---> the ---> None
# world ---> world ---> None
# 's ---> 's ---> None
# most ---> most ---> None
# influential ---> influential ---> None
# oil ---> oil ---> None
# company ---> company ---> None
# , ---> , ---> punctuation mark, comma
# makes ---> make ---> None
# the ---> the ---> None
# feat ---> feat ---> None
# all ---> all ---> None
# the ---> the ---> None
# more ---> more ---> None
# astonishing ---> astonishing ---> None
# . ---> . ---> punctuation mark, sentence closer
# And ---> and ---> None
# it ---> it ---> None
# demonstrates ---> demonstrate ---> None
# how ---> how ---> None
# arguments ---> argument ---> None
# about ---> about ---> None
# the ---> the ---> None
# financial ---> financial ---> None
# implications ---> implication ---> None
# of ---> of ---> None
# climate ---> climate ---> None
# change ---> change ---> None
# — ---> — ---> None
# specifically ---> specifically ---> None
# , ---> , ---> punctuation mark, comma
# the ---> the ---> None
# possibility ---> possibility ---> None
# that ---> that ---> None
# the ---> the ---> None
# world ---> world ---> None
# will ---> will ---> None
# stop ---> stop ---> None
# using ---> use ---> None
# oil ---> oil ---> None
# and ---> and ---> None
# gas ---> gas ---> None
# and ---> and ---> None
# investments ---> investment ---> None
# in ---> in ---> None
# fossil ---> fossil ---> None
# fuels ---> fuel ---> None
# will ---> will ---> None
# not ---> not ---> None
# pay ---> pay ---> None
# off ---> off ---> None
# — ---> — ---> None
# have ---> have ---> None
# moved ---> move ---> None
# firmly ---> firmly ---> None
# to ---> to ---> None
# the ---> the ---> None
# center ---> center ---> None
# of ---> of ---> None
# mainstream ---> mainstream ---> None
# investor ---> investor ---> None
# thinking ---> thinking ---> None
# . ---> . ---> punctuation mark, sentence closer
# Public ---> public ---> None
# companies ---> company ---> None
# have ---> have ---> None
# a ---> a ---> None
# board ---> board ---> None
# of ---> of ---> None
# directors ---> director ---> None
# that ---> that ---> None
# 's ---> be ---> None
# responsible ---> responsible ---> None
# for ---> for ---> None
# oversight ---> oversight ---> None
# of ---> of ---> None
# the ---> the ---> None
# CEO ---> CEO ---> None
# and ---> and ---> None
# overall ---> overall ---> None
# corporate ---> corporate ---> None
# strategy ---> strategy ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# The ---> the ---> None
# members ---> member ---> None
# of ---> of ---> None
# the ---> the ---> None
# board ---> board ---> None
# are ---> be ---> None
# technically ---> technically ---> None
# elected ---> elect ---> None
# by ---> by ---> None
# shareholders ---> shareholder ---> None
# , ---> , ---> punctuation mark, comma
# but ---> but ---> None
# normally ---> normally ---> None
# those ---> those ---> None
# elections ---> election ---> None
# are ---> be ---> None
# uncontested ---> uncontested ---> None
# and ---> and ---> None
# voting ---> voting ---> None
# is ---> be ---> None
# just ---> just ---> None
# a ---> a ---> None
# formality ---> formality ---> None
# . ---> . ---> punctuation mark, sentence closer
# Sometimes ---> sometimes ---> None
# , ---> , ---> punctuation mark, comma
# though ---> though ---> None
# , ---> , ---> punctuation mark, comma
# unhappy ---> unhappy ---> None
# investors ---> investor ---> None
# decide ---> decide ---> None
# to ---> to ---> None
# make ---> make ---> None
# it ---> it ---> None
# a ---> a ---> None
# real ---> real ---> None
# race ---> race ---> None
# by ---> by ---> None
# putting ---> put ---> None
# forward ---> forward ---> None
# rival ---> rival ---> None
# candidates ---> candidate ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# That ---> that ---> None
# 's ---> be ---> None
# exactly ---> exactly ---> None
# what ---> what ---> None
# happened ---> happen ---> None
# at ---> at ---> None
# Exxon ---> Exxon ---> None
# . ---> . ---> punctuation mark, sentence closer
# A ---> a ---> None
# hedge ---> hedge ---> None
# fund ---> fund ---> None
# called ---> call ---> None
# Engine ---> Engine ---> None
# No ---> no ---> None
# . ---> . ---> punctuation mark, sentence closer
# 1 ---> 1 ---> None
# was ---> be ---> None
# formed ---> form ---> None
# just ---> just ---> None
# last ---> last ---> None
# year ---> year ---> None
# with ---> with ---> None
# the ---> the ---> None
# express ---> express ---> None
# purpose ---> purpose ---> None
# of ---> of ---> None
# challenging ---> challenge ---> None
# Exxon ---> Exxon ---> None
# 's ---> 's ---> None
# corporate ---> corporate ---> None
# strategy ---> strategy ---> None
# . ---> . ---> punctuation mark, sentence closer
# The ---> the ---> None
# company ---> company ---> None
# and ---> and ---> None
# the ---> the ---> None
# upstart ---> upstart ---> None
# fund ---> fund ---> None
# have ---> have ---> None
# been ---> be ---> None
# vying ---> vie ---> None
# for ---> for ---> None
# shareholders ---> shareholder ---> None
# ' ---> ' ---> None
# votes ---> vote ---> None
# through ---> through ---> None
# slideshows ---> slideshow ---> None
# , ---> , ---> punctuation mark, comma
# letters ---> letter ---> None
# and ---> and ---> None
# public ---> public ---> None
# statements ---> statement ---> None
# . ---> . ---> punctuation mark, sentence closer
# The ---> the ---> None
# fund ---> fund ---> None
# pointed ---> point ---> None
# to ---> to ---> None
# Exxon ---> Exxon ---> None
# 's ---> 's ---> None
# poor ---> poor ---> None
# performance ---> performance ---> None
# , ---> , ---> punctuation mark, comma
# relative ---> relative ---> None
# to ---> to ---> None
# its ---> its ---> None
# peers ---> peer ---> None
# , ---> , ---> punctuation mark, comma
# during ---> during ---> None
# the ---> the ---> None
# years ---> year ---> None
# leading ---> lead ---> None
# up ---> up ---> None
# to ---> to ---> None
# the ---> the ---> None
# pandemic ---> pandemic ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# It ---> it ---> None
# also ---> also ---> None
# forcefully ---> forcefully ---> None
# argued ---> argue ---> None
# that ---> that ---> None
# the ---> the ---> None
# company ---> company ---> None
# has ---> have ---> None
# not ---> not ---> None
# laid ---> lay ---> None
# out ---> out ---> None
# a ---> a ---> None
# viable ---> viable ---> None
# plan ---> plan ---> None
# to ---> to ---> None
# be ---> be ---> None
# profitable ---> profitable ---> None
# if ---> if ---> None
# the ---> the ---> None
# world ---> world ---> None
# makes ---> make ---> None
# a ---> a ---> None
# rapid ---> rapid ---> None
# transition ---> transition ---> None
# away ---> away ---> None
# from ---> from ---> None
# oil ---> oil ---> None
# and ---> and ---> None
# gas ---> gas ---> None
# to ---> to ---> None
# ward ---> ward ---> None
# off ---> off ---> None
# the ---> the ---> None
# worst ---> bad ---> None
# effects ---> effect ---> None
# of ---> of ---> None
# climate ---> climate ---> None
# change ---> change ---> None
# . ---> . ---> punctuation mark, sentence closer
# Large ---> large ---> None
# European ---> european ---> None
# oil ---> oil ---> None
# and ---> and ---> None
# gas ---> gas ---> None
# companies ---> company ---> None
# are ---> be ---> None
# investing ---> invest ---> None
# in ---> in ---> None
# renewable ---> renewable ---> None
# energy ---> energy ---> None
# and ---> and ---> None
# pledging ---> pledge ---> None
# to ---> to ---> None
# slash ---> slash ---> None
# their ---> their ---> None
# emissions ---> emission ---> None
# to ---> to ---> None
# zero ---> zero ---> None
# , ---> , ---> punctuation mark, comma
# but ---> but ---> None
# Exxon ---> Exxon ---> None
# has ---> have ---> None
# consistently ---> consistently ---> None
# rejected ---> reject ---> None
# that ---> that ---> None
# strategy ---> strategy ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# The ---> the ---> None
# company ---> company ---> None
# says ---> say ---> None
# its ---> its ---> None
# core ---> core ---> None
# strengths ---> strength ---> None
# are ---> be ---> None
# in ---> in ---> None
# oil ---> oil ---> None
# and ---> and ---> None
# gas ---> gas ---> None
# , ---> , ---> punctuation mark, comma
# and ---> and ---> None
# it ---> it ---> None
# argues ---> argue ---> None
# that ---> that ---> None
# the ---> the ---> None
# world ---> world ---> None
# simply ---> simply ---> None
# will ---> will ---> None
# not ---> not ---> None
# pivot ---> pivot ---> None
# away ---> away ---> None
# from ---> from ---> None
# those ---> those ---> None
# energy ---> energy ---> None
# sources ---> source ---> None
# very ---> very ---> None
# quickly ---> quickly ---> None
# . ---> . ---> punctuation mark, sentence closer
# Instead ---> instead ---> None
# of ---> of ---> None
# branching ---> branch ---> None
# into ---> into ---> None
# new ---> new ---> None
# industries ---> industry ---> None
# where ---> where ---> None
# it ---> it ---> None
# does ---> do ---> None
# n't ---> n't ---> None
# have ---> have ---> None
# a ---> a ---> None
# competitive ---> competitive ---> None
# advantage ---> advantage ---> None
# , ---> , ---> punctuation mark, comma
# it ---> it ---> None
# argues ---> argue ---> None
# that ---> that ---> None
# it ---> it ---> None
# can ---> can ---> None
# invest ---> invest ---> None
# in ---> in ---> None
# carbon ---> carbon ---> None
# capture ---> capture ---> None
# technology ---> technology ---> None
# — ---> — ---> None
# capturing ---> capture ---> None
# greenhouse ---> greenhouse ---> None
# gases ---> gas ---> None
# in ---> in ---> None
# the ---> the ---> None
# atmosphere ---> atmosphere ---> None
# — ---> — ---> None
# and ---> and ---> None
# continue ---> continue ---> None
# to ---> to ---> None
# make ---> make ---> None
# money ---> money ---> None
# off ---> off ---> None
# oil ---> oil ---> None
# and ---> and ---> None
# gas ---> gas ---> None
# in ---> in ---> None
# a ---> a ---> None
# " ---> " ---> None
# lower ---> low ---> None
# - ---> - ---> None
# carbon ---> carbon ---> None
# " ---> " ---> None
# future ---> future ---> None
# . ---> . ---> punctuation mark, sentence closer
# This ---> this ---> None
# vision ---> vision ---> None
# of ---> of ---> None
# the ---> the ---> None
# future ---> future ---> None
# is ---> be ---> None
# increasingly ---> increasingly ---> None
# at ---> at ---> None
# odds ---> odd ---> None
# with ---> with ---> None
# the ---> the ---> None
# goals ---> goal ---> None
# espoused ---> espouse ---> None
# by ---> by ---> None
# world ---> world ---> None
# governments ---> government ---> None
# and ---> and ---> None
# the ---> the ---> None
# pathways ---> pathway ---> None
# laid ---> lay ---> None
# out ---> out ---> None
# by ---> by ---> None
# organizations ---> organization ---> None
# like ---> like ---> None
# the ---> the ---> None
# International ---> International ---> None
# Energy ---> Energy ---> None
# Agency ---> Agency ---> None
# . ---> . ---> punctuation mark, sentence closer
# Exxon ---> Exxon ---> None
# regards ---> regard ---> None
# those ---> those ---> None
# goals ---> goal ---> None
# and ---> and ---> None
# pathways ---> pathway ---> None
# as ---> as ---> None
# unrealistic ---> unrealistic ---> None
# , ---> , ---> punctuation mark, comma
# skeptically ---> skeptically ---> None
# noting ---> note ---> None
# that ---> that ---> None
# some ---> some ---> None
# plans ---> plan ---> None
# for ---> for ---> None
# fighting ---> fight ---> None
# climate ---> climate ---> None
# change ---> change ---> None
# would ---> would ---> None
# require ---> require ---> None
# people ---> people ---> None
# to ---> to ---> None
# immediately ---> immediately ---> None
# adjust ---> adjust ---> None
# their ---> their ---> None
# home ---> home ---> None
# thermostats ---> thermostat ---> None
# and ---> and ---> None
# take ---> take ---> None
# significantly ---> significantly ---> None
# fewer ---> few ---> None
# flights ---> flight ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# Those ---> those ---> None
# are ---> be ---> None
# behavioral ---> behavioral ---> None
# changes ---> change ---> None
# the ---> the ---> None
# company ---> company ---> None
# does ---> do ---> None
# not ---> not ---> None
# believe ---> believe ---> None
# likely ---> likely ---> None
# enough ---> enough ---> None
# to ---> to ---> None
# factor ---> factor ---> None
# in ---> in ---> None
# to ---> to ---> None
# its ---> its ---> None
# business ---> business ---> None
# planning ---> planning ---> None
# . ---> . ---> punctuation mark, sentence closer
# The ---> the ---> None
# vote ---> vote ---> None
# to ---> to ---> None
# defy ---> defy ---> None
# management ---> management ---> None
# and ---> and ---> None
# add ---> add ---> None
# two ---> two ---> None
# dissident ---> dissident ---> None
# members ---> member ---> None
# to ---> to ---> None
# the ---> the ---> None
# board ---> board ---> None
# represents ---> represent ---> None
# a ---> a ---> None
# repudiation ---> repudiation ---> None
# of ---> of ---> None
# that ---> that ---> None
# philosophy ---> philosophy ---> None
# . ---> . ---> punctuation mark, sentence closer
# Engine ---> engine ---> None
# No ---> no ---> None
# . ---> . ---> punctuation mark, sentence closer
# 1 ---> 1 ---> None
# holds ---> hold ---> None
# a ---> a ---> None
# tiny ---> tiny ---> None
# fraction ---> fraction ---> None
# of ---> of ---> None
# Exxon ---> Exxon ---> None
# shares ---> share ---> None
# — ---> — ---> None
# just ---> just ---> None
# 0.02 ---> 0.02 ---> None
# % ---> % ---> None
# , ---> , ---> punctuation mark, comma
# according ---> accord ---> None
# to ---> to ---> None
# the ---> the ---> None
# proxy ---> proxy ---> None
# advisory ---> advisory ---> None
# firm ---> firm ---> None
# ISS ---> ISS ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# By ---> by ---> None
# itself ---> itself ---> None
# , ---> , ---> punctuation mark, comma
# it ---> it ---> None
# had ---> have ---> None
# no ---> no ---> None
# chance ---> chance ---> None
# to ---> to ---> None
# sway ---> sway ---> None
# the ---> the ---> None
# company ---> company ---> None
# . ---> . ---> punctuation mark, sentence closer
# But ---> but ---> None
# it ---> it ---> None
# spent ---> spend ---> None
# months ---> month ---> None
# building ---> building ---> None
# support ---> support ---> None
# for ---> for ---> None
# its ---> its ---> None
# case ---> case ---> case marking
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# CalSTRS ---> calstrs ---> None
# , ---> , ---> punctuation mark, comma
# the ---> the ---> None
# California ---> California ---> None
# teachers ---> teacher ---> None
# pension ---> pension ---> None
# , ---> , ---> punctuation mark, comma
# was ---> be ---> None
# an ---> an ---> None
# early ---> early ---> None
# backer ---> backer ---> None
# , ---> , ---> punctuation mark, comma
# citing ---> cite ---> None
# frustration ---> frustration ---> None
# with ---> with ---> None
# Exxon ---> Exxon ---> None
# 's ---> 's ---> None
# lack ---> lack ---> None
# of ---> of ---> None
# response ---> response ---> None
# to ---> to ---> None
# previous ---> previous ---> None
# shareholder ---> shareholder ---> None
# proposals ---> proposal ---> None
# and ---> and ---> None
# direct ---> direct ---> None
# appeals ---> appeal ---> None
# from ---> from ---> None
# investors ---> investor ---> None
# . ---> . ---> punctuation mark, sentence closer
# "When ---> "When ---> None
# Engine ---> engine ---> None
# No ---> no ---> None
# . ---> . ---> punctuation mark, sentence closer
# 1 ---> 1 ---> None
# brought ---> bring ---> None
# this ---> this ---> None
# idea ---> idea ---> None
# to ---> to ---> None
# us ---> we ---> None
# around ---> around ---> None
# replacing ---> replace ---> None
# some ---> some ---> None
# of ---> of ---> None
# the ---> the ---> None
# incumbent ---> incumbent ---> None
# directors ---> director ---> None
# , ---> , ---> punctuation mark, comma
# we ---> we ---> None
# were ---> be ---> None
# very ---> very ---> None
# intrigued ---> intrigue ---> None
# — ---> — ---> None
# because ---> because ---> None
# we ---> we ---> None
# had ---> have ---> None
# tried ---> try ---> None
# everything ---> everything ---> None
# else ---> else ---> None
# , ---> , ---> punctuation mark, comma
# " ---> " ---> None
# says ---> say ---> None
# Aeisha ---> Aeisha ---> None
# Mastagni ---> Mastagni ---> None
# , ---> , ---> punctuation mark, comma
# a ---> a ---> None
# portfolio ---> portfolio ---> None
# manager ---> manager ---> None
# with ---> with ---> None
# CalSTRS ---> calstr ---> None
# ' ---> ' ---> None
# sustainable ---> sustainable ---> None
# investment ---> investment ---> None
# and ---> and ---> None
# stewardship ---> stewardship ---> None
# strategies ---> strategy ---> None
# unit ---> unit ---> None
# . ---> . ---> punctuation mark, sentence closer
# The ---> the ---> None
# influential ---> influential ---> None
# proxy ---> proxy ---> None
# advisory ---> advisory ---> None
# firms ---> firm ---> None
# ISS ---> ISS ---> None
# and ---> and ---> None
# Glass ---> Glass ---> None
# Lewis ---> Lewis ---> None
# , ---> , ---> punctuation mark, comma
# which ---> which ---> None
# issue ---> issue ---> None
# recommendations ---> recommendation ---> None
# on ---> on ---> None
# how ---> how ---> None
# investors ---> investor ---> None
# should ---> should ---> None
# vote ---> vote ---> None
# in ---> in ---> None
# shareholder ---> shareholder ---> None
# meetings ---> meeting ---> None
# , ---> , ---> punctuation mark, comma
# also ---> also ---> None
# partially ---> partially ---> None
# endorsed ---> endorse ---> None
# Engine ---> Engine ---> None
# No ---> no ---> None
# . ---> . ---> punctuation mark, sentence closer
# 1 ---> 1 ---> None
# 's ---> 's ---> None
# nominations ---> nomination ---> None
# . ---> . ---> punctuation mark, sentence closer
# Their ---> their ---> None
# reports ---> report ---> None
# provide ---> provide ---> None
# a ---> a ---> None
# striking ---> striking ---> None
# glimpse ---> glimpse ---> None
# into ---> into ---> None
# how ---> how ---> None
# arguments ---> argument ---> None
# that ---> that ---> None
# were ---> be ---> None
# initially ---> initially ---> None
# made ---> make ---> None
# by ---> by ---> None
# climate ---> climate ---> None
# activists ---> activist ---> None
# are ---> be ---> None
# becoming ---> become ---> None
# increasingly ---> increasingly ---> None
# mainstream ---> mainstream ---> None
# in ---> in ---> None
# the ---> the ---> None
# investor ---> investor ---> None
# community ---> community ---> None
# . ---> . ---> punctuation mark, sentence closer
# Both ---> both ---> None
# firms ---> firm ---> None
# used ---> use ---> None
# the ---> the ---> None
# word ---> word ---> None
# " ---> " ---> None
# inevitable ---> inevitable ---> None
# " ---> " ---> None
# to ---> to ---> None
# describe ---> describe ---> None
# the ---> the ---> None
# energy ---> energy ---> None
# transition ---> transition ---> None
# , ---> , ---> punctuation mark, comma
# or ---> or ---> None
# the ---> the ---> None
# world ---> world ---> None
# 's ---> 's ---> None
# shift ---> shift ---> None
# away ---> away ---> None
# from ---> from ---> None
# relying ---> rely ---> None
# on ---> on ---> None
# fossil ---> fossil ---> None
# fuels ---> fuel ---> None
# , ---> , ---> punctuation mark, comma
# and ---> and ---> None
# agreed ---> agree ---> None
# that ---> that ---> None
# Exxon ---> Exxon ---> None
# has ---> have ---> None
# inadequately ---> inadequately ---> None
# prepared ---> prepare ---> None
# for ---> for ---> None
# this ---> this ---> None
# future ---> future ---> None
# . ---> . ---> punctuation mark, sentence closer
# Heading ---> head ---> None
# into ---> into ---> None
# Wednesday ---> Wednesday ---> None
# 's ---> 's ---> None
# meeting ---> meeting ---> None
# , ---> , ---> punctuation mark, comma
# all ---> all ---> None
# eyes ---> eye ---> None
# were ---> be ---> None
# on ---> on ---> None
# the ---> the ---> None
# three ---> three ---> None
# companies ---> company ---> None
# with ---> with ---> None
# the ---> the ---> None
# biggest ---> big ---> None
# sway ---> sway ---> None
# in ---> in ---> None
# this ---> this ---> None
# vote ---> vote ---> None
# : ---> : ---> punctuation mark, colon or ellipsis
# Blackrock ---> Blackrock ---> None
# , ---> , ---> punctuation mark, comma
# Vanguard ---> Vanguard ---> None
# and ---> and ---> None
# State ---> State ---> None
# Street ---> Street ---> None
# Global ---> Global ---> None
# Advisors ---> Advisors ---> None
# . ---> . ---> punctuation mark, sentence closer
# Those ---> those ---> None
# companies ---> company ---> None
# manage ---> manage ---> None
# huge ---> huge ---> None
# funds ---> fund ---> None
# — ---> — ---> None
# including ---> include ---> None
# many ---> many ---> None
# people ---> people ---> None
# 's ---> 's ---> None
# retirement ---> retirement ---> None
# accounts ---> account ---> None
# — ---> — ---> None
# and ---> and ---> None
# their ---> their ---> None
# votes ---> vote ---> None
# are ---> be ---> None
# weighted ---> weight ---> None
# accordingly ---> accordingly ---> None
# , ---> , ---> punctuation mark, comma
# giving ---> give ---> None
# them ---> they ---> None
# tremendous ---> tremendous ---> None
# power ---> power ---> None
# in ---> in ---> None
# these ---> these ---> None
# kinds ---> kind ---> None
# of ---> of ---> None
# proxy ---> proxy ---> None
# votes ---> vote ---> None
# . ---> . ---> punctuation mark, sentence closer
# All ---> all ---> None
# three ---> three ---> None
# have ---> have ---> None
# pledged ---> pledge ---> None
# support ---> support ---> None
# for ---> for ---> None
# investor ---> investor ---> None
# initiatives ---> initiative ---> None
# focused ---> focus ---> None
# on ---> on ---> None
# fighting ---> fight ---> None
# climate ---> climate ---> None
# change ---> change ---> None
# . ---> . ---> punctuation mark, sentence closer

# %% [markdown]
# ### Sentence boundary detection

# %%
list(doc.sents)
# Out:
# [Pictured are pumps at an Exxon gas station in Charlotte, N.C.,
#  A tiny fund got two board members elected to the oil giant's board, delivering a historic defeat to ExxonMobil.,
#  In a dramatic boardroom battle on Wednesday, a tiny hedge fund fought with the energy giant ExxonMobil over the future of the oil and gas industry — and won.,
#  The brand-new activist hedge fund successfully placed at least two new candidates on the company's board of directors in hopes that they can use that position to push Exxon to take climate change more seriously.,
#  ,
#  For two more seats on the board, the vote was too close to call.,
#  Winning a seat for any directors at all is an unprecedented achievement by activist shareholders, who have spent decades trying to persuade companies to cut their carbon emissions.,
#  ,
#  To do it at ExxonMobil, once the world's most influential oil company, makes the feat all the more astonishing.,
#  And it demonstrates how arguments about the financial implications of climate change — specifically, the possibility that the world will stop using oil and gas and investments in fossil fuels will not pay off — have moved firmly to the center of mainstream investor thinking.,
#  Public companies have a board of directors that's responsible for oversight of the CEO and overall corporate strategy.,
#  ,
#  The members of the board are technically elected by shareholders, but normally those elections are uncontested and voting is just a formality.,
#  Sometimes, though, unhappy investors decide to make it a real race by putting forward rival candidates.,
#  ,
#  That's exactly what happened at Exxon.,
#  A hedge fund called Engine No. 1 was formed just last year with the express purpose of challenging Exxon's corporate strategy.,
#  The company and the upstart fund have been vying for shareholders' votes through slideshows, letters and public statements.,
#  The fund pointed to Exxon's poor performance, relative to its peers, during the years leading up to the pandemic.,
#  It also forcefully argued that the company has not laid out a viable plan to be profitable if the world makes a rapid transition away from oil and gas to ward off the worst effects of climate change.,
#  Large European oil and gas companies are investing in renewable energy and pledging to slash their emissions to zero, but Exxon has consistently rejected that strategy.,
#  ,
#  The company says its core strengths are in oil and gas, and it argues that the world simply will not pivot away from those energy sources very quickly.,
#  Instead of branching into new industries where it doesn't have a competitive advantage, it argues that it can invest in carbon capture technology — capturing greenhouse gases in the atmosphere — and continue to make money off oil and gas in a "lower-carbon" future.,
#  This vision of the future is increasingly at odds with the goals espoused by world governments and the pathways laid out by organizations like the International Energy Agency.,
#  Exxon regards those goals and pathways as unrealistic, skeptically noting that some plans for fighting climate change would require people to immediately adjust their home thermostats and take significantly fewer flights.,
#  ,
#  Those are behavioral changes the company does not believe likely enough to factor in to its business planning.,
#  The vote to defy management and add two dissident members to the board represents a repudiation of that philosophy.,
#  Engine No. 1 holds a tiny fraction of Exxon shares — just 0.02%, according to the proxy advisory firm ISS.,
#  ,
#  By itself, it had no chance to sway the company.,
#  But it spent months building support for its case.,
#
#  CalSTRS, the California teachers pension, was an early backer, citing frustration with Exxon's lack of response to previous shareholder proposals and direct appeals from investors.,
#  "When Engine No. 1 brought this idea to us around replacing some of the incumbent directors, we were very intrigued — because we had tried everything else," says Aeisha Mastagni, a portfolio manager with CalSTRS' sustainable investment and stewardship strategies unit.,
#  The influential proxy advisory firms ISS and Glass Lewis, which issue recommendations on how investors should vote in shareholder meetings, also partially endorsed Engine No. 1's nominations.,
#  Their reports provide a striking glimpse into how arguments that were initially made by climate activists are becoming increasingly mainstream in the investor community.,
#  Both firms used the word "inevitable" to describe the energy transition, or the world's shift away from relying on fossil fuels, and agreed that Exxon has inadequately prepared for this future.,
#  Heading into Wednesday's meeting, all eyes were on the three companies with the biggest sway in this vote: Blackrock, Vanguard and State Street Global Advisors.,
#  Those companies manage huge funds — including many people's retirement accounts — and their votes are weighted accordingly, giving them tremendous power in these kinds of proxy votes.,
#  All three have pledged support for investor initiatives focused on fighting climate change.]

# %%
sentences = list(doc.sents)

# %%
for sentence in sentences:
    print(sentence)
# Out:
# Pictured are pumps at an Exxon gas station in Charlotte, N.C.
# A tiny fund got two board members elected to the oil giant's board, delivering a historic defeat to ExxonMobil.
# In a dramatic boardroom battle on Wednesday, a tiny hedge fund fought with the energy giant ExxonMobil over the future of the oil and gas industry — and won.
# The brand-new activist hedge fund successfully placed at least two new candidates on the company's board of directors in hopes that they can use that position to push Exxon to take climate change more seriously.
#
#
# For two more seats on the board, the vote was too close to call.
# Winning a seat for any directors at all is an unprecedented achievement by activist shareholders, who have spent decades trying to persuade companies to cut their carbon emissions.
#
#
# To do it at ExxonMobil, once the world's most influential oil company, makes the feat all the more astonishing.
# And it demonstrates how arguments about the financial implications of climate change — specifically, the possibility that the world will stop using oil and gas and investments in fossil fuels will not pay off — have moved firmly to the center of mainstream investor thinking.
# Public companies have a board of directors that's responsible for oversight of the CEO and overall corporate strategy.
#
#
# The members of the board are technically elected by shareholders, but normally those elections are uncontested and voting is just a formality.
# Sometimes, though, unhappy investors decide to make it a real race by putting forward rival candidates.
#
#
# That's exactly what happened at Exxon.
# A hedge fund called Engine No. 1 was formed just last year with the express purpose of challenging Exxon's corporate strategy.
# The company and the upstart fund have been vying for shareholders' votes through slideshows, letters and public statements.
# The fund pointed to Exxon's poor performance, relative to its peers, during the years leading up to the pandemic.
#
# It also forcefully argued that the company has not laid out a viable plan to be profitable if the world makes a rapid transition away from oil and gas to ward off the worst effects of climate change.
# Large European oil and gas companies are investing in renewable energy and pledging to slash their emissions to zero, but Exxon has consistently rejected that strategy.
#
#
# The company says its core strengths are in oil and gas, and it argues that the world simply will not pivot away from those energy sources very quickly.
# Instead of branching into new industries where it doesn't have a competitive advantage, it argues that it can invest in carbon capture technology — capturing greenhouse gases in the atmosphere — and continue to make money off oil and gas in a "lower-carbon" future.
# This vision of the future is increasingly at odds with the goals espoused by world governments and the pathways laid out by organizations like the International Energy Agency.
# Exxon regards those goals and pathways as unrealistic, skeptically noting that some plans for fighting climate change would require people to immediately adjust their home thermostats and take significantly fewer flights.
#
#
# Those are behavioral changes the company does not believe likely enough to factor in to its business planning.
# The vote to defy management and add two dissident members to the board represents a repudiation of that philosophy.
# Engine No. 1 holds a tiny fraction of Exxon shares — just 0.02%, according to the proxy advisory firm ISS.
#
#
# By itself, it had no chance to sway the company.
# But it spent months building support for its case.
#
# CalSTRS, the California teachers pension, was an early backer, citing frustration with Exxon's lack of response to previous shareholder proposals and direct appeals from investors.
# "When Engine No. 1 brought this idea to us around replacing some of the incumbent directors, we were very intrigued — because we had tried everything else," says Aeisha Mastagni, a portfolio manager with CalSTRS' sustainable investment and stewardship strategies unit.
# The influential proxy advisory firms ISS and Glass Lewis, which issue recommendations on how investors should vote in shareholder meetings, also partially endorsed Engine No. 1's nominations.
# Their reports provide a striking glimpse into how arguments that were initially made by climate activists are becoming increasingly mainstream in the investor community.
# Both firms used the word "inevitable" to describe the energy transition, or the world's shift away from relying on fossil fuels, and agreed that Exxon has inadequately prepared for this future.
# Heading into Wednesday's meeting, all eyes were on the three companies with the biggest sway in this vote: Blackrock, Vanguard and State Street Global Advisors.
# Those companies manage huge funds — including many people's retirement accounts — and their votes are weighted accordingly, giving them tremendous power in these kinds of proxy votes.
# All three have pledged support for investor initiatives focused on fighting climate change.

# %% [markdown]
# ### Named entity

# %%
for ent in doc.ents:
    print(ent.text, '--->', ent.label_, '--->', spacy.explain(ent.label_))
# Out:
# Exxon ---> ORG ---> Companies, agencies, institutions, etc.
# Charlotte ---> GPE ---> Countries, cities, states
# N.C. ---> GPE ---> Countries, cities, states
# two ---> CARDINAL ---> Numerals that do not fall under another type
# ExxonMobil ---> ORG ---> Companies, agencies, institutions, etc.
# Wednesday ---> DATE ---> Absolute or relative dates or periods
# ExxonMobil ---> ORG ---> Companies, agencies, institutions, etc.
# at least two ---> CARDINAL ---> Numerals that do not fall under another type
# Exxon ---> ORG ---> Companies, agencies, institutions, etc.
# two ---> CARDINAL ---> Numerals that do not fall under another type
# decades ---> DATE ---> Absolute or relative dates or periods
# ExxonMobil ---> ORG ---> Companies, agencies, institutions, etc.
# Exxon ---> ORG ---> Companies, agencies, institutions, etc.
# Engine ---> ORG ---> Companies, agencies, institutions, etc.
# 1 ---> CARDINAL ---> Numerals that do not fall under another type
# just last year ---> DATE ---> Absolute or relative dates or periods
# Exxon ---> ORG ---> Companies, agencies, institutions, etc.
# Exxon ---> ORG ---> Companies, agencies, institutions, etc.
# the years ---> DATE ---> Absolute or relative dates or periods
# European ---> NORP ---> Nationalities or religious or political groups
# zero ---> CARDINAL ---> Numerals that do not fall under another type
# Exxon ---> ORG ---> Companies, agencies, institutions, etc.
# the International Energy Agency ---> ORG ---> Companies, agencies, institutions, etc.
# Exxon ---> ORG ---> Companies, agencies, institutions, etc.
# two ---> CARDINAL ---> Numerals that do not fall under another type
# 1 ---> CARDINAL ---> Numerals that do not fall under another type
# Exxon ---> ORG ---> Companies, agencies, institutions, etc.
# just 0.02% ---> PERCENT ---> Percentage, including "%"
# months ---> DATE ---> Absolute or relative dates or periods
# California ---> GPE ---> Countries, cities, states
# Exxon ---> ORG ---> Companies, agencies, institutions, etc.
# Aeisha Mastagni ---> PERSON ---> People, including fictional
# CalSTRS ---> ORG ---> Companies, agencies, institutions, etc.
# Glass Lewis ---> PERSON ---> People, including fictional
# Engine ---> PERSON ---> People, including fictional
# 1 ---> CARDINAL ---> Numerals that do not fall under another type
# Exxon ---> ORG ---> Companies, agencies, institutions, etc.
# Wednesday ---> DATE ---> Absolute or relative dates or periods
# three ---> CARDINAL ---> Numerals that do not fall under another type
# Blackrock ---> GPE ---> Countries, cities, states
# Vanguard ---> ORG ---> Companies, agencies, institutions, etc.
# State Street Global Advisors ---> ORG ---> Companies, agencies, institutions, etc.
# three ---> CARDINAL ---> Numerals that do not fall under another type

# %% [markdown]
# ### Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Pictured are pumps at an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Exxon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  gas station in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Charlotte
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     N.C.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  A tiny fund got
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  board members elected to the oil giant's board, delivering a historic defeat to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ExxonMobil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .In a dramatic boardroom battle on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a tiny hedge fund fought with the energy giant
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ExxonMobil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  over the future of the oil and gas industry — and won.The brand-new activist hedge fund successfully placed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at least two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  new candidates on the company's board of directors in hopes that they can use that position to push
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Exxon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to take climate change more seriously.</br>For
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  more seats on the board, the vote was too close to call.Winning a seat for any directors at all is an unprecedented achievement by activist shareholders, who have spent
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     decades
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  trying to persuade companies to cut their carbon emissions.</br>To do it at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ExxonMobil
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , once the world's most influential oil company, makes the feat all the more astonishing.And it demonstrates how arguments about the financial implications of climate change — specifically, the possibility that the world will stop using oil and gas and investments in fossil fuels will not pay off — have moved firmly to the center of mainstream investor thinking.Public companies have a board of directors that's responsible for oversight of the CEO and overall corporate strategy.</br>The members of the board are technically elected by shareholders, but normally those elections are uncontested and voting is just a formality.Sometimes, though, unhappy investors decide to make it a real race by putting forward rival candidates.</br>That's exactly what happened at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Exxon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .A hedge fund called
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Engine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  No.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  was formed
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     just last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with the express purpose of challenging
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Exxon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's corporate strategy.The company and the upstart fund have been vying for shareholders' votes through slideshows, letters and public statements.The fund pointed to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Exxon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's poor performance, relative to its peers, during
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  leading up to the pandemic.</br>It also forcefully argued that the company has not laid out a viable plan to be profitable if the world makes a rapid transition away from oil and gas to ward off the worst effects of climate change.Large
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">

# %%
displacy.render(doc, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f7904f5782b848b7879fc2b96c59027e-0" class="displacy" width="143550" height="2324.5" direction="ltr" style="max-width: none; height: 2324.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Pictured</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">pumps</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Exxon</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">gas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">station</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Charlotte,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">N.C.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">A</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">tiny</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">fund</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">got</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">board</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">members</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">elected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">oil</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">giant</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">board,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">delivering</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">historic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">defeat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="2234.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">ExxonMobil.</tspan>
#     <tspan class="displacy-tag

# %% [markdown]
# ### Putting it all together

# %%
lis = []

# %%
for token in doc:
    dic = {}
    dic['Token'] = token.text
    dic['POS'] = token.pos_
    dic['Tags'] = token.tag_
    dic['Dep'] = token.dep_
    dic['Explaination'] = spacy.explain(token.tag_)
    lis.append(dic)

# %%
import pandas as pd

# %%
data = pd.DataFrame(lis)

# %%
data
# Out:
#         Token    POS Tags       Dep                               Explaination
# 0    Pictured   VERB  VBN     nsubj                      verb, past participle
# 1         are    AUX  VBP      ROOT      verb, non-3rd person singular present
# 2       pumps   NOUN  NNS      attr                               noun, plural
# 3          at    ADP   IN      prep  conjunction, subordinating or preposition
# 4          an    DET   DT       det                                 determiner
# ..        ...    ...  ...       ...                                        ...
# 905        on    ADP   IN      prep  conjunction, subordinating or preposition
# 906  fighting   VERB  VBG     pcomp         verb, gerund or present participle
# 907   climate   NOUN   NN  compound                     noun, singular or mass
# 908    change   NOUN   NN      dobj                     noun, singular or mass
# 909         .  PUNCT    .     punct          punctuation mark, sentence closer
#
# [910 rows x 5 columns]

# %% [markdown]
# #### You can reindex if you do not like the arrangement

# %%
l = []
for ent in doc.ents:
    d = {}
    d['entities'] = ent.text
    d['labels'] = ent.label_
    d['Explaination'] = spacy.explain(ent.label_)
    l.append(d)

# %%
entities = pd.DataFrame(l)

# %%
entities
# Out:
#                            entities    labels  \
# 0                             Exxon       ORG
# 1                         Charlotte       GPE
# 2                              N.C.       GPE
# 3                               two  CARDINAL
# 4                        ExxonMobil       ORG
# 5                         Wednesday      DATE
# 6                        ExxonMobil       ORG
# 7                      at least two  CARDINAL
# 8                             Exxon       ORG
# 9                               two  CARDINAL
# 10                          decades      DATE
# 11                       ExxonMobil       ORG
# 12                            Exxon       ORG
# 13                           Engine       ORG
# 14                                1  CARDINAL
# 15                   just last year      DATE
# 16                            Exxon       ORG
# 17                            Exxon       ORG
# 18                        the years      DATE
# 19                         European      NORP
# 20                             zero  CARDINAL
# 21                            Exxon       ORG
# 22  the International Energy Agency       ORG
# 23                            Exxon       ORG
# 24                              two  CARDINAL
# 25                                1  CARDINAL
# 26                            Exxon       ORG
# 27                       just 0.02%   PERCENT
# 28                           months      DATE
# 29                       California       GPE
# 30                            Exxon       ORG
# 31                  Aeisha Mastagni    PERSON
# 32                          CalSTRS       ORG
# 33                      Glass Lewis    PERSON
# 34                           Engine    PERSON
# 35                                1  CARDINAL
# 36                            Exxon       ORG
# 37                        Wednesday      DATE
# 38                            three  CARDINAL
# 39                        Blackrock       GPE
# 40                         Vanguard       ORG
# 41     State Street Global Advisors       ORG
# 42                            three  CARDINAL
#
#                                       Explaination
# 0          Companies, agencies, institutions, etc.
# 1                        Countries, cities, states
# 2                        Countries, cities, states
# 3     Numerals that do not fall under another type
# 4          Companies, agencies, institutions, etc.
# 5            Absolute or relative dates or periods
# 6          Companies, agencies, institutions, etc.
# 7     Numerals that do not fall under another type
# 8          Companies, agencies, institutions, etc.
# 9     Numerals that do not fall under another type
# 10           Absolute or relative dates or periods
# 11         Companies, agencies, institutions, etc.
# 12         Companies, agencies, institutions, etc.
# 13         Companies, agencies, institutions, etc.
# 14    Numerals that do not fall under another type
# 15           Absolute or relative dates or periods
# 16         Companies, agencies, institutions, etc.
# 17         Companies, agencies, institutions, etc.
# 18           Absolute or relative dates or periods
# 19  Nationalities or religious or political groups
# 20    Numerals that do not fall under another type
# 21         Companies, agencies, institutions, etc.
# 22         Companies, agencies, institutions, etc.
# 23         Companies, agencies, institutions, etc.
# 24    Numerals that do not fall under another type
# 25    Numerals that do not fall under another type
# 26         Companies, agencies, institutions, etc.
# 27                       Percentage, including "%"
# 28           Absolute or relative dates or periods
# 29                       Countries, cities, states
# 30         Companies, agencies, institutions, etc.
# 31                     People, including fictional
# 32         Companies, agencies, institutions, etc.
# 33                     People, including fictional
# 34                     People, including fictional
# 35    Numerals that do not fall under another type
# 36         Companies, agencies, institutions, etc.
# 37           Absolute or relative dates or periods
# 38    Numerals that do not fall under another type
# 39                       Countries, cities, states
# 40         Companies, agencies, institutions, etc.
# 41         Companies, agencies, institutions, etc.
# 42    Numerals that do not fall under another type

# %%
entities.to_csv('Entities.csv', index = False)

# %% [markdown]
# ### Scraping and summerizing article 2

# %%
url2 = 'https://www.npr.org/2021/05/26/1000452074/if-you-didnt-look-up-this-morning-heres-what-you-missed'

# %%
requests.get(url2)
page = requests.get(url2).text
soup = BeautifulSoup(page)
header = soup.find('h1').get_text()
date = soup.find(name = 'span', attrs = {'class':'date'}).text
p_tags = soup.find_all('p')
text = [tags.get_text().strip() for tags in p_tags]
sentence_list = [sentence for sentence in text if not '\n' in sentence]
body = [sentence for sentence in sentence_list if '.' in sentence]
article = ''.join(body)
summary2 = summarize(article, 1)
doc = docx.Document()
doc.add_heading(header)
doc.add_picture('pic02.png')
doc.add_paragraph(date)
doc.add_paragraph(summary2)
doc.save('article2.docx')

# %%
summary2
# Out:
# 'The lunar eclipse is seen in Santa Monica.\nFull moons that occur in May are sometimes known as flower moons.Maybe the sky was cloudy; maybe waking up in the middle of the night to look at the moon just sounds like lunacy.\nWhatever the reason, if you missed seeing last night\'s lunar eclipse, you\'re not alone.\nLuckily, there are plenty of photos and video of the rare sight.For those of us who slept through the Super Flower Blood Moon: Here\'s a quick time lapse taken early this morning 🌷🌕 pic.twitter.com/Q38GJ4WrWHThe supermoon — the Super Flower Blood Moon, to be exact — brought the first total lunar eclipse in nearly 2 1/2 years, treating sky watchers to the sight of the moon slipping into Earth\'s shadow while also appearing around 7% larger than it normally does.Residents watch the lunar eclipse Wednesday at Sanur beach in Indonesia\'s Bali.\nThe reddish-orange color of the supermoon is the result of all the sunrises and sunsets in Earth\'s atmosphere projected onto the surface of the eclipsed moon.People on both sides of the Pacific Ocean were able to see the total eclipse, from the Western U.S. and Mexico to New Zealand and eastern Australia.\nSome of the best views were in Hawaii and the Pacific islands.The biggest draw of this celestial event is that a supermoon and a total lunar eclipse are occurring simultaneously.\nIn the past 10 years, there have been just 10 total lunar eclipses.A lunar eclipse is observed Wednesday in Brasilia, Brazil.The supermoon was visible all over the world, but the full lunar eclipse was visible in many parts of the world.\nObservers had to look fast; the total eclipse lasted around 15 minutes.The unusual name for this moon is due to several astronomical phenomena coinciding in one event."Blood": The moon takes on a red hue as it aligns with the sun and Earth and passes fully into Earth\'s shadow, or umbra.\nThe distinct bloodlike color is caused by red-orange light refracted through the Earth\'s atmosphere.\nThe red hue can appear more intense if more clouds or dust are in the Earth\'s atmosphere, according to NASA.A surfer rides a wave Wednesday as a supermoon rises above the horizon at Manly Beach in Sydney."Super": The shape of the moon\'s orbit around the Earth is not a perfect circle, but an oval.\nWhen a full moon reaches the point closest to our planet on its elliptical orbit, it\'s called a supermoon, or perigee-syzygy, and appears larger than usual in the sky.\nSupermoons are more common than total eclipses — they typically occur several times a year.The moon rises over Victoria Harbour in Hong Kong on Wednesday."Flower": Full moons that occur in May are sometimes known as flower moons.\nAccording to The Old Farmer\'s Almanac, the name is a reference to the flowers that are blooming in May and has been attributed to Native American, Colonial American and European sources.Photographers take photos of the lunar eclipse Wednesday at the Central TV Tower in Beijing.The next total lunar eclipse will occur about a year from now.\nBut a near-total eclipse will come on the night of Nov. 18 to 19, says Diana Hannikainen, observing editor at Sky & Telescope.The lunar eclipse progresses behind a Ferris wheel over Santa Monica Beach on Wednesday in Santa Monica, Calif.\nThe first total lunar eclipse in more than two years is coinciding with a supermoon."Technically, the November event will be partial, but only the thinnest sliver of the moon\'s disk will remain outside the umbra, so for all intents and purposes it\'ll be very much like a total eclipse," she said.'

# %% [markdown]
# ### Tokenization

# %%
import spacy

# %% [markdown]
# #### Load the language model

# %%
nlp = spacy.load('en_core_web_sm')

# %%
doc2 = nlp(summary2)

# %%
for token in doc2:
    print(token.text, '--->', spacy.explain(token.text))
# Out:
# The ---> None
# lunar ---> None
# eclipse ---> None
# is ---> None
# seen ---> None
# in ---> None
# Santa ---> None
# Monica ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# Full ---> None
# moons ---> None
# that ---> None
# occur ---> None
# in ---> None
# May ---> None
# are ---> None
# sometimes ---> None
# known ---> None
# as ---> None
# flower ---> None
# moons ---> None
# . ---> punctuation mark, sentence closer
# Maybe ---> None
# the ---> None
# sky ---> None
# was ---> None
# cloudy ---> None
# ; ---> None
# maybe ---> None
# waking ---> None
# up ---> None
# in ---> None
# the ---> None
# middle ---> None
# of ---> None
# the ---> None
# night ---> None
# to ---> None
# look ---> None
# at ---> None
# the ---> None
# moon ---> None
# just ---> None
# sounds ---> None
# like ---> None
# lunacy ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# Whatever ---> None
# the ---> None
# reason ---> None
# , ---> punctuation mark, comma
# if ---> None
# you ---> None
# missed ---> None
# seeing ---> None
# last ---> None
# night ---> None
# 's ---> None
# lunar ---> None
# eclipse ---> None
# , ---> punctuation mark, comma
# you ---> None
# 're ---> None
# not ---> None
# alone ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# Luckily ---> None
# , ---> punctuation mark, comma
# there ---> None
# are ---> None
# plenty ---> None
# of ---> None
# photos ---> None
# and ---> None
# video ---> None
# of ---> None
# the ---> None
# rare ---> None
# sight ---> None
# . ---> punctuation mark, sentence closer
# For ---> None
# those ---> None
# of ---> None
# us ---> None
# who ---> None
# slept ---> None
# through ---> None
# the ---> None
# Super ---> None
# Flower ---> None
# Blood ---> None
# Moon ---> None
# : ---> punctuation mark, colon or ellipsis
# Here ---> None
# 's ---> None
# a ---> None
# quick ---> None
# time ---> None
# lapse ---> None
# taken ---> None
# early ---> None
# this ---> None
# morning ---> None
# 🌷 ---> None
# 🌕 ---> None
# pic.twitter.com/Q38GJ4WrWHThe ---> None
# supermoon ---> None
# — ---> None
# the ---> None
# Super ---> None
# Flower ---> None
# Blood ---> None
# Moon ---> None
# , ---> punctuation mark, comma
# to ---> None
# be ---> None
# exact ---> None
# — ---> None
# brought ---> None
# the ---> None
# first ---> None
# total ---> None
# lunar ---> None
# eclipse ---> None
# in ---> None
# nearly ---> None
# 2 ---> None
# 1/2 ---> None
# years ---> None
# , ---> punctuation mark, comma
# treating ---> None
# sky ---> None
# watchers ---> None
# to ---> None
# the ---> None
# sight ---> None
# of ---> None
# the ---> None
# moon ---> None
# slipping ---> None
# into ---> None
# Earth ---> None
# 's ---> None
# shadow ---> None
# while ---> None
# also ---> None
# appearing ---> None
# around ---> None
# 7 ---> None
# % ---> None
# larger ---> None
# than ---> None
# it ---> None
# normally ---> None
# does ---> None
# . ---> punctuation mark, sentence closer
# Residents ---> None
# watch ---> None
# the ---> None
# lunar ---> None
# eclipse ---> None
# Wednesday ---> None
# at ---> None
# Sanur ---> None
# beach ---> None
# in ---> None
# Indonesia ---> None
# 's ---> None
# Bali ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# The ---> None
# reddish ---> None
# - ---> None
# orange ---> None
# color ---> None
# of ---> None
# the ---> None
# supermoon ---> None
# is ---> None
# the ---> None
# result ---> None
# of ---> None
# all ---> None
# the ---> None
# sunrises ---> None
# and ---> None
# sunsets ---> None
# in ---> None
# Earth ---> None
# 's ---> None
# atmosphere ---> None
# projected ---> None
# onto ---> None
# the ---> None
# surface ---> None
# of ---> None
# the ---> None
# eclipsed ---> None
# moon ---> None
# . ---> punctuation mark, sentence closer
# People ---> None
# on ---> None
# both ---> None
# sides ---> None
# of ---> None
# the ---> None
# Pacific ---> None
# Ocean ---> None
# were ---> None
# able ---> None
# to ---> None
# see ---> None
# the ---> None
# total ---> None
# eclipse ---> None
# , ---> punctuation mark, comma
# from ---> None
# the ---> None
# Western ---> None
# U.S. ---> None
# and ---> None
# Mexico ---> None
# to ---> None
# New ---> None
# Zealand ---> None
# and ---> None
# eastern ---> None
# Australia ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# Some ---> None
# of ---> None
# the ---> None
# best ---> None
# views ---> None
# were ---> None
# in ---> None
# Hawaii ---> None
# and ---> None
# the ---> None
# Pacific ---> None
# islands ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# biggest ---> None
# draw ---> None
# of ---> None
# this ---> None
# celestial ---> None
# event ---> None
# is ---> None
# that ---> None
# a ---> None
# supermoon ---> None
# and ---> None
# a ---> None
# total ---> None
# lunar ---> None
# eclipse ---> None
# are ---> None
# occurring ---> None
# simultaneously ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# In ---> None
# the ---> None
# past ---> None
# 10 ---> None
# years ---> None
# , ---> punctuation mark, comma
# there ---> None
# have ---> None
# been ---> None
# just ---> None
# 10 ---> None
# total ---> None
# lunar ---> None
# eclipses ---> None
# . ---> punctuation mark, sentence closer
# A ---> None
# lunar ---> None
# eclipse ---> None
# is ---> None
# observed ---> None
# Wednesday ---> None
# in ---> None
# Brasilia ---> None
# , ---> punctuation mark, comma
# Brazil ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# supermoon ---> None
# was ---> None
# visible ---> None
# all ---> None
# over ---> None
# the ---> None
# world ---> None
# , ---> punctuation mark, comma
# but ---> None
# the ---> None
# full ---> None
# lunar ---> None
# eclipse ---> None
# was ---> None
# visible ---> None
# in ---> None
# many ---> None
# parts ---> None
# of ---> None
# the ---> None
# world ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# Observers ---> None
# had ---> None
# to ---> None
# look ---> None
# fast ---> None
# ; ---> None
# the ---> None
# total ---> None
# eclipse ---> None
# lasted ---> None
# around ---> None
# 15 ---> None
# minutes ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# unusual ---> None
# name ---> None
# for ---> None
# this ---> None
# moon ---> None
# is ---> None
# due ---> None
# to ---> None
# several ---> None
# astronomical ---> None
# phenomena ---> None
# coinciding ---> None
# in ---> None
# one ---> None
# event ---> None
# . ---> punctuation mark, sentence closer
# "Blood ---> None
# " ---> None
# : ---> punctuation mark, colon or ellipsis
# The ---> None
# moon ---> None
# takes ---> None
# on ---> None
# a ---> None
# red ---> None
# hue ---> None
# as ---> None
# it ---> None
# aligns ---> None
# with ---> None
# the ---> None
# sun ---> None
# and ---> None
# Earth ---> None
# and ---> None
# passes ---> None
# fully ---> None
# into ---> None
# Earth ---> None
# 's ---> None
# shadow ---> None
# , ---> punctuation mark, comma
# or ---> None
# umbra ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# The ---> None
# distinct ---> None
# bloodlike ---> None
# color ---> None
# is ---> None
# caused ---> None
# by ---> None
# red ---> None
# - ---> None
# orange ---> None
# light ---> None
# refracted ---> None
# through ---> None
# the ---> None
# Earth ---> None
# 's ---> None
# atmosphere ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# The ---> None
# red ---> None
# hue ---> None
# can ---> None
# appear ---> None
# more ---> None
# intense ---> None
# if ---> None
# more ---> None
# clouds ---> None
# or ---> None
# dust ---> None
# are ---> None
# in ---> None
# the ---> None
# Earth ---> None
# 's ---> None
# atmosphere ---> None
# , ---> punctuation mark, comma
# according ---> None
# to ---> None
# NASA.A ---> None
# surfer ---> None
# rides ---> None
# a ---> None
# wave ---> None
# Wednesday ---> None
# as ---> None
# a ---> None
# supermoon ---> None
# rises ---> None
# above ---> None
# the ---> None
# horizon ---> None
# at ---> None
# Manly ---> None
# Beach ---> None
# in ---> None
# Sydney ---> None
# . ---> punctuation mark, sentence closer
# "Super ---> None
# " ---> None
# : ---> punctuation mark, colon or ellipsis
# The ---> None
# shape ---> None
# of ---> None
# the ---> None
# moon ---> None
# 's ---> None
# orbit ---> None
# around ---> None
# the ---> None
# Earth ---> None
# is ---> None
# not ---> None
# a ---> None
# perfect ---> None
# circle ---> None
# , ---> punctuation mark, comma
# but ---> None
# an ---> None
# oval ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# When ---> None
# a ---> None
# full ---> None
# moon ---> None
# reaches ---> None
# the ---> None
# point ---> None
# closest ---> None
# to ---> None
# our ---> None
# planet ---> None
# on ---> None
# its ---> None
# elliptical ---> None
# orbit ---> None
# , ---> punctuation mark, comma
# it ---> None
# 's ---> None
# called ---> None
# a ---> None
# supermoon ---> None
# , ---> punctuation mark, comma
# or ---> None
# perigee ---> None
# - ---> None
# syzygy ---> None
# , ---> punctuation mark, comma
# and ---> None
# appears ---> None
# larger ---> None
# than ---> None
# usual ---> None
# in ---> None
# the ---> None
# sky ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# Supermoons ---> None
# are ---> None
# more ---> None
# common ---> None
# than ---> None
# total ---> None
# eclipses ---> None
# — ---> None
# they ---> None
# typically ---> None
# occur ---> None
# several ---> None
# times ---> None
# a ---> None
# year ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# moon ---> None
# rises ---> None
# over ---> None
# Victoria ---> None
# Harbour ---> None
# in ---> None
# Hong ---> None
# Kong ---> None
# on ---> None
# Wednesday ---> None
# . ---> punctuation mark, sentence closer
# "Flower ---> None
# " ---> None
# : ---> punctuation mark, colon or ellipsis
# Full ---> None
# moons ---> None
# that ---> None
# occur ---> None
# in ---> None
# May ---> None
# are ---> None
# sometimes ---> None
# known ---> None
# as ---> None
# flower ---> None
# moons ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# According ---> None
# to ---> None
# The ---> None
# Old ---> None
# Farmer ---> None
# 's ---> None
# Almanac ---> None
# , ---> punctuation mark, comma
# the ---> None
# name ---> None
# is ---> None
# a ---> None
# reference ---> None
# to ---> None
# the ---> None
# flowers ---> None
# that ---> None
# are ---> None
# blooming ---> None
# in ---> None
# May ---> None
# and ---> None
# has ---> None
# been ---> None
# attributed ---> None
# to ---> None
# Native ---> None
# American ---> None
# , ---> punctuation mark, comma
# Colonial ---> None
# American ---> None
# and ---> None
# European ---> None
# sources ---> None
# . ---> punctuation mark, sentence closer
# Photographers ---> None
# take ---> None
# photos ---> None
# of ---> None
# the ---> None
# lunar ---> None
# eclipse ---> None
# Wednesday ---> None
# at ---> None
# the ---> None
# Central ---> None
# TV ---> None
# Tower ---> None
# in ---> None
# Beijing ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# next ---> None
# total ---> None
# lunar ---> None
# eclipse ---> None
# will ---> None
# occur ---> None
# about ---> None
# a ---> None
# year ---> None
# from ---> None
# now ---> None
# . ---> punctuation mark, sentence closer
#
#  ---> None
# But ---> None
# a ---> None
# near ---> None
# - ---> None
# total ---> None
# eclipse ---> None
# will ---> None
# come ---> None
# on ---> None
# the ---> None
# night ---> None
# of ---> None
# Nov. ---> None
# 18 ---> None
# to ---> None
# 19 ---> None
# , ---> punctuation mark, comma
# says ---> None
# Diana ---> None
# Hannikainen ---> None
# , ---> punctuation mark, comma
# observing ---> None
# editor ---> None
# at ---> None
# Sky ---> None
# & ---> None
# Telescope ---> None
# . ---> punctuation mark, sentence closer
# The ---> None
# lunar ---> None
# eclipse ---> None
# progresses ---> None
# behind ---> None
# a ---> None
# Ferris ---> None
# wheel ---> None
# over ---> None
# Santa ---> None
# Monica ---> None
# Beach ---> None
# on ---> None
# Wednesday ---> None
# in ---> None
# Santa ---> None
# Monica ---> None
# , ---> punctuation mark, comma
# Calif. ---> None
#
#  ---> None
# The ---> None
# first ---> None
# total ---> None
# lunar ---> None
# eclipse ---> None
# in ---> None
# more ---> None
# than ---> None
# two ---> None
# years ---> None
# is ---> None
# coinciding ---> None
# with ---> None
# a ---> None
# supermoon ---> None
# . ---> punctuation mark, sentence closer
# "Technically ---> None
# , ---> punctuation mark, comma
# the ---> None
# November ---> None
# event ---> None
# will ---> None
# be ---> None
# partial ---> None
# , ---> punctuation mark, comma
# but ---> None
# only ---> None
# the ---> None
# thinnest ---> None
# sliver ---> None
# of ---> None
# the ---> None
# moon ---> None
# 's ---> None
# disk ---> None
# will ---> None
# remain ---> None
# outside ---> None
# the ---> None
# umbra ---> None
# , ---> punctuation mark, comma
# so ---> None
# for ---> None
# all ---> None
# intents ---> None
# and ---> None
# purposes ---> None
# it ---> None
# 'll ---> None
# be ---> None
# very ---> None
# much ---> None
# like ---> None
# a ---> None
# total ---> None
# eclipse ---> None
# , ---> punctuation mark, comma
# " ---> None
# she ---> None
# said ---> None
# . ---> punctuation mark, sentence closer

# %% [markdown]
# ### POS tagging

# %%
for token in doc2:
    print(token.text, '--->', token.pos_, '--->', spacy.explain(token.pos_))
# Out:
# The ---> DET ---> determiner
# lunar ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# is ---> AUX ---> auxiliary
# seen ---> VERB ---> verb
# in ---> ADP ---> adposition
# Santa ---> PROPN ---> proper noun
# Monica ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# Full ---> ADJ ---> adjective
# moons ---> NOUN ---> noun
# that ---> DET ---> determiner
# occur ---> VERB ---> verb
# in ---> ADP ---> adposition
# May ---> PROPN ---> proper noun
# are ---> AUX ---> auxiliary
# sometimes ---> ADV ---> adverb
# known ---> VERB ---> verb
# as ---> ADP ---> adposition
# flower ---> NOUN ---> noun
# moons ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Maybe ---> ADV ---> adverb
# the ---> DET ---> determiner
# sky ---> NOUN ---> noun
# was ---> AUX ---> auxiliary
# cloudy ---> ADJ ---> adjective
# ; ---> PUNCT ---> punctuation
# maybe ---> ADV ---> adverb
# waking ---> VERB ---> verb
# up ---> ADP ---> adposition
# in ---> ADP ---> adposition
# the ---> DET ---> determiner
# middle ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# night ---> NOUN ---> noun
# to ---> PART ---> particle
# look ---> VERB ---> verb
# at ---> ADP ---> adposition
# the ---> DET ---> determiner
# moon ---> NOUN ---> noun
# just ---> ADV ---> adverb
# sounds ---> VERB ---> verb
# like ---> ADP ---> adposition
# lunacy ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# Whatever ---> DET ---> determiner
# the ---> DET ---> determiner
# reason ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# if ---> SCONJ ---> subordinating conjunction
# you ---> PRON ---> pronoun
# missed ---> VERB ---> verb
# seeing ---> NOUN ---> noun
# last ---> ADJ ---> adjective
# night ---> NOUN ---> noun
# 's ---> PART ---> particle
# lunar ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# you ---> PRON ---> pronoun
# 're ---> VERB ---> verb
# not ---> PART ---> particle
# alone ---> ADJ ---> adjective
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# Luckily ---> ADV ---> adverb
# , ---> PUNCT ---> punctuation
# there ---> PRON ---> pronoun
# are ---> AUX ---> auxiliary
# plenty ---> NOUN ---> noun
# of ---> ADP ---> adposition
# photos ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# video ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# rare ---> ADJ ---> adjective
# sight ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# For ---> ADP ---> adposition
# those ---> DET ---> determiner
# of ---> ADP ---> adposition
# us ---> PRON ---> pronoun
# who ---> PRON ---> pronoun
# slept ---> VERB ---> verb
# through ---> ADP ---> adposition
# the ---> DET ---> determiner
# Super ---> PROPN ---> proper noun
# Flower ---> PROPN ---> proper noun
# Blood ---> PROPN ---> proper noun
# Moon ---> PROPN ---> proper noun
# : ---> PUNCT ---> punctuation
# Here ---> ADV ---> adverb
# 's ---> VERB ---> verb
# a ---> DET ---> determiner
# quick ---> ADJ ---> adjective
# time ---> NOUN ---> noun
# lapse ---> NOUN ---> noun
# taken ---> VERB ---> verb
# early ---> ADV ---> adverb
# this ---> DET ---> determiner
# morning ---> NOUN ---> noun
# 🌷 ---> NOUN ---> noun
# 🌕 ---> NOUN ---> noun
# pic.twitter.com/Q38GJ4WrWHThe ---> PROPN ---> proper noun
# supermoon ---> ADJ ---> adjective
# — ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# Super ---> PROPN ---> proper noun
# Flower ---> PROPN ---> proper noun
# Blood ---> PROPN ---> proper noun
# Moon ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# to ---> PART ---> particle
# be ---> VERB ---> verb
# exact ---> ADJ ---> adjective
# — ---> PUNCT ---> punctuation
# brought ---> VERB ---> verb
# the ---> DET ---> determiner
# first ---> ADJ ---> adjective
# total ---> ADJ ---> adjective
# lunar ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# in ---> ADP ---> adposition
# nearly ---> ADV ---> adverb
# 2 ---> NUM ---> numeral
# 1/2 ---> NUM ---> numeral
# years ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# treating ---> VERB ---> verb
# sky ---> NOUN ---> noun
# watchers ---> NOUN ---> noun
# to ---> ADP ---> adposition
# the ---> DET ---> determiner
# sight ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# moon ---> NOUN ---> noun
# slipping ---> VERB ---> verb
# into ---> ADP ---> adposition
# Earth ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# shadow ---> NOUN ---> noun
# while ---> SCONJ ---> subordinating conjunction
# also ---> ADV ---> adverb
# appearing ---> VERB ---> verb
# around ---> ADP ---> adposition
# 7 ---> NUM ---> numeral
# % ---> NOUN ---> noun
# larger ---> ADJ ---> adjective
# than ---> SCONJ ---> subordinating conjunction
# it ---> PRON ---> pronoun
# normally ---> ADV ---> adverb
# does ---> VERB ---> verb
# . ---> PUNCT ---> punctuation
# Residents ---> NOUN ---> noun
# watch ---> VERB ---> verb
# the ---> DET ---> determiner
# lunar ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# Wednesday ---> PROPN ---> proper noun
# at ---> ADP ---> adposition
# Sanur ---> PROPN ---> proper noun
# beach ---> NOUN ---> noun
# in ---> ADP ---> adposition
# Indonesia ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# Bali ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# The ---> DET ---> determiner
# reddish ---> ADJ ---> adjective
# - ---> PUNCT ---> punctuation
# orange ---> NOUN ---> noun
# color ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# supermoon ---> NOUN ---> noun
# is ---> AUX ---> auxiliary
# the ---> DET ---> determiner
# result ---> NOUN ---> noun
# of ---> ADP ---> adposition
# all ---> DET ---> determiner
# the ---> DET ---> determiner
# sunrises ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# sunsets ---> NOUN ---> noun
# in ---> ADP ---> adposition
# Earth ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# atmosphere ---> NOUN ---> noun
# projected ---> VERB ---> verb
# onto ---> ADP ---> adposition
# the ---> DET ---> determiner
# surface ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# eclipsed ---> VERB ---> verb
# moon ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# People ---> NOUN ---> noun
# on ---> ADP ---> adposition
# both ---> DET ---> determiner
# sides ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# Pacific ---> PROPN ---> proper noun
# Ocean ---> PROPN ---> proper noun
# were ---> AUX ---> auxiliary
# able ---> ADJ ---> adjective
# to ---> PART ---> particle
# see ---> VERB ---> verb
# the ---> DET ---> determiner
# total ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# from ---> ADP ---> adposition
# the ---> DET ---> determiner
# Western ---> ADJ ---> adjective
# U.S. ---> PROPN ---> proper noun
# and ---> CCONJ ---> coordinating conjunction
# Mexico ---> PROPN ---> proper noun
# to ---> ADP ---> adposition
# New ---> PROPN ---> proper noun
# Zealand ---> PROPN ---> proper noun
# and ---> CCONJ ---> coordinating conjunction
# eastern ---> PROPN ---> proper noun
# Australia ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# Some ---> DET ---> determiner
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# best ---> ADJ ---> adjective
# views ---> NOUN ---> noun
# were ---> AUX ---> auxiliary
# in ---> ADP ---> adposition
# Hawaii ---> PROPN ---> proper noun
# and ---> CCONJ ---> coordinating conjunction
# the ---> DET ---> determiner
# Pacific ---> PROPN ---> proper noun
# islands ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# biggest ---> ADJ ---> adjective
# draw ---> NOUN ---> noun
# of ---> ADP ---> adposition
# this ---> DET ---> determiner
# celestial ---> ADJ ---> adjective
# event ---> NOUN ---> noun
# is ---> AUX ---> auxiliary
# that ---> SCONJ ---> subordinating conjunction
# a ---> DET ---> determiner
# supermoon ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# a ---> DET ---> determiner
# total ---> ADJ ---> adjective
# lunar ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# are ---> AUX ---> auxiliary
# occurring ---> VERB ---> verb
# simultaneously ---> ADV ---> adverb
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# In ---> ADP ---> adposition
# the ---> DET ---> determiner
# past ---> ADJ ---> adjective
# 10 ---> NUM ---> numeral
# years ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# there ---> PRON ---> pronoun
# have ---> AUX ---> auxiliary
# been ---> VERB ---> verb
# just ---> ADV ---> adverb
# 10 ---> NUM ---> numeral
# total ---> ADJ ---> adjective
# lunar ---> ADJ ---> adjective
# eclipses ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# A ---> DET ---> determiner
# lunar ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# is ---> AUX ---> auxiliary
# observed ---> VERB ---> verb
# Wednesday ---> PROPN ---> proper noun
# in ---> ADP ---> adposition
# Brasilia ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# Brazil ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# supermoon ---> NOUN ---> noun
# was ---> AUX ---> auxiliary
# visible ---> ADJ ---> adjective
# all ---> ADV ---> adverb
# over ---> ADP ---> adposition
# the ---> DET ---> determiner
# world ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# but ---> CCONJ ---> coordinating conjunction
# the ---> DET ---> determiner
# full ---> ADJ ---> adjective
# lunar ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# was ---> VERB ---> verb
# visible ---> ADJ ---> adjective
# in ---> ADP ---> adposition
# many ---> ADJ ---> adjective
# parts ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# world ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# Observers ---> NOUN ---> noun
# had ---> VERB ---> verb
# to ---> PART ---> particle
# look ---> VERB ---> verb
# fast ---> ADV ---> adverb
# ; ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# total ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# lasted ---> VERB ---> verb
# around ---> ADV ---> adverb
# 15 ---> NUM ---> numeral
# minutes ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# unusual ---> ADJ ---> adjective
# name ---> NOUN ---> noun
# for ---> ADP ---> adposition
# this ---> DET ---> determiner
# moon ---> NOUN ---> noun
# is ---> AUX ---> auxiliary
# due ---> ADJ ---> adjective
# to ---> ADP ---> adposition
# several ---> ADJ ---> adjective
# astronomical ---> ADJ ---> adjective
# phenomena ---> NOUN ---> noun
# coinciding ---> VERB ---> verb
# in ---> ADP ---> adposition
# one ---> NUM ---> numeral
# event ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# "Blood ---> PUNCT ---> punctuation
# " ---> PUNCT ---> punctuation
# : ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# moon ---> NOUN ---> noun
# takes ---> VERB ---> verb
# on ---> ADP ---> adposition
# a ---> DET ---> determiner
# red ---> ADJ ---> adjective
# hue ---> NOUN ---> noun
# as ---> ADP ---> adposition
# it ---> PRON ---> pronoun
# aligns ---> VERB ---> verb
# with ---> ADP ---> adposition
# the ---> DET ---> determiner
# sun ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# Earth ---> PROPN ---> proper noun
# and ---> CCONJ ---> coordinating conjunction
# passes ---> VERB ---> verb
# fully ---> ADV ---> adverb
# into ---> ADP ---> adposition
# Earth ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# shadow ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# or ---> CCONJ ---> coordinating conjunction
# umbra ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# The ---> DET ---> determiner
# distinct ---> ADJ ---> adjective
# bloodlike ---> ADJ ---> adjective
# color ---> NOUN ---> noun
# is ---> AUX ---> auxiliary
# caused ---> VERB ---> verb
# by ---> ADP ---> adposition
# red ---> ADJ ---> adjective
# - ---> PUNCT ---> punctuation
# orange ---> NOUN ---> noun
# light ---> NOUN ---> noun
# refracted ---> VERB ---> verb
# through ---> ADP ---> adposition
# the ---> DET ---> determiner
# Earth ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# atmosphere ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# The ---> DET ---> determiner
# red ---> ADJ ---> adjective
# hue ---> NOUN ---> noun
# can ---> AUX ---> auxiliary
# appear ---> VERB ---> verb
# more ---> ADV ---> adverb
# intense ---> ADJ ---> adjective
# if ---> SCONJ ---> subordinating conjunction
# more ---> ADJ ---> adjective
# clouds ---> NOUN ---> noun
# or ---> CCONJ ---> coordinating conjunction
# dust ---> NOUN ---> noun
# are ---> VERB ---> verb
# in ---> ADP ---> adposition
# the ---> DET ---> determiner
# Earth ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# atmosphere ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# according ---> VERB ---> verb
# to ---> ADP ---> adposition
# NASA.A ---> PROPN ---> proper noun
# surfer ---> NOUN ---> noun
# rides ---> VERB ---> verb
# a ---> DET ---> determiner
# wave ---> NOUN ---> noun
# Wednesday ---> PROPN ---> proper noun
# as ---> ADP ---> adposition
# a ---> DET ---> determiner
# supermoon ---> NOUN ---> noun
# rises ---> VERB ---> verb
# above ---> ADP ---> adposition
# the ---> DET ---> determiner
# horizon ---> NOUN ---> noun
# at ---> ADP ---> adposition
# Manly ---> PROPN ---> proper noun
# Beach ---> PROPN ---> proper noun
# in ---> ADP ---> adposition
# Sydney ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# "Super ---> PUNCT ---> punctuation
# " ---> PUNCT ---> punctuation
# : ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# shape ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# moon ---> NOUN ---> noun
# 's ---> PART ---> particle
# orbit ---> NOUN ---> noun
# around ---> ADP ---> adposition
# the ---> DET ---> determiner
# Earth ---> PROPN ---> proper noun
# is ---> AUX ---> auxiliary
# not ---> PART ---> particle
# a ---> DET ---> determiner
# perfect ---> ADJ ---> adjective
# circle ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# but ---> CCONJ ---> coordinating conjunction
# an ---> DET ---> determiner
# oval ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# When ---> ADV ---> adverb
# a ---> DET ---> determiner
# full ---> ADJ ---> adjective
# moon ---> NOUN ---> noun
# reaches ---> VERB ---> verb
# the ---> DET ---> determiner
# point ---> NOUN ---> noun
# closest ---> ADJ ---> adjective
# to ---> ADP ---> adposition
# our ---> PRON ---> pronoun
# planet ---> NOUN ---> noun
# on ---> ADP ---> adposition
# its ---> PRON ---> pronoun
# elliptical ---> ADJ ---> adjective
# orbit ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# it ---> PRON ---> pronoun
# 's ---> AUX ---> auxiliary
# called ---> VERB ---> verb
# a ---> DET ---> determiner
# supermoon ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# or ---> CCONJ ---> coordinating conjunction
# perigee ---> NOUN ---> noun
# - ---> PUNCT ---> punctuation
# syzygy ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# and ---> CCONJ ---> coordinating conjunction
# appears ---> VERB ---> verb
# larger ---> ADJ ---> adjective
# than ---> SCONJ ---> subordinating conjunction
# usual ---> ADJ ---> adjective
# in ---> ADP ---> adposition
# the ---> DET ---> determiner
# sky ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# Supermoons ---> NOUN ---> noun
# are ---> AUX ---> auxiliary
# more ---> ADV ---> adverb
# common ---> ADJ ---> adjective
# than ---> SCONJ ---> subordinating conjunction
# total ---> ADJ ---> adjective
# eclipses ---> NOUN ---> noun
# — ---> PUNCT ---> punctuation
# they ---> PRON ---> pronoun
# typically ---> ADV ---> adverb
# occur ---> VERB ---> verb
# several ---> ADJ ---> adjective
# times ---> NOUN ---> noun
# a ---> DET ---> determiner
# year ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# moon ---> NOUN ---> noun
# rises ---> VERB ---> verb
# over ---> ADP ---> adposition
# Victoria ---> PROPN ---> proper noun
# Harbour ---> PROPN ---> proper noun
# in ---> ADP ---> adposition
# Hong ---> PROPN ---> proper noun
# Kong ---> PROPN ---> proper noun
# on ---> ADP ---> adposition
# Wednesday ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# "Flower ---> NOUN ---> noun
# " ---> PUNCT ---> punctuation
# : ---> PUNCT ---> punctuation
# Full ---> ADJ ---> adjective
# moons ---> NOUN ---> noun
# that ---> DET ---> determiner
# occur ---> VERB ---> verb
# in ---> ADP ---> adposition
# May ---> PROPN ---> proper noun
# are ---> AUX ---> auxiliary
# sometimes ---> ADV ---> adverb
# known ---> VERB ---> verb
# as ---> ADP ---> adposition
# flower ---> NOUN ---> noun
# moons ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# According ---> VERB ---> verb
# to ---> ADP ---> adposition
# The ---> DET ---> determiner
# Old ---> PROPN ---> proper noun
# Farmer ---> PROPN ---> proper noun
# 's ---> PART ---> particle
# Almanac ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# name ---> NOUN ---> noun
# is ---> AUX ---> auxiliary
# a ---> DET ---> determiner
# reference ---> NOUN ---> noun
# to ---> ADP ---> adposition
# the ---> DET ---> determiner
# flowers ---> NOUN ---> noun
# that ---> DET ---> determiner
# are ---> AUX ---> auxiliary
# blooming ---> VERB ---> verb
# in ---> ADP ---> adposition
# May ---> PROPN ---> proper noun
# and ---> CCONJ ---> coordinating conjunction
# has ---> AUX ---> auxiliary
# been ---> AUX ---> auxiliary
# attributed ---> VERB ---> verb
# to ---> ADP ---> adposition
# Native ---> ADJ ---> adjective
# American ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# Colonial ---> PROPN ---> proper noun
# American ---> ADJ ---> adjective
# and ---> CCONJ ---> coordinating conjunction
# European ---> ADJ ---> adjective
# sources ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# Photographers ---> NOUN ---> noun
# take ---> VERB ---> verb
# photos ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# lunar ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# Wednesday ---> PROPN ---> proper noun
# at ---> ADP ---> adposition
# the ---> DET ---> determiner
# Central ---> PROPN ---> proper noun
# TV ---> PROPN ---> proper noun
# Tower ---> PROPN ---> proper noun
# in ---> ADP ---> adposition
# Beijing ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# next ---> ADJ ---> adjective
# total ---> ADJ ---> adjective
# lunar ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# will ---> AUX ---> auxiliary
# occur ---> VERB ---> verb
# about ---> ADV ---> adverb
# a ---> DET ---> determiner
# year ---> NOUN ---> noun
# from ---> ADP ---> adposition
# now ---> ADV ---> adverb
# . ---> PUNCT ---> punctuation
#
#  ---> SPACE ---> space
# But ---> CCONJ ---> coordinating conjunction
# a ---> DET ---> determiner
# near ---> ADJ ---> adjective
# - ---> PUNCT ---> punctuation
# total ---> NOUN ---> noun
# eclipse ---> NOUN ---> noun
# will ---> AUX ---> auxiliary
# come ---> VERB ---> verb
# on ---> ADP ---> adposition
# the ---> DET ---> determiner
# night ---> NOUN ---> noun
# of ---> ADP ---> adposition
# Nov. ---> PROPN ---> proper noun
# 18 ---> NUM ---> numeral
# to ---> PART ---> particle
# 19 ---> NUM ---> numeral
# , ---> PUNCT ---> punctuation
# says ---> VERB ---> verb
# Diana ---> PROPN ---> proper noun
# Hannikainen ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# observing ---> VERB ---> verb
# editor ---> NOUN ---> noun
# at ---> ADP ---> adposition
# Sky ---> PROPN ---> proper noun
# & ---> CCONJ ---> coordinating conjunction
# Telescope ---> PROPN ---> proper noun
# . ---> PUNCT ---> punctuation
# The ---> DET ---> determiner
# lunar ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# progresses ---> VERB ---> verb
# behind ---> ADP ---> adposition
# a ---> DET ---> determiner
# Ferris ---> PROPN ---> proper noun
# wheel ---> NOUN ---> noun
# over ---> ADP ---> adposition
# Santa ---> PROPN ---> proper noun
# Monica ---> PROPN ---> proper noun
# Beach ---> PROPN ---> proper noun
# on ---> ADP ---> adposition
# Wednesday ---> PROPN ---> proper noun
# in ---> ADP ---> adposition
# Santa ---> PROPN ---> proper noun
# Monica ---> PROPN ---> proper noun
# , ---> PUNCT ---> punctuation
# Calif. ---> PROPN ---> proper noun
#
#  ---> SPACE ---> space
# The ---> DET ---> determiner
# first ---> ADJ ---> adjective
# total ---> ADJ ---> adjective
# lunar ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# in ---> ADP ---> adposition
# more ---> ADJ ---> adjective
# than ---> SCONJ ---> subordinating conjunction
# two ---> NUM ---> numeral
# years ---> NOUN ---> noun
# is ---> AUX ---> auxiliary
# coinciding ---> VERB ---> verb
# with ---> ADP ---> adposition
# a ---> DET ---> determiner
# supermoon ---> NOUN ---> noun
# . ---> PUNCT ---> punctuation
# "Technically ---> ADV ---> adverb
# , ---> PUNCT ---> punctuation
# the ---> DET ---> determiner
# November ---> PROPN ---> proper noun
# event ---> NOUN ---> noun
# will ---> AUX ---> auxiliary
# be ---> VERB ---> verb
# partial ---> ADJ ---> adjective
# , ---> PUNCT ---> punctuation
# but ---> CCONJ ---> coordinating conjunction
# only ---> ADV ---> adverb
# the ---> DET ---> determiner
# thinnest ---> ADJ ---> adjective
# sliver ---> NOUN ---> noun
# of ---> ADP ---> adposition
# the ---> DET ---> determiner
# moon ---> NOUN ---> noun
# 's ---> PART ---> particle
# disk ---> NOUN ---> noun
# will ---> AUX ---> auxiliary
# remain ---> VERB ---> verb
# outside ---> ADP ---> adposition
# the ---> DET ---> determiner
# umbra ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# so ---> CCONJ ---> coordinating conjunction
# for ---> ADP ---> adposition
# all ---> DET ---> determiner
# intents ---> NOUN ---> noun
# and ---> CCONJ ---> coordinating conjunction
# purposes ---> NOUN ---> noun
# it ---> PRON ---> pronoun
# 'll ---> AUX ---> auxiliary
# be ---> VERB ---> verb
# very ---> ADV ---> adverb
# much ---> ADV ---> adverb
# like ---> ADP ---> adposition
# a ---> DET ---> determiner
# total ---> ADJ ---> adjective
# eclipse ---> NOUN ---> noun
# , ---> PUNCT ---> punctuation
# " ---> PUNCT ---> punctuation
# she ---> PRON ---> pronoun
# said ---> VERB ---> verb
# . ---> PUNCT ---> punctuation

# %% [markdown]
# ### Dependency Parsing

# %%
for token in doc2:
    print(token.text, '--->', token.dep_, '--->', spacy.explain(token.dep_))
# Out:
# The ---> det ---> determiner
# lunar ---> amod ---> adjectival modifier
# eclipse ---> nsubjpass ---> nominal subject (passive)
# is ---> auxpass ---> auxiliary (passive)
# seen ---> ROOT ---> None
# in ---> prep ---> prepositional modifier
# Santa ---> compound ---> compound
# Monica ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# Full ---> amod ---> adjectival modifier
# moons ---> nsubjpass ---> nominal subject (passive)
# that ---> nsubj ---> nominal subject
# occur ---> relcl ---> relative clause modifier
# in ---> prep ---> prepositional modifier
# May ---> pobj ---> object of preposition
# are ---> auxpass ---> auxiliary (passive)
# sometimes ---> advmod ---> adverbial modifier
# known ---> ROOT ---> None
# as ---> prep ---> prepositional modifier
# flower ---> compound ---> compound
# moons ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# Maybe ---> advmod ---> adverbial modifier
# the ---> det ---> determiner
# sky ---> nsubj ---> nominal subject
# was ---> ccomp ---> clausal complement
# cloudy ---> acomp ---> adjectival complement
# ; ---> punct ---> punctuation
# maybe ---> advmod ---> adverbial modifier
# waking ---> csubj ---> clausal subject
# up ---> prt ---> particle
# in ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# middle ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# night ---> pobj ---> object of preposition
# to ---> aux ---> auxiliary
# look ---> advcl ---> adverbial clause modifier
# at ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# moon ---> pobj ---> object of preposition
# just ---> advmod ---> adverbial modifier
# sounds ---> ROOT ---> None
# like ---> prep ---> prepositional modifier
# lunacy ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# Whatever ---> dep ---> unclassified dependent
# the ---> det ---> determiner
# reason ---> nsubj ---> nominal subject
# , ---> punct ---> punctuation
# if ---> mark ---> marker
# you ---> nsubj ---> nominal subject
# missed ---> advcl ---> adverbial clause modifier
# seeing ---> dobj ---> direct object
# last ---> amod ---> adjectival modifier
# night ---> poss ---> possession modifier
# 's ---> case ---> case marking
# lunar ---> amod ---> adjectival modifier
# eclipse ---> dobj ---> direct object
# , ---> punct ---> punctuation
# you ---> nsubj ---> nominal subject
# 're ---> ROOT ---> None
# not ---> neg ---> negation modifier
# alone ---> acomp ---> adjectival complement
# . ---> punct ---> punctuation
#
#  ---> punct ---> punctuation
# Luckily ---> advmod ---> adverbial modifier
# , ---> punct ---> punctuation
# there ---> expl ---> expletive
# are ---> ROOT ---> None
# plenty ---> attr ---> attribute
# of ---> prep ---> prepositional modifier
# photos ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# video ---> conj ---> conjunct
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# rare ---> amod ---> adjectival modifier
# sight ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# For ---> prep ---> prepositional modifier
# those ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# us ---> pobj ---> object of preposition
# who ---> nsubj ---> nominal subject
# slept ---> relcl ---> relative clause modifier
# through ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# Super ---> compound ---> compound
# Flower ---> compound ---> compound
# Blood ---> compound ---> compound
# Moon ---> pobj ---> object of preposition
# : ---> punct ---> punctuation
# Here ---> advmod ---> adverbial modifier
# 's ---> advcl ---> adverbial clause modifier
# a ---> det ---> determiner
# quick ---> amod ---> adjectival modifier
# time ---> compound ---> compound
# lapse ---> nsubj ---> nominal subject
# taken ---> acl ---> clausal modifier of noun (adjectival clause)
# early ---> advmod ---> adverbial modifier
# this ---> det ---> determiner
# morning ---> compound ---> compound
# 🌷 ---> compound ---> compound
# 🌕 ---> dobj ---> direct object
# pic.twitter.com/Q38GJ4WrWHThe ---> nsubj ---> nominal subject
# supermoon ---> ccomp ---> clausal complement
# — ---> punct ---> punctuation
# the ---> det ---> determiner
# Super ---> compound ---> compound
# Flower ---> compound ---> compound
# Blood ---> compound ---> compound
# Moon ---> appos ---> appositional modifier
# , ---> punct ---> punctuation
# to ---> aux ---> auxiliary
# be ---> advcl ---> adverbial clause modifier
# exact ---> acomp ---> adjectival complement
# — ---> punct ---> punctuation
# brought ---> ROOT ---> None
# the ---> det ---> determiner
# first ---> amod ---> adjectival modifier
# total ---> amod ---> adjectival modifier
# lunar ---> amod ---> adjectival modifier
# eclipse ---> dobj ---> direct object
# in ---> prep ---> prepositional modifier
# nearly ---> advmod ---> adverbial modifier
# 2 ---> compound ---> compound
# 1/2 ---> nummod ---> numeric modifier
# years ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# treating ---> advcl ---> adverbial clause modifier
# sky ---> compound ---> compound
# watchers ---> dobj ---> direct object
# to ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# sight ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# moon ---> pobj ---> object of preposition
# slipping ---> acl ---> clausal modifier of noun (adjectival clause)
# into ---> prep ---> prepositional modifier
# Earth ---> poss ---> possession modifier
# 's ---> case ---> case marking
# shadow ---> pobj ---> object of preposition
# while ---> mark ---> marker
# also ---> advmod ---> adverbial modifier
# appearing ---> advcl ---> adverbial clause modifier
# around ---> quantmod ---> modifier of quantifier
# 7 ---> nummod ---> numeric modifier
# % ---> npadvmod ---> noun phrase as adverbial modifier
# larger ---> oprd ---> object predicate
# than ---> mark ---> marker
# it ---> nsubj ---> nominal subject
# normally ---> advmod ---> adverbial modifier
# does ---> advcl ---> adverbial clause modifier
# . ---> punct ---> punctuation
# Residents ---> nsubj ---> nominal subject
# watch ---> ROOT ---> None
# the ---> det ---> determiner
# lunar ---> amod ---> adjectival modifier
# eclipse ---> dobj ---> direct object
# Wednesday ---> npadvmod ---> noun phrase as adverbial modifier
# at ---> prep ---> prepositional modifier
# Sanur ---> compound ---> compound
# beach ---> pobj ---> object of preposition
# in ---> prep ---> prepositional modifier
# Indonesia ---> poss ---> possession modifier
# 's ---> case ---> case marking
# Bali ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
#
#  ---> punct ---> punctuation
# The ---> det ---> determiner
# reddish ---> amod ---> adjectival modifier
# - ---> punct ---> punctuation
# orange ---> compound ---> compound
# color ---> nsubj ---> nominal subject
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# supermoon ---> pobj ---> object of preposition
# is ---> ROOT ---> None
# the ---> det ---> determiner
# result ---> attr ---> attribute
# of ---> prep ---> prepositional modifier
# all ---> predet ---> None
# the ---> det ---> determiner
# sunrises ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# sunsets ---> conj ---> conjunct
# in ---> prep ---> prepositional modifier
# Earth ---> poss ---> possession modifier
# 's ---> case ---> case marking
# atmosphere ---> pobj ---> object of preposition
# projected ---> acl ---> clausal modifier of noun (adjectival clause)
# onto ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# surface ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# eclipsed ---> amod ---> adjectival modifier
# moon ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# People ---> nsubj ---> nominal subject
# on ---> prep ---> prepositional modifier
# both ---> det ---> determiner
# sides ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# Pacific ---> compound ---> compound
# Ocean ---> pobj ---> object of preposition
# were ---> ROOT ---> None
# able ---> acomp ---> adjectival complement
# to ---> aux ---> auxiliary
# see ---> xcomp ---> open clausal complement
# the ---> det ---> determiner
# total ---> amod ---> adjectival modifier
# eclipse ---> dobj ---> direct object
# , ---> punct ---> punctuation
# from ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# Western ---> amod ---> adjectival modifier
# U.S. ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# Mexico ---> conj ---> conjunct
# to ---> prep ---> prepositional modifier
# New ---> compound ---> compound
# Zealand ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# eastern ---> compound ---> compound
# Australia ---> conj ---> conjunct
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# Some ---> nsubj ---> nominal subject
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# best ---> amod ---> adjectival modifier
# views ---> pobj ---> object of preposition
# were ---> ROOT ---> None
# in ---> prep ---> prepositional modifier
# Hawaii ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# the ---> det ---> determiner
# Pacific ---> compound ---> compound
# islands ---> conj ---> conjunct
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# biggest ---> amod ---> adjectival modifier
# draw ---> nsubj ---> nominal subject
# of ---> prep ---> prepositional modifier
# this ---> det ---> determiner
# celestial ---> amod ---> adjectival modifier
# event ---> pobj ---> object of preposition
# is ---> ROOT ---> None
# that ---> mark ---> marker
# a ---> det ---> determiner
# supermoon ---> nsubj ---> nominal subject
# and ---> cc ---> coordinating conjunction
# a ---> det ---> determiner
# total ---> amod ---> adjectival modifier
# lunar ---> amod ---> adjectival modifier
# eclipse ---> conj ---> conjunct
# are ---> aux ---> auxiliary
# occurring ---> ccomp ---> clausal complement
# simultaneously ---> advmod ---> adverbial modifier
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# In ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# past ---> amod ---> adjectival modifier
# 10 ---> nummod ---> numeric modifier
# years ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# there ---> expl ---> expletive
# have ---> aux ---> auxiliary
# been ---> ROOT ---> None
# just ---> advmod ---> adverbial modifier
# 10 ---> nummod ---> numeric modifier
# total ---> amod ---> adjectival modifier
# lunar ---> amod ---> adjectival modifier
# eclipses ---> attr ---> attribute
# . ---> punct ---> punctuation
# A ---> det ---> determiner
# lunar ---> amod ---> adjectival modifier
# eclipse ---> nsubjpass ---> nominal subject (passive)
# is ---> auxpass ---> auxiliary (passive)
# observed ---> ROOT ---> None
# Wednesday ---> npadvmod ---> noun phrase as adverbial modifier
# in ---> prep ---> prepositional modifier
# Brasilia ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# Brazil ---> appos ---> appositional modifier
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# supermoon ---> nsubj ---> nominal subject
# was ---> ROOT ---> None
# visible ---> acomp ---> adjectival complement
# all ---> advmod ---> adverbial modifier
# over ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# world ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# but ---> cc ---> coordinating conjunction
# the ---> det ---> determiner
# full ---> amod ---> adjectival modifier
# lunar ---> amod ---> adjectival modifier
# eclipse ---> nsubj ---> nominal subject
# was ---> conj ---> conjunct
# visible ---> acomp ---> adjectival complement
# in ---> prep ---> prepositional modifier
# many ---> amod ---> adjectival modifier
# parts ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# world ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# Observers ---> nsubj ---> nominal subject
# had ---> ccomp ---> clausal complement
# to ---> aux ---> auxiliary
# look ---> xcomp ---> open clausal complement
# fast ---> advmod ---> adverbial modifier
# ; ---> punct ---> punctuation
# the ---> det ---> determiner
# total ---> amod ---> adjectival modifier
# eclipse ---> nsubj ---> nominal subject
# lasted ---> ROOT ---> None
# around ---> advmod ---> adverbial modifier
# 15 ---> nummod ---> numeric modifier
# minutes ---> npadvmod ---> noun phrase as adverbial modifier
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# unusual ---> amod ---> adjectival modifier
# name ---> nsubj ---> nominal subject
# for ---> prep ---> prepositional modifier
# this ---> det ---> determiner
# moon ---> pobj ---> object of preposition
# is ---> ROOT ---> None
# due ---> acomp ---> adjectival complement
# to ---> prep ---> prepositional modifier
# several ---> amod ---> adjectival modifier
# astronomical ---> amod ---> adjectival modifier
# phenomena ---> nsubj ---> nominal subject
# coinciding ---> pcomp ---> complement of preposition
# in ---> prep ---> prepositional modifier
# one ---> nummod ---> numeric modifier
# event ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# "Blood ---> intj ---> interjection
# " ---> punct ---> punctuation
# : ---> punct ---> punctuation
# The ---> det ---> determiner
# moon ---> nsubj ---> nominal subject
# takes ---> ROOT ---> None
# on ---> prt ---> particle
# a ---> det ---> determiner
# red ---> amod ---> adjectival modifier
# hue ---> dobj ---> direct object
# as ---> mark ---> marker
# it ---> nsubj ---> nominal subject
# aligns ---> advcl ---> adverbial clause modifier
# with ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# sun ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# Earth ---> conj ---> conjunct
# and ---> cc ---> coordinating conjunction
# passes ---> conj ---> conjunct
# fully ---> advmod ---> adverbial modifier
# into ---> prep ---> prepositional modifier
# Earth ---> poss ---> possession modifier
# 's ---> case ---> case marking
# shadow ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# or ---> cc ---> coordinating conjunction
# umbra ---> conj ---> conjunct
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# The ---> det ---> determiner
# distinct ---> amod ---> adjectival modifier
# bloodlike ---> compound ---> compound
# color ---> nsubjpass ---> nominal subject (passive)
# is ---> auxpass ---> auxiliary (passive)
# caused ---> ROOT ---> None
# by ---> agent ---> agent
# red ---> amod ---> adjectival modifier
# - ---> punct ---> punctuation
# orange ---> compound ---> compound
# light ---> pobj ---> object of preposition
# refracted ---> acl ---> clausal modifier of noun (adjectival clause)
# through ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# Earth ---> poss ---> possession modifier
# 's ---> case ---> case marking
# atmosphere ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# The ---> det ---> determiner
# red ---> amod ---> adjectival modifier
# hue ---> nsubj ---> nominal subject
# can ---> aux ---> auxiliary
# appear ---> ROOT ---> None
# more ---> advmod ---> adverbial modifier
# intense ---> oprd ---> object predicate
# if ---> mark ---> marker
# more ---> amod ---> adjectival modifier
# clouds ---> nsubj ---> nominal subject
# or ---> cc ---> coordinating conjunction
# dust ---> conj ---> conjunct
# are ---> advcl ---> adverbial clause modifier
# in ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# Earth ---> poss ---> possession modifier
# 's ---> case ---> case marking
# atmosphere ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# according ---> prep ---> prepositional modifier
# to ---> prep ---> prepositional modifier
# NASA.A ---> compound ---> compound
# surfer ---> pobj ---> object of preposition
# rides ---> conj ---> conjunct
# a ---> det ---> determiner
# wave ---> dobj ---> direct object
# Wednesday ---> npadvmod ---> noun phrase as adverbial modifier
# as ---> mark ---> marker
# a ---> det ---> determiner
# supermoon ---> nsubj ---> nominal subject
# rises ---> advcl ---> adverbial clause modifier
# above ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# horizon ---> pobj ---> object of preposition
# at ---> prep ---> prepositional modifier
# Manly ---> compound ---> compound
# Beach ---> pobj ---> object of preposition
# in ---> prep ---> prepositional modifier
# Sydney ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# "Super ---> punct ---> punctuation
# " ---> punct ---> punctuation
# : ---> punct ---> punctuation
# The ---> det ---> determiner
# shape ---> nsubj ---> nominal subject
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# moon ---> poss ---> possession modifier
# 's ---> case ---> case marking
# orbit ---> pobj ---> object of preposition
# around ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# Earth ---> pobj ---> object of preposition
# is ---> ROOT ---> None
# not ---> neg ---> negation modifier
# a ---> det ---> determiner
# perfect ---> amod ---> adjectival modifier
# circle ---> attr ---> attribute
# , ---> punct ---> punctuation
# but ---> cc ---> coordinating conjunction
# an ---> det ---> determiner
# oval ---> conj ---> conjunct
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# When ---> advmod ---> adverbial modifier
# a ---> det ---> determiner
# full ---> amod ---> adjectival modifier
# moon ---> nsubj ---> nominal subject
# reaches ---> advcl ---> adverbial clause modifier
# the ---> det ---> determiner
# point ---> dobj ---> direct object
# closest ---> amod ---> adjectival modifier
# to ---> prep ---> prepositional modifier
# our ---> poss ---> possession modifier
# planet ---> pobj ---> object of preposition
# on ---> prep ---> prepositional modifier
# its ---> poss ---> possession modifier
# elliptical ---> amod ---> adjectival modifier
# orbit ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# it ---> nsubjpass ---> nominal subject (passive)
# 's ---> auxpass ---> auxiliary (passive)
# called ---> ROOT ---> None
# a ---> det ---> determiner
# supermoon ---> oprd ---> object predicate
# , ---> punct ---> punctuation
# or ---> cc ---> coordinating conjunction
# perigee ---> compound ---> compound
# - ---> punct ---> punctuation
# syzygy ---> conj ---> conjunct
# , ---> punct ---> punctuation
# and ---> cc ---> coordinating conjunction
# appears ---> conj ---> conjunct
# larger ---> oprd ---> object predicate
# than ---> prep ---> prepositional modifier
# usual ---> amod ---> adjectival modifier
# in ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# sky ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# Supermoons ---> nsubj ---> nominal subject
# are ---> ccomp ---> clausal complement
# more ---> advmod ---> adverbial modifier
# common ---> acomp ---> adjectival complement
# than ---> prep ---> prepositional modifier
# total ---> amod ---> adjectival modifier
# eclipses ---> pobj ---> object of preposition
# — ---> punct ---> punctuation
# they ---> nsubj ---> nominal subject
# typically ---> advmod ---> adverbial modifier
# occur ---> ROOT ---> None
# several ---> amod ---> adjectival modifier
# times ---> npadvmod ---> noun phrase as adverbial modifier
# a ---> det ---> determiner
# year ---> npadvmod ---> noun phrase as adverbial modifier
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# moon ---> nsubj ---> nominal subject
# rises ---> ROOT ---> None
# over ---> prep ---> prepositional modifier
# Victoria ---> compound ---> compound
# Harbour ---> pobj ---> object of preposition
# in ---> prep ---> prepositional modifier
# Hong ---> compound ---> compound
# Kong ---> pobj ---> object of preposition
# on ---> prep ---> prepositional modifier
# Wednesday ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# "Flower ---> dep ---> unclassified dependent
# " ---> punct ---> punctuation
# : ---> punct ---> punctuation
# Full ---> amod ---> adjectival modifier
# moons ---> nsubjpass ---> nominal subject (passive)
# that ---> nsubj ---> nominal subject
# occur ---> relcl ---> relative clause modifier
# in ---> prep ---> prepositional modifier
# May ---> pobj ---> object of preposition
# are ---> auxpass ---> auxiliary (passive)
# sometimes ---> advmod ---> adverbial modifier
# known ---> ROOT ---> None
# as ---> prep ---> prepositional modifier
# flower ---> compound ---> compound
# moons ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# According ---> prep ---> prepositional modifier
# to ---> prep ---> prepositional modifier
# The ---> det ---> determiner
# Old ---> compound ---> compound
# Farmer ---> poss ---> possession modifier
# 's ---> case ---> case marking
# Almanac ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# the ---> det ---> determiner
# name ---> nsubj ---> nominal subject
# is ---> ROOT ---> None
# a ---> det ---> determiner
# reference ---> attr ---> attribute
# to ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# flowers ---> pobj ---> object of preposition
# that ---> nsubj ---> nominal subject
# are ---> aux ---> auxiliary
# blooming ---> relcl ---> relative clause modifier
# in ---> prep ---> prepositional modifier
# May ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# has ---> aux ---> auxiliary
# been ---> auxpass ---> auxiliary (passive)
# attributed ---> conj ---> conjunct
# to ---> prep ---> prepositional modifier
# Native ---> amod ---> adjectival modifier
# American ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# Colonial ---> nmod ---> modifier of nominal
# American ---> amod ---> adjectival modifier
# and ---> cc ---> coordinating conjunction
# European ---> conj ---> conjunct
# sources ---> conj ---> conjunct
# . ---> punct ---> punctuation
# Photographers ---> nsubj ---> nominal subject
# take ---> ROOT ---> None
# photos ---> dobj ---> direct object
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# lunar ---> amod ---> adjectival modifier
# eclipse ---> pobj ---> object of preposition
# Wednesday ---> npadvmod ---> noun phrase as adverbial modifier
# at ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# Central ---> compound ---> compound
# TV ---> compound ---> compound
# Tower ---> pobj ---> object of preposition
# in ---> prep ---> prepositional modifier
# Beijing ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# next ---> amod ---> adjectival modifier
# total ---> amod ---> adjectival modifier
# lunar ---> amod ---> adjectival modifier
# eclipse ---> nsubj ---> nominal subject
# will ---> aux ---> auxiliary
# occur ---> ROOT ---> None
# about ---> advmod ---> adverbial modifier
# a ---> nummod ---> numeric modifier
# year ---> npadvmod ---> noun phrase as adverbial modifier
# from ---> prep ---> prepositional modifier
# now ---> pcomp ---> complement of preposition
# . ---> punct ---> punctuation
#
#  ---> ROOT ---> None
# But ---> cc ---> coordinating conjunction
# a ---> det ---> determiner
# near ---> advmod ---> adverbial modifier
# - ---> punct ---> punctuation
# total ---> amod ---> adjectival modifier
# eclipse ---> nsubj ---> nominal subject
# will ---> aux ---> auxiliary
# come ---> ccomp ---> clausal complement
# on ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# night ---> pobj ---> object of preposition
# of ---> prep ---> prepositional modifier
# Nov. ---> pobj ---> object of preposition
# 18 ---> nummod ---> numeric modifier
# to ---> quantmod ---> modifier of quantifier
# 19 ---> npadvmod ---> noun phrase as adverbial modifier
# , ---> punct ---> punctuation
# says ---> ROOT ---> None
# Diana ---> compound ---> compound
# Hannikainen ---> nsubj ---> nominal subject
# , ---> punct ---> punctuation
# observing ---> amod ---> adjectival modifier
# editor ---> appos ---> appositional modifier
# at ---> prep ---> prepositional modifier
# Sky ---> pobj ---> object of preposition
# & ---> cc ---> coordinating conjunction
# Telescope ---> conj ---> conjunct
# . ---> punct ---> punctuation
# The ---> det ---> determiner
# lunar ---> amod ---> adjectival modifier
# eclipse ---> nsubj ---> nominal subject
# progresses ---> ROOT ---> None
# behind ---> prep ---> prepositional modifier
# a ---> det ---> determiner
# Ferris ---> compound ---> compound
# wheel ---> pobj ---> object of preposition
# over ---> prep ---> prepositional modifier
# Santa ---> compound ---> compound
# Monica ---> compound ---> compound
# Beach ---> pobj ---> object of preposition
# on ---> prep ---> prepositional modifier
# Wednesday ---> pobj ---> object of preposition
# in ---> prep ---> prepositional modifier
# Santa ---> compound ---> compound
# Monica ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# Calif. ---> appos ---> appositional modifier
#
#  ---> punct ---> punctuation
# The ---> det ---> determiner
# first ---> amod ---> adjectival modifier
# total ---> amod ---> adjectival modifier
# lunar ---> amod ---> adjectival modifier
# eclipse ---> nsubj ---> nominal subject
# in ---> prep ---> prepositional modifier
# more ---> amod ---> adjectival modifier
# than ---> quantmod ---> modifier of quantifier
# two ---> nummod ---> numeric modifier
# years ---> pobj ---> object of preposition
# is ---> aux ---> auxiliary
# coinciding ---> ROOT ---> None
# with ---> prep ---> prepositional modifier
# a ---> det ---> determiner
# supermoon ---> pobj ---> object of preposition
# . ---> punct ---> punctuation
# "Technically ---> advmod ---> adverbial modifier
# , ---> punct ---> punctuation
# the ---> det ---> determiner
# November ---> compound ---> compound
# event ---> nsubj ---> nominal subject
# will ---> aux ---> auxiliary
# be ---> ccomp ---> clausal complement
# partial ---> acomp ---> adjectival complement
# , ---> punct ---> punctuation
# but ---> cc ---> coordinating conjunction
# only ---> advmod ---> adverbial modifier
# the ---> det ---> determiner
# thinnest ---> amod ---> adjectival modifier
# sliver ---> nsubj ---> nominal subject
# of ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# moon ---> poss ---> possession modifier
# 's ---> case ---> case marking
# disk ---> pobj ---> object of preposition
# will ---> aux ---> auxiliary
# remain ---> conj ---> conjunct
# outside ---> prep ---> prepositional modifier
# the ---> det ---> determiner
# umbra ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# so ---> cc ---> coordinating conjunction
# for ---> prep ---> prepositional modifier
# all ---> det ---> determiner
# intents ---> pobj ---> object of preposition
# and ---> cc ---> coordinating conjunction
# purposes ---> conj ---> conjunct
# it ---> nsubj ---> nominal subject
# 'll ---> aux ---> auxiliary
# be ---> conj ---> conjunct
# very ---> advmod ---> adverbial modifier
# much ---> advmod ---> adverbial modifier
# like ---> prep ---> prepositional modifier
# a ---> det ---> determiner
# total ---> amod ---> adjectival modifier
# eclipse ---> pobj ---> object of preposition
# , ---> punct ---> punctuation
# " ---> punct ---> punctuation
# she ---> nsubj ---> nominal subject
# said ---> ROOT ---> None
# . ---> punct ---> punctuation

# %% [markdown]
# ### Lemmatization

# %%
for token in doc2:
    print(token.text, '--->', token.lemma_, '--->', spacy.explain(token.lemma_))
# Out:
# The ---> the ---> None
# lunar ---> lunar ---> None
# eclipse ---> eclipse ---> None
# is ---> be ---> None
# seen ---> see ---> None
# in ---> in ---> None
# Santa ---> Santa ---> None
# Monica ---> Monica ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# Full ---> full ---> None
# moons ---> moon ---> None
# that ---> that ---> None
# occur ---> occur ---> None
# in ---> in ---> None
# May ---> May ---> None
# are ---> be ---> None
# sometimes ---> sometimes ---> None
# known ---> know ---> None
# as ---> as ---> None
# flower ---> flower ---> None
# moons ---> moon ---> None
# . ---> . ---> punctuation mark, sentence closer
# Maybe ---> maybe ---> None
# the ---> the ---> None
# sky ---> sky ---> None
# was ---> be ---> None
# cloudy ---> cloudy ---> None
# ; ---> ; ---> None
# maybe ---> maybe ---> None
# waking ---> wake ---> None
# up ---> up ---> None
# in ---> in ---> None
# the ---> the ---> None
# middle ---> middle ---> None
# of ---> of ---> None
# the ---> the ---> None
# night ---> night ---> None
# to ---> to ---> None
# look ---> look ---> None
# at ---> at ---> None
# the ---> the ---> None
# moon ---> moon ---> None
# just ---> just ---> None
# sounds ---> sound ---> None
# like ---> like ---> None
# lunacy ---> lunacy ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# Whatever ---> whatever ---> None
# the ---> the ---> None
# reason ---> reason ---> None
# , ---> , ---> punctuation mark, comma
# if ---> if ---> None
# you ---> you ---> None
# missed ---> miss ---> None
# seeing ---> seeing ---> None
# last ---> last ---> None
# night ---> night ---> None
# 's ---> 's ---> None
# lunar ---> lunar ---> None
# eclipse ---> eclipse ---> None
# , ---> , ---> punctuation mark, comma
# you ---> you ---> None
# 're ---> be ---> None
# not ---> not ---> None
# alone ---> alone ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# Luckily ---> luckily ---> None
# , ---> , ---> punctuation mark, comma
# there ---> there ---> None
# are ---> be ---> None
# plenty ---> plenty ---> None
# of ---> of ---> None
# photos ---> photo ---> None
# and ---> and ---> None
# video ---> video ---> None
# of ---> of ---> None
# the ---> the ---> None
# rare ---> rare ---> None
# sight ---> sight ---> None
# . ---> . ---> punctuation mark, sentence closer
# For ---> for ---> None
# those ---> those ---> None
# of ---> of ---> None
# us ---> we ---> None
# who ---> who ---> None
# slept ---> sleep ---> None
# through ---> through ---> None
# the ---> the ---> None
# Super ---> Super ---> None
# Flower ---> Flower ---> None
# Blood ---> Blood ---> None
# Moon ---> Moon ---> None
# : ---> : ---> punctuation mark, colon or ellipsis
# Here ---> here ---> None
# 's ---> be ---> None
# a ---> a ---> None
# quick ---> quick ---> None
# time ---> time ---> None
# lapse ---> lapse ---> None
# taken ---> take ---> None
# early ---> early ---> None
# this ---> this ---> None
# morning ---> morning ---> None
# 🌷 ---> 🌷 ---> None
# 🌕 ---> 🌕 ---> None
# pic.twitter.com/Q38GJ4WrWHThe ---> pic.twitter.com/Q38GJ4WrWHThe ---> None
# supermoon ---> supermoon ---> None
# — ---> — ---> None
# the ---> the ---> None
# Super ---> Super ---> None
# Flower ---> Flower ---> None
# Blood ---> Blood ---> None
# Moon ---> Moon ---> None
# , ---> , ---> punctuation mark, comma
# to ---> to ---> None
# be ---> be ---> None
# exact ---> exact ---> None
# — ---> — ---> None
# brought ---> bring ---> None
# the ---> the ---> None
# first ---> first ---> None
# total ---> total ---> None
# lunar ---> lunar ---> None
# eclipse ---> eclipse ---> None
# in ---> in ---> None
# nearly ---> nearly ---> None
# 2 ---> 2 ---> None
# 1/2 ---> 1/2 ---> None
# years ---> year ---> None
# , ---> , ---> punctuation mark, comma
# treating ---> treat ---> None
# sky ---> sky ---> None
# watchers ---> watcher ---> None
# to ---> to ---> None
# the ---> the ---> None
# sight ---> sight ---> None
# of ---> of ---> None
# the ---> the ---> None
# moon ---> moon ---> None
# slipping ---> slip ---> None
# into ---> into ---> None
# Earth ---> Earth ---> None
# 's ---> 's ---> None
# shadow ---> shadow ---> None
# while ---> while ---> None
# also ---> also ---> None
# appearing ---> appear ---> None
# around ---> around ---> None
# 7 ---> 7 ---> None
# % ---> % ---> None
# larger ---> large ---> None
# than ---> than ---> None
# it ---> it ---> None
# normally ---> normally ---> None
# does ---> do ---> None
# . ---> . ---> punctuation mark, sentence closer
# Residents ---> resident ---> None
# watch ---> watch ---> None
# the ---> the ---> None
# lunar ---> lunar ---> None
# eclipse ---> eclipse ---> None
# Wednesday ---> Wednesday ---> None
# at ---> at ---> None
# Sanur ---> Sanur ---> None
# beach ---> beach ---> None
# in ---> in ---> None
# Indonesia ---> Indonesia ---> None
# 's ---> 's ---> None
# Bali ---> bali ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# The ---> the ---> None
# reddish ---> reddish ---> None
# - ---> - ---> None
# orange ---> orange ---> None
# color ---> color ---> None
# of ---> of ---> None
# the ---> the ---> None
# supermoon ---> supermoon ---> None
# is ---> be ---> None
# the ---> the ---> None
# result ---> result ---> None
# of ---> of ---> None
# all ---> all ---> None
# the ---> the ---> None
# sunrises ---> sunrise ---> None
# and ---> and ---> None
# sunsets ---> sunset ---> None
# in ---> in ---> None
# Earth ---> Earth ---> None
# 's ---> 's ---> None
# atmosphere ---> atmosphere ---> None
# projected ---> project ---> None
# onto ---> onto ---> None
# the ---> the ---> None
# surface ---> surface ---> None
# of ---> of ---> None
# the ---> the ---> None
# eclipsed ---> eclipse ---> None
# moon ---> moon ---> None
# . ---> . ---> punctuation mark, sentence closer
# People ---> People ---> None
# on ---> on ---> None
# both ---> both ---> None
# sides ---> side ---> None
# of ---> of ---> None
# the ---> the ---> None
# Pacific ---> Pacific ---> None
# Ocean ---> Ocean ---> None
# were ---> be ---> None
# able ---> able ---> None
# to ---> to ---> None
# see ---> see ---> None
# the ---> the ---> None
# total ---> total ---> None
# eclipse ---> eclipse ---> None
# , ---> , ---> punctuation mark, comma
# from ---> from ---> None
# the ---> the ---> None
# Western ---> western ---> None
# U.S. ---> U.S. ---> None
# and ---> and ---> None
# Mexico ---> Mexico ---> None
# to ---> to ---> None
# New ---> New ---> None
# Zealand ---> Zealand ---> None
# and ---> and ---> None
# eastern ---> eastern ---> None
# Australia ---> Australia ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# Some ---> some ---> None
# of ---> of ---> None
# the ---> the ---> None
# best ---> good ---> None
# views ---> view ---> None
# were ---> be ---> None
# in ---> in ---> None
# Hawaii ---> Hawaii ---> None
# and ---> and ---> None
# the ---> the ---> None
# Pacific ---> Pacific ---> None
# islands ---> island ---> None
# . ---> . ---> punctuation mark, sentence closer
# The ---> the ---> None
# biggest ---> big ---> None
# draw ---> draw ---> None
# of ---> of ---> None
# this ---> this ---> None
# celestial ---> celestial ---> None
# event ---> event ---> None
# is ---> be ---> None
# that ---> that ---> None
# a ---> a ---> None
# supermoon ---> supermoon ---> None
# and ---> and ---> None
# a ---> a ---> None
# total ---> total ---> None
# lunar ---> lunar ---> None
# eclipse ---> eclipse ---> None
# are ---> be ---> None
# occurring ---> occur ---> None
# simultaneously ---> simultaneously ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# In ---> in ---> None
# the ---> the ---> None
# past ---> past ---> None
# 10 ---> 10 ---> None
# years ---> year ---> None
# , ---> , ---> punctuation mark, comma
# there ---> there ---> None
# have ---> have ---> None
# been ---> be ---> None
# just ---> just ---> None
# 10 ---> 10 ---> None
# total ---> total ---> None
# lunar ---> lunar ---> None
# eclipses ---> eclipse ---> None
# . ---> . ---> punctuation mark, sentence closer
# A ---> a ---> None
# lunar ---> lunar ---> None
# eclipse ---> eclipse ---> None
# is ---> be ---> None
# observed ---> observe ---> None
# Wednesday ---> Wednesday ---> None
# in ---> in ---> None
# Brasilia ---> Brasilia ---> None
# , ---> , ---> punctuation mark, comma
# Brazil ---> Brazil ---> None
# . ---> . ---> punctuation mark, sentence closer
# The ---> the ---> None
# supermoon ---> supermoon ---> None
# was ---> be ---> None
# visible ---> visible ---> None
# all ---> all ---> None
# over ---> over ---> None
# the ---> the ---> None
# world ---> world ---> None
# , ---> , ---> punctuation mark, comma
# but ---> but ---> None
# the ---> the ---> None
# full ---> full ---> None
# lunar ---> lunar ---> None
# eclipse ---> eclipse ---> None
# was ---> be ---> None
# visible ---> visible ---> None
# in ---> in ---> None
# many ---> many ---> None
# parts ---> part ---> None
# of ---> of ---> None
# the ---> the ---> None
# world ---> world ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# Observers ---> observer ---> None
# had ---> have ---> None
# to ---> to ---> None
# look ---> look ---> None
# fast ---> fast ---> None
# ; ---> ; ---> None
# the ---> the ---> None
# total ---> total ---> None
# eclipse ---> eclipse ---> None
# lasted ---> last ---> None
# around ---> around ---> None
# 15 ---> 15 ---> None
# minutes ---> minute ---> None
# . ---> . ---> punctuation mark, sentence closer
# The ---> the ---> None
# unusual ---> unusual ---> None
# name ---> name ---> None
# for ---> for ---> None
# this ---> this ---> None
# moon ---> moon ---> None
# is ---> be ---> None
# due ---> due ---> None
# to ---> to ---> None
# several ---> several ---> None
# astronomical ---> astronomical ---> None
# phenomena ---> phenomenon ---> None
# coinciding ---> coincide ---> None
# in ---> in ---> None
# one ---> one ---> None
# event ---> event ---> None
# . ---> . ---> punctuation mark, sentence closer
# "Blood ---> "Blood ---> None
# " ---> " ---> None
# : ---> : ---> punctuation mark, colon or ellipsis
# The ---> the ---> None
# moon ---> moon ---> None
# takes ---> take ---> None
# on ---> on ---> None
# a ---> a ---> None
# red ---> red ---> None
# hue ---> hue ---> None
# as ---> as ---> None
# it ---> it ---> None
# aligns ---> align ---> None
# with ---> with ---> None
# the ---> the ---> None
# sun ---> sun ---> None
# and ---> and ---> None
# Earth ---> Earth ---> None
# and ---> and ---> None
# passes ---> pass ---> None
# fully ---> fully ---> None
# into ---> into ---> None
# Earth ---> Earth ---> None
# 's ---> 's ---> None
# shadow ---> shadow ---> None
# , ---> , ---> punctuation mark, comma
# or ---> or ---> None
# umbra ---> umbra ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# The ---> the ---> None
# distinct ---> distinct ---> None
# bloodlike ---> bloodlike ---> None
# color ---> color ---> None
# is ---> be ---> None
# caused ---> cause ---> None
# by ---> by ---> None
# red ---> red ---> None
# - ---> - ---> None
# orange ---> orange ---> None
# light ---> light ---> None
# refracted ---> refract ---> None
# through ---> through ---> None
# the ---> the ---> None
# Earth ---> Earth ---> None
# 's ---> 's ---> None
# atmosphere ---> atmosphere ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# The ---> the ---> None
# red ---> red ---> None
# hue ---> hue ---> None
# can ---> can ---> None
# appear ---> appear ---> None
# more ---> more ---> None
# intense ---> intense ---> None
# if ---> if ---> None
# more ---> more ---> None
# clouds ---> cloud ---> None
# or ---> or ---> None
# dust ---> dust ---> None
# are ---> be ---> None
# in ---> in ---> None
# the ---> the ---> None
# Earth ---> Earth ---> None
# 's ---> 's ---> None
# atmosphere ---> atmosphere ---> None
# , ---> , ---> punctuation mark, comma
# according ---> accord ---> None
# to ---> to ---> None
# NASA.A ---> NASA.A ---> None
# surfer ---> surfer ---> None
# rides ---> ride ---> None
# a ---> a ---> None
# wave ---> wave ---> None
# Wednesday ---> Wednesday ---> None
# as ---> as ---> None
# a ---> a ---> None
# supermoon ---> supermoon ---> None
# rises ---> rise ---> None
# above ---> above ---> None
# the ---> the ---> None
# horizon ---> horizon ---> None
# at ---> at ---> None
# Manly ---> Manly ---> None
# Beach ---> Beach ---> None
# in ---> in ---> None
# Sydney ---> Sydney ---> None
# . ---> . ---> punctuation mark, sentence closer
# "Super ---> "Super ---> None
# " ---> " ---> None
# : ---> : ---> punctuation mark, colon or ellipsis
# The ---> the ---> None
# shape ---> shape ---> None
# of ---> of ---> None
# the ---> the ---> None
# moon ---> moon ---> None
# 's ---> 's ---> None
# orbit ---> orbit ---> None
# around ---> around ---> None
# the ---> the ---> None
# Earth ---> Earth ---> None
# is ---> be ---> None
# not ---> not ---> None
# a ---> a ---> None
# perfect ---> perfect ---> None
# circle ---> circle ---> None
# , ---> , ---> punctuation mark, comma
# but ---> but ---> None
# an ---> an ---> None
# oval ---> oval ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# When ---> when ---> None
# a ---> a ---> None
# full ---> full ---> None
# moon ---> moon ---> None
# reaches ---> reach ---> None
# the ---> the ---> None
# point ---> point ---> None
# closest ---> close ---> None
# to ---> to ---> None
# our ---> our ---> None
# planet ---> planet ---> None
# on ---> on ---> None
# its ---> its ---> None
# elliptical ---> elliptical ---> None
# orbit ---> orbit ---> None
# , ---> , ---> punctuation mark, comma
# it ---> it ---> None
# 's ---> be ---> None
# called ---> call ---> None
# a ---> a ---> None
# supermoon ---> supermoon ---> None
# , ---> , ---> punctuation mark, comma
# or ---> or ---> None
# perigee ---> perigee ---> None
# - ---> - ---> None
# syzygy ---> syzygy ---> None
# , ---> , ---> punctuation mark, comma
# and ---> and ---> None
# appears ---> appear ---> None
# larger ---> large ---> None
# than ---> than ---> None
# usual ---> usual ---> None
# in ---> in ---> None
# the ---> the ---> None
# sky ---> sky ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# Supermoons ---> supermoon ---> None
# are ---> be ---> None
# more ---> more ---> None
# common ---> common ---> None
# than ---> than ---> None
# total ---> total ---> None
# eclipses ---> eclipse ---> None
# — ---> — ---> None
# they ---> they ---> None
# typically ---> typically ---> None
# occur ---> occur ---> None
# several ---> several ---> None
# times ---> time ---> None
# a ---> a ---> None
# year ---> year ---> None
# . ---> . ---> punctuation mark, sentence closer
# The ---> the ---> None
# moon ---> moon ---> None
# rises ---> rise ---> None
# over ---> over ---> None
# Victoria ---> Victoria ---> None
# Harbour ---> Harbour ---> None
# in ---> in ---> None
# Hong ---> Hong ---> None
# Kong ---> Kong ---> None
# on ---> on ---> None
# Wednesday ---> Wednesday ---> None
# . ---> . ---> punctuation mark, sentence closer
# "Flower ---> "flower ---> None
# " ---> " ---> None
# : ---> : ---> punctuation mark, colon or ellipsis
# Full ---> full ---> None
# moons ---> moon ---> None
# that ---> that ---> None
# occur ---> occur ---> None
# in ---> in ---> None
# May ---> May ---> None
# are ---> be ---> None
# sometimes ---> sometimes ---> None
# known ---> know ---> None
# as ---> as ---> None
# flower ---> flower ---> None
# moons ---> moon ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# According ---> accord ---> None
# to ---> to ---> None
# The ---> the ---> None
# Old ---> Old ---> None
# Farmer ---> Farmer ---> None
# 's ---> 's ---> None
# Almanac ---> Almanac ---> None
# , ---> , ---> punctuation mark, comma
# the ---> the ---> None
# name ---> name ---> None
# is ---> be ---> None
# a ---> a ---> None
# reference ---> reference ---> None
# to ---> to ---> None
# the ---> the ---> None
# flowers ---> flower ---> None
# that ---> that ---> None
# are ---> be ---> None
# blooming ---> bloom ---> None
# in ---> in ---> None
# May ---> May ---> None
# and ---> and ---> None
# has ---> have ---> None
# been ---> be ---> None
# attributed ---> attribute ---> None
# to ---> to ---> None
# Native ---> native ---> None
# American ---> American ---> None
# , ---> , ---> punctuation mark, comma
# Colonial ---> Colonial ---> None
# American ---> american ---> None
# and ---> and ---> None
# European ---> european ---> None
# sources ---> source ---> None
# . ---> . ---> punctuation mark, sentence closer
# Photographers ---> photographer ---> None
# take ---> take ---> None
# photos ---> photo ---> None
# of ---> of ---> None
# the ---> the ---> None
# lunar ---> lunar ---> None
# eclipse ---> eclipse ---> None
# Wednesday ---> Wednesday ---> None
# at ---> at ---> None
# the ---> the ---> None
# Central ---> Central ---> None
# TV ---> TV ---> None
# Tower ---> Tower ---> None
# in ---> in ---> None
# Beijing ---> Beijing ---> None
# . ---> . ---> punctuation mark, sentence closer
# The ---> the ---> None
# next ---> next ---> None
# total ---> total ---> None
# lunar ---> lunar ---> None
# eclipse ---> eclipse ---> None
# will ---> will ---> None
# occur ---> occur ---> None
# about ---> about ---> None
# a ---> a ---> None
# year ---> year ---> None
# from ---> from ---> None
# now ---> now ---> None
# . ---> . ---> punctuation mark, sentence closer
#
#  --->
#  ---> None
# But ---> but ---> None
# a ---> a ---> None
# near ---> near ---> None
# - ---> - ---> None
# total ---> total ---> None
# eclipse ---> eclipse ---> None
# will ---> will ---> None
# come ---> come ---> None
# on ---> on ---> None
# the ---> the ---> None
# night ---> night ---> None
# of ---> of ---> None
# Nov. ---> Nov. ---> None
# 18 ---> 18 ---> None
# to ---> to ---> None
# 19 ---> 19 ---> None
# , ---> , ---> punctuation mark, comma
# says ---> say ---> None
# Diana ---> Diana ---> None
# Hannikainen ---> Hannikainen ---> None
# , ---> , ---> punctuation mark, comma
# observing ---> observe ---> None
# editor ---> editor ---> None
# at ---> at ---> None
# Sky ---> Sky ---> None
# & ---> & ---> None
# Telescope ---> Telescope ---> None
# . ---> . ---> punctuation mark, sentence closer
# The ---> the ---> None
# lunar ---> lunar ---> None
# eclipse ---> eclipse ---> None
# progresses ---> progress ---> None
# behind ---> behind ---> None
# a ---> a ---> None
# Ferris ---> Ferris ---> None
# wheel ---> wheel ---> None
# over ---> over ---> None
# Santa ---> Santa ---> None
# Monica ---> Monica ---> None
# Beach ---> Beach ---> None
# on ---> on ---> None
# Wednesday ---> Wednesday ---> None
# in ---> in ---> None
# Santa ---> Santa ---> None
# Monica ---> Monica ---> None
# , ---> , ---> punctuation mark, comma
# Calif. ---> Calif. ---> None
#
#  --->
#  ---> None
# The ---> the ---> None
# first ---> first ---> None
# total ---> total ---> None
# lunar ---> lunar ---> None
# eclipse ---> eclipse ---> None
# in ---> in ---> None
# more ---> more ---> None
# than ---> than ---> None
# two ---> two ---> None
# years ---> year ---> None
# is ---> be ---> None
# coinciding ---> coincide ---> None
# with ---> with ---> None
# a ---> a ---> None
# supermoon ---> supermoon ---> None
# . ---> . ---> punctuation mark, sentence closer
# "Technically ---> "technically ---> None
# , ---> , ---> punctuation mark, comma
# the ---> the ---> None
# November ---> November ---> None
# event ---> event ---> None
# will ---> will ---> None
# be ---> be ---> None
# partial ---> partial ---> None
# , ---> , ---> punctuation mark, comma
# but ---> but ---> None
# only ---> only ---> None
# the ---> the ---> None
# thinnest ---> thin ---> None
# sliver ---> sliver ---> None
# of ---> of ---> None
# the ---> the ---> None
# moon ---> moon ---> None
# 's ---> 's ---> None
# disk ---> disk ---> None
# will ---> will ---> None
# remain ---> remain ---> None
# outside ---> outside ---> None
# the ---> the ---> None
# umbra ---> umbra ---> None
# , ---> , ---> punctuation mark, comma
# so ---> so ---> None
# for ---> for ---> None
# all ---> all ---> None
# intents ---> intent ---> None
# and ---> and ---> None
# purposes ---> purpose ---> None
# it ---> it ---> None
# 'll ---> 'll ---> None
# be ---> be ---> None
# very ---> very ---> None
# much ---> much ---> None
# like ---> like ---> None
# a ---> a ---> None
# total ---> total ---> None
# eclipse ---> eclipse ---> None
# , ---> , ---> punctuation mark, comma
# " ---> " ---> None
# she ---> she ---> None
# said ---> say ---> None
# . ---> . ---> punctuation mark, sentence closer

# %% [markdown]
# ### Sentence boundary detection

# %%
list(doc2.sents)
# Out:
# [The lunar eclipse is seen in Santa Monica.,
#  ,
#  Full moons that occur in May are sometimes known as flower moons.,
#  Maybe the sky was cloudy; maybe waking up in the middle of the night to look at the moon just sounds like lunacy.,
#  ,
#  Whatever the reason, if you missed seeing last night's lunar eclipse, you're not alone.,
#  Luckily, there are plenty of photos and video of the rare sight.,
#  For those of us who slept through the Super Flower Blood Moon: Here's a quick time lapse taken early this morning 🌷🌕 pic.twitter.com/Q38GJ4WrWHThe supermoon — the Super Flower Blood Moon, to be exact — brought the first total lunar eclipse in nearly 2 1/2 years, treating sky watchers to the sight of the moon slipping into Earth's shadow while also appearing around 7% larger than it normally does.,
#  Residents watch the lunar eclipse Wednesday at Sanur beach in Indonesia's Bali.,
#  The reddish-orange color of the supermoon is the result of all the sunrises and sunsets in Earth's atmosphere projected onto the surface of the eclipsed moon.,
#  People on both sides of the Pacific Ocean were able to see the total eclipse, from the Western U.S. and Mexico to New Zealand and eastern Australia.,
#  ,
#  Some of the best views were in Hawaii and the Pacific islands.,
#  The biggest draw of this celestial event is that a supermoon and a total lunar eclipse are occurring simultaneously.,
#  ,
#  In the past 10 years, there have been just 10 total lunar eclipses.,
#  A lunar eclipse is observed Wednesday in Brasilia, Brazil.,
#  The supermoon was visible all over the world, but the full lunar eclipse was visible in many parts of the world.,
#  ,
#  Observers had to look fast; the total eclipse lasted around 15 minutes.,
#  The unusual name for this moon is due to several astronomical phenomena coinciding in one event.,
#  "Blood": The moon takes on a red hue as it aligns with the sun and Earth and passes fully into Earth's shadow, or umbra.,
#  ,
#  The distinct bloodlike color is caused by red-orange light refracted through the Earth's atmosphere.,
#  ,
#  The red hue can appear more intense if more clouds or dust are in the Earth's atmosphere, according to NASA.A surfer rides a wave Wednesday as a supermoon rises above the horizon at Manly Beach in Sydney."Super,
#  ": The shape of the moon's orbit around the Earth is not a perfect circle, but an oval.,
#  ,
#  When a full moon reaches the point closest to our planet on its elliptical orbit, it's called a supermoon, or perigee-syzygy, and appears larger than usual in the sky.,
#  ,
#  Supermoons are more common than total eclipses — they typically occur several times a year.,
#  The moon rises over Victoria Harbour in Hong Kong on Wednesday.,
#  "Flower": Full moons that occur in May are sometimes known as flower moons.,
#  ,
#  According to The Old Farmer's Almanac, the name is a reference to the flowers that are blooming in May and has been attributed to Native American, Colonial American and European sources.,
#  Photographers take photos of the lunar eclipse Wednesday at the Central TV Tower in Beijing.,
#  The next total lunar eclipse will occur about a year from now.,
#  ,
#  But a near-total eclipse will come on the night of Nov. 18 to 19, says Diana Hannikainen, observing editor at Sky & Telescope.,
#  The lunar eclipse progresses behind a Ferris wheel over Santa Monica Beach on Wednesday in Santa Monica, Calif.,
#  The first total lunar eclipse in more than two years is coinciding with a supermoon.,
#  "Technically, the November event will be partial, but only the thinnest sliver of the moon's disk will remain outside the umbra, so for all intents and purposes it'll be very much like a total eclipse," she said.]

# %%
sentences2 = list(doc2.sents)

# %%
for sentence in sentences2:
    print(sentence)
# Out:
# The lunar eclipse is seen in Santa Monica.
#
#
# Full moons that occur in May are sometimes known as flower moons.
# Maybe the sky was cloudy; maybe waking up in the middle of the night to look at the moon just sounds like lunacy.
#
#
# Whatever the reason, if you missed seeing last night's lunar eclipse, you're not alone.
#
# Luckily, there are plenty of photos and video of the rare sight.
# For those of us who slept through the Super Flower Blood Moon: Here's a quick time lapse taken early this morning 🌷🌕 pic.twitter.com/Q38GJ4WrWHThe supermoon — the Super Flower Blood Moon, to be exact — brought the first total lunar eclipse in nearly 2 1/2 years, treating sky watchers to the sight of the moon slipping into Earth's shadow while also appearing around 7% larger than it normally does.
# Residents watch the lunar eclipse Wednesday at Sanur beach in Indonesia's Bali.
#
# The reddish-orange color of the supermoon is the result of all the sunrises and sunsets in Earth's atmosphere projected onto the surface of the eclipsed moon.
# People on both sides of the Pacific Ocean were able to see the total eclipse, from the Western U.S. and Mexico to New Zealand and eastern Australia.
#
#
# Some of the best views were in Hawaii and the Pacific islands.
# The biggest draw of this celestial event is that a supermoon and a total lunar eclipse are occurring simultaneously.
#
#
# In the past 10 years, there have been just 10 total lunar eclipses.
# A lunar eclipse is observed Wednesday in Brasilia, Brazil.
# The supermoon was visible all over the world, but the full lunar eclipse was visible in many parts of the world.
#
#
# Observers had to look fast; the total eclipse lasted around 15 minutes.
# The unusual name for this moon is due to several astronomical phenomena coinciding in one event.
# "Blood": The moon takes on a red hue as it aligns with the sun and Earth and passes fully into Earth's shadow, or umbra.
#
#
# The distinct bloodlike color is caused by red-orange light refracted through the Earth's atmosphere.
#
#
# The red hue can appear more intense if more clouds or dust are in the Earth's atmosphere, according to NASA.A surfer rides a wave Wednesday as a supermoon rises above the horizon at Manly Beach in Sydney."Super
# ": The shape of the moon's orbit around the Earth is not a perfect circle, but an oval.
#
#
# When a full moon reaches the point closest to our planet on its elliptical orbit, it's called a supermoon, or perigee-syzygy, and appears larger than usual in the sky.
#
#
# Supermoons are more common than total eclipses — they typically occur several times a year.
# The moon rises over Victoria Harbour in Hong Kong on Wednesday.
# "Flower": Full moons that occur in May are sometimes known as flower moons.
#
#
# According to The Old Farmer's Almanac, the name is a reference to the flowers that are blooming in May and has been attributed to Native American, Colonial American and European sources.
# Photographers take photos of the lunar eclipse Wednesday at the Central TV Tower in Beijing.
# The next total lunar eclipse will occur about a year from now.
#
#
# But a near-total eclipse will come on the night of Nov. 18 to 19, says Diana Hannikainen, observing editor at Sky & Telescope.
# The lunar eclipse progresses behind a Ferris wheel over Santa Monica Beach on Wednesday in Santa Monica, Calif.
#
# The first total lunar eclipse in more than two years is coinciding with a supermoon.
# "Technically, the November event will be partial, but only the thinnest sliver of the moon's disk will remain outside the umbra, so for all intents and purposes it'll be very much like a total eclipse," she said.

# %% [markdown]
# ### Named entity

# %%
for ent in doc2.ents:
    print(ent.text, '--->', ent.label_, '--->', spacy.explain(ent.label_))
# Out:
# Santa Monica ---> GPE ---> Countries, cities, states
# May ---> DATE ---> Absolute or relative dates or periods
# last night's ---> TIME ---> Times smaller than a day
# early this morning ---> TIME ---> Times smaller than a day
# 🌕 ---> DATE ---> Absolute or relative dates or periods
# first ---> ORDINAL ---> "first", "second", etc.
# nearly 2 1/2 years ---> DATE ---> Absolute or relative dates or periods
# Earth ---> LOC ---> Non-GPE locations, mountain ranges, bodies of water
# around 7% ---> PERCENT ---> Percentage, including "%"
# Wednesday ---> DATE ---> Absolute or relative dates or periods
# Sanur ---> ORG ---> Companies, agencies, institutions, etc.
# Indonesia ---> GPE ---> Countries, cities, states
# Bali ---> GPE ---> Countries, cities, states
# Earth ---> LOC ---> Non-GPE locations, mountain ranges, bodies of water
# the Pacific Ocean ---> LOC ---> Non-GPE locations, mountain ranges, bodies of water
# U.S. ---> GPE ---> Countries, cities, states
# Mexico ---> GPE ---> Countries, cities, states
# New Zealand ---> GPE ---> Countries, cities, states
# Australia ---> GPE ---> Countries, cities, states
# Hawaii ---> GPE ---> Countries, cities, states
# Pacific ---> LOC ---> Non-GPE locations, mountain ranges, bodies of water
# the past 10 years ---> DATE ---> Absolute or relative dates or periods
# 10 ---> CARDINAL ---> Numerals that do not fall under another type
# Wednesday ---> DATE ---> Absolute or relative dates or periods
# Brasilia ---> GPE ---> Countries, cities, states
# Brazil ---> GPE ---> Countries, cities, states
# around 15 minutes ---> TIME ---> Times smaller than a day
# one ---> CARDINAL ---> Numerals that do not fall under another type
# Earth ---> LOC ---> Non-GPE locations, mountain ranges, bodies of water
# Earth ---> LOC ---> Non-GPE locations, mountain ranges, bodies of water
# Earth ---> LOC ---> Non-GPE locations, mountain ranges, bodies of water
# Earth ---> LOC ---> Non-GPE locations, mountain ranges, bodies of water
# NASA.A ---> ORG ---> Companies, agencies, institutions, etc.
# Wednesday ---> DATE ---> Absolute or relative dates or periods
# Manly Beach ---> GPE ---> Countries, cities, states
# Sydney ---> GPE ---> Countries, cities, states
# Earth ---> LOC ---> Non-GPE locations, mountain ranges, bodies of water
# Victoria Harbour ---> FAC ---> Buildings, airports, highways, bridges, etc.
# Hong Kong ---> GPE ---> Countries, cities, states
# Wednesday ---> DATE ---> Absolute or relative dates or periods
# May ---> DATE ---> Absolute or relative dates or periods
# The Old Farmer's Almanac ---> ORG ---> Companies, agencies, institutions, etc.
# May ---> DATE ---> Absolute or relative dates or periods
# Native American ---> NORP ---> Nationalities or religious or political groups
# Colonial American ---> NORP ---> Nationalities or religious or political groups
# European ---> NORP ---> Nationalities or religious or political groups
# Wednesday ---> DATE ---> Absolute or relative dates or periods
# the Central TV Tower ---> ORG ---> Companies, agencies, institutions, etc.
# Beijing ---> GPE ---> Countries, cities, states
# about a year from now ---> DATE ---> Absolute or relative dates or periods
# the night of Nov. 18 to 19 ---> TIME ---> Times smaller than a day
# Diana Hannikainen ---> PERSON ---> People, including fictional
# Sky & Telescope ---> ORG ---> Companies, agencies, institutions, etc.
# Ferris ---> PERSON ---> People, including fictional
# Santa Monica Beach ---> GPE ---> Countries, cities, states
# Wednesday ---> DATE ---> Absolute or relative dates or periods
# Santa Monica ---> GPE ---> Countries, cities, states
# Calif. ---> GPE ---> Countries, cities, states
# first ---> ORDINAL ---> "first", "second", etc.
# more than two years ---> DATE ---> Absolute or relative dates or periods
# November ---> DATE ---> Absolute or relative dates or periods

# %% [markdown]
# ### Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc2, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The lunar eclipse is seen in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Santa Monica
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</br>Full moons that occur in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     May
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  are sometimes known as flower moons.Maybe the sky was cloudy; maybe waking up in the middle of the night to look at the moon just sounds like lunacy.</br>Whatever the reason, if you missed seeing
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last night's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  lunar eclipse, you're not alone.</br>Luckily, there are plenty of photos and video of the rare sight.For those of us who slept through the Super Flower Blood Moon: Here's a quick time lapse taken
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     early this morning
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  🌷
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     🌕
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  pic.twitter.com/Q38GJ4WrWHThe supermoon — the Super Flower Blood Moon, to be exact — brought the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  total lunar eclipse in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nearly 2 1/2 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , treating sky watchers to the sight of the moon slipping into
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# 's shadow while also appearing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     around 7%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  larger than it normally does.Residents watch the lunar eclipse
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sanur
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  beach in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Indonesia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bali
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</br>The reddish-orange color of the supermoon is the result of all the sunrises and sunsets in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# 's atmosphere projected onto the surface of the eclipsed moon.People on both sides of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Pacific Ocean
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  were able to see the total eclipse, from the Western
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mexico
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New Zealand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and eastern
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Australia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</br>Some of the best views were in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hawaii
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pacific
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  islands.The biggest draw of this celestial event is that a supermoon and a total lunar eclipse are occurring simultaneously.</br>In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past 10 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , there have been just
# <mark class="entit

# %%
displacy.render(doc2, style='dep', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="76a124a02cf94c429df9dd0655fb0e64-0" class="displacy" width="112925" height="1887.0" direction="ltr" style="max-width: none; height: 1887.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">lunar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">eclipse</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">seen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Santa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Monica.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Full</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">moons</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">occur</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">May</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">sometimes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">known</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">flower</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">moons.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">Maybe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">sky</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">cloudy;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">maybe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">waking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">up</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1797.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="cu

# %% [markdown]
# ### Putting it all together

# %%
lis2 = []

# %%
for token in doc2:
    dic = {}
    dic['Token'] = token.text
    dic['POS'] = token.pos_
    dic['Tags'] = token.tag_
    dic['Dep'] = token.dep_
    dic['Explaination'] = spacy.explain(token.tag_)
    lis2.append(dic)

# %%
import pandas as pd

# %%
data2 = pd.DataFrame(lis2)

# %%
data2
# Out:
#        Token    POS Tags        Dep                       Explaination
# 0        The    DET   DT        det                         determiner
# 1      lunar    ADJ   JJ       amod                          adjective
# 2    eclipse   NOUN   NN  nsubjpass             noun, singular or mass
# 3         is    AUX  VBZ    auxpass  verb, 3rd person singular present
# 4       seen   VERB  VBN       ROOT              verb, past participle
# ..       ...    ...  ...        ...                                ...
# 713        ,  PUNCT    ,      punct            punctuation mark, comma
# 714        "  PUNCT   ''      punct             closing quotation mark
# 715      she   PRON  PRP      nsubj                  pronoun, personal
# 716     said   VERB  VBD       ROOT                   verb, past tense
# 717        .  PUNCT    .      punct  punctuation mark, sentence closer
#
# [718 rows x 5 columns]

# %% [markdown]
# #### You can reindex if you do not like the arrangement

# %%
l2 = []
for ent in doc2.ents:
    d = {}
    d['entities'] = ent.text
    d['labels'] = ent.label_
    d['Explaination'] = spacy.explain(ent.label_)
    l2.append(d)

# %%
entities2 = pd.DataFrame(l2)

# %%
entities2
# Out:
#                entities   labels                           Explaination
# 0          Santa Monica      GPE              Countries, cities, states
# 1                   May     DATE  Absolute or relative dates or periods
# 2          last night's     TIME               Times smaller than a day
# 3    early this morning     TIME               Times smaller than a day
# 4                     🌕     DATE  Absolute or relative dates or periods
# ..                  ...      ...                                    ...
# 56         Santa Monica      GPE              Countries, cities, states
# 57               Calif.      GPE              Countries, cities, states
# 58                first  ORDINAL                "first", "second", etc.
# 59  more than two years     DATE  Absolute or relative dates or periods
# 60             November     DATE  Absolute or relative dates or periods
#
# [61 rows x 3 columns]

# %%
entities2.to_csv('Entities2.csv', index = False)
